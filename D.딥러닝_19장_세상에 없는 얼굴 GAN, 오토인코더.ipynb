# %% [markdown]
# # 19장. 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# * https://www.thispersondoesnotexist.com/ : 들어갈때마다 새로운 인물이 나옴
# * GAN 적대적이라는 단어가 있음.진짜같은 가짜를 만들기 위해 GAN알고리즘 내부에서는 적대적인 경합을 함
# * https://arxiv.org/pdf/1511.06434.pdf
# * https://phillipi.github.io/pix2pix/
# * https://www.youtube.com/watch?v=dCKbRCUyop8

# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential (Sequential)     (None, 28, 28, 1)         865281
#
#  sequential_1 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4624  g_loss:0.3281
# epoch:2  d_loss:0.5688  g_loss:0.1024
# epoch:3  d_loss:0.6580  g_loss:0.0836
# epoch:4  d_loss:0.5759  g_loss:0.1646
# epoch:5  d_loss:0.5085  g_loss:0.4193
# epoch:6  d_loss:0.4878  g_loss:0.6924
# epoch:7  d_loss:0.5097  g_loss:0.8631
# epoch:8  d_loss:0.4979  g_loss:0.8866
# epoch:9  d_loss:0.4886  g_loss:0.8602
# epoch:10  d_loss:0.4219  g_loss:0.7737
# epoch:11  d_loss:0.4458  g_loss:0.7970
# epoch:12  d_loss:0.4926  g_loss:0.8488
# epoch:13  d_loss:0.4896  g_loss:0.8935
# epoch:14  d_loss:0.5805  g_loss:0.9655
# epoch:15  d_loss:0.4861  g_loss:1.0666
# epoch:16  d_loss:0.4107  g_loss:1.0645
# epoch:17  d_loss:0.6209  g_loss:0.8040
# epoch:18  d_loss:0.5595  g_loss:0.6708
# epoch:19  d_loss:0.4596  g_loss:0.7138
# epoch:20  d_loss:0.4292  g_loss:0.7457
# epoch:21  d_loss:0.4943  g_loss:0.8084
# epoch:22  d_loss:0.5023  g_loss:0.6541
# epoch:23  d_loss:0.4476  g_loss:0.6239
# epoch:24  d_loss:0.4426  g_loss:0.6779
# epoch:25  d_loss:0.4646  g_loss:0.6954
# epoch:26  d_loss:0.4984  g_loss:0.7026
# epoch:27  d_loss:0.4548  g_loss:0.6087
# epoch:28  d_loss:0.4738  g_loss:0.5301
# epoch:29  d_loss:0.5111  g_loss:0.5885
# epoch:30  d_loss:0.4444  g_loss:0.6502
# epoch:31  d_loss:0.4465  g_loss:0.7042
# epoch:32  d_loss:0.4150  g_loss:0.5367
# epoch:33  d_loss:0.3913  g_loss:0.7091
# epoch:34  d_loss:0.3097  g_loss:0.7422
# epoch:35  d_loss:0.3675  g_loss:0.8572
# epoch:36  d_loss:0.3944  g_loss:0.6923
# epoch:37  d_loss:0.3220  g_loss:0.8099
# epoch:38  d_loss:0.3163  g_loss:1.0292
# epoch:39  d_loss:0.2302  g_loss:1.3923
# epoch:40  d_loss:0.2973  g_loss:1.3392
# epoch:41  d_loss:0.3882  g_loss:1.1084
# epoch:42  d_loss:0.3593  g_loss:0.8447
# epoch:43  d_loss:0.2337  g_loss:1.1415
# epoch:44  d_loss:0.1797  g_loss:1.3665
# epoch:45  d_loss:0.1874  g_loss:1.8548
# epoch:46  d_loss:0.4527  g_loss:1.1842
# epoch:47  d_loss:0.4145  g_loss:1.0180
# epoch:48  d_loss:0.2870  g_loss:2.0464
# epoch:49  d_loss:0.2833  g_loss:2.6412
# epoch:50  d_loss:0.1886  g_loss:2.4848
# epoch:51  d_loss:0.1241  g_loss:2.0416
# epoch:52  d_loss:0.0927  g_loss:2.0546
# epoch:53  d_loss:0.1555  g_loss:1.9774
# epoch:54  d_loss:0.1373  g_loss:2.7533
# epoch:55  d_loss:0.1678  g_loss:3.8428
# epoch:56  d_loss:0.4381  g_loss:2.0814
# epoch:57  d_loss:0.6922  g_loss:2.1398
# epoch:58  d_loss:0.5809  g_loss:2.8570
# epoch:59  d_loss:0.6353  g_loss:2.2319
# epoch:60  d_loss:0.6976  g_loss:2.4336
# epoch:61  d_loss:0.5337  g_loss:3.3638
# epoch:62  d_loss:0.4987  g_loss:3.2108
# epoch:63  d_loss:0.2612  g_loss:3.4496
# epoch:64  d_loss:0.4575  g_loss:2.6672
# epoch:65  d_loss:0.4759  g_loss:2.6139
# epoch:66  d_loss:0.4320  g_loss:2.1490
# epoch:67  d_loss:0.4468  g_loss:2.3810
# epoch:68  d_loss:0.1982  g_loss:3.3622
# epoch:69  d_loss:0.6906  g_loss:1.7504
# epoch:70  d_loss:0.8452  g_loss:0.8926
# epoch:71  d_loss:0.5425  g_loss:1.1226
# epoch:72  d_loss:0.6853  g_loss:1.5627
# epoch:73  d_loss:0.5754  g_loss:1.6204
# epoch:74  d_loss:0.8404  g_loss:1.1003
# epoch:75  d_loss:0.8898  g_loss:1.0441
# epoch:76  d_loss:0.6833  g_loss:1.2441
# epoch:77  d_loss:0.4201  g_loss:2.4923
# epoch:78  d_loss:0.3891  g_loss:3.4204
# epoch:79  d_loss:0.3008  g_loss:3.4409
# epoch:80  d_loss:0.2978  g_loss:2.7954
# epoch:81  d_loss:0.3643  g_loss:2.7613
# epoch:82  d_loss:0.2763  g_loss:3.2343
# epoch:83  d_loss:0.2842  g_loss:4.8211
# epoch:84  d_loss:0.3921  g_loss:5.2442
# epoch:85  d_loss:0.9671  g_loss:3.7397
# epoch:86  d_loss:0.8316  g_loss:3.1745
# epoch:87  d_loss:0.8656  g_loss:3.2904
# epoch:88  d_loss:0.9556  g_loss:3.4391
# epoch:89  d_loss:1.0503  g_loss:2.7616
# epoch:90  d_loss:0.7245  g_loss:2.5967
# epoch:91  d_loss:0.8251  g_loss:2.7441
# epoch:92  d_loss:0.7969  g_loss:2.3109
# epoch:93  d_loss:0.7493  g_loss:1.7034
# epoch:94  d_loss:0.5896  g_loss:1.3987
# epoch:95  d_loss:0.5661  g_loss:1.3689
# epoch:96  d_loss:0.5209  g_loss:1.2622
# epoch:97  d_loss:0.4172  g_loss:1.5440
# epoch:98  d_loss:0.4014  g_loss:1.4200
# epoch:99  d_loss:0.5458  g_loss:1.4714
# epoch:100  d_loss:0.5139  g_loss:1.0825
# epoch:101  d_loss:0.4231  g_loss:1.2376
# epoch:102  d_loss:0.3695  g_loss:1.2487
# epoch:103  d_loss:0.4983  g_loss:1.2523
# epoch:104  d_loss:0.4287  g_loss:1.1161
# epoch:105  d_loss:0.5140  g_loss:1.1063
# epoch:106  d_loss:0.5136  g_loss:1.0299
# epoch:107  d_loss:0.4396  g_loss:1.2132
# epoch:108  d_loss:0.4921  g_loss:1.0455
# epoch:109  d_loss:0.3896  g_loss:1.0732
# epoch:110  d_loss:0.4356  g_loss:1.0371
# epoch:111  d_loss:0.4593  g_loss:1.0718
# epoch:112  d_loss:0.4628  g_loss:1.1439
# epoch:113  d_loss:0.5314  g_loss:1.0334
# epoch:114  d_loss:0.6387  g_loss:0.9204
# epoch:115  d_loss:0.6034  g_loss:0.9353
# epoch:116  d_loss:0.5579  g_loss:0.8938
# epoch:117  d_loss:0.6179  g_loss:0.9899
# epoch:118  d_loss:0.6503  g_loss:0.8938
# epoch:119  d_loss:0.4777  g_loss:1.0803
# epoch:120  d_loss:0.6330  g_loss:1.0369
# epoch:121  d_loss:0.7007  g_loss:0.8986
# epoch:122  d_loss:0.7926  g_loss:0.8675
# epoch:123  d_loss:0.7221  g_loss:0.8373
# epoch:124  d_loss:0.6193  g_loss:0.9428
# epoch:125  d_loss:0.7282  g_loss:0.9704
# epoch:126  d_loss:0.6452  g_loss:1.0185
# epoch:127  d_loss:0.5867  g_loss:1.1464
# epoch:128  d_loss:0.5442  g_loss:1.1819
# epoch:129  d_loss:0.5359  g_loss:1.3651
# epoch:130  d_loss:0.4844  g_loss:1.3222
# epoch:131  d_loss:0.4996  g_loss:1.5380
# epoch:132  d_loss:0.4795  g_loss:1.4456
# epoch:133  d_loss:0.4122  g_loss:1.7883
# epoch:134  d_loss:0.3526  g_loss:2.0609
# epoch:135  d_loss:0.3595  g_loss:2.1071
# epoch:136  d_loss:0.4082  g_loss:1.9134
# epoch:137  d_loss:0.2979  g_loss:2.4485
# epoch:138  d_loss:0.3027  g_loss:2.1628
# epoch:139  d_loss:0.3206  g_loss:2.4959
# epoch:140  d_loss:0.3048  g_loss:2.2213
# epoch:141  d_loss:0.3797  g_loss:2.2802
# epoch:142  d_loss:0.3990  g_loss:2.0479
# epoch:143  d_loss:0.3439  g_loss:2.4447
# epoch:144  d_loss:0.4455  g_loss:2.3579
# epoch:145  d_loss:0.4449  g_loss:2.7728
# epoch:146  d_loss:0.5341  g_loss:2.8900
# epoch:147  d_loss:0.7776  g_loss:2.5826
# epoch:148  d_loss:0.6331  g_loss:2.3102
# epoch:149  d_loss:0.6111  g_loss:2.1595
# epoch:150  d_loss:0.6312  g_loss:1.8812
# epoch:151  d_loss:0.7292  g_loss:1.9835
# epoch:152  d_loss:0.6671  g_loss:1.8677
# epoch:153  d_loss:0.6494  g_loss:1.7400
# epoch:154  d_loss:0.6280  g_loss:1.4544
# epoch:155  d_loss:0.7134  g_loss:1.5275
# epoch:156  d_loss:0.7360  g_loss:1.3670
# epoch:157  d_loss:0.5602  g_loss:1.9662
# epoch:158  d_loss:0.4874  g_loss:1.5960
# epoch:159  d_loss:0.4917  g_loss:1.5024
# epoch:160  d_loss:0.5420  g_loss:1.3143
# epoch:161  d_loss:0.5512  g_loss:1.4244
# epoch:162  d_loss:0.4598  g_loss:1.4516
# epoch:163  d_loss:0.3898  g_loss:1.6189
# epoch:164  d_loss:0.4165  g_loss:1.4536
# epoch:165  d_loss:0.3555  g_loss:1.6631
# epoch:166  d_loss:0.3846  g_loss:1.7852
# epoch:167  d_loss:0.4620  g_loss:1.5452
# epoch:168  d_loss:0.3834  g_loss:1.5852
# epoch:169  d_loss:0.4198  g_loss:1.7220
# epoch:170  d_loss:0.3998  g_loss:1.4076
# epoch:171  d_loss:0.4363  g_loss:1.3449
# epoch:172  d_loss:0.3579  g_loss:1.2381
# epoch:173  d_loss:0.3293  g_loss:1.3261
# epoch:174  d_loss:0.3931  g_loss:1.3983
# epoch:175  d_loss:0.3157  g_loss:1.5806
# epoch:176  d_loss:0.5320  g_loss:1.3610
# epoch:177  d_loss:0.4220  g_loss:1.7861
# epoch:178  d_loss:0.3261  g_loss:1.4652
# epoch:179  d_loss:0.3502  g_loss:1.3768
# epoch:180  d_loss:0.3940  g_loss:1.2052
# epoch:181  d_loss:0.3875  g_loss:1.4027
# epoch:182  d_loss:0.4325  g_loss:1.2809
# epoch:183  d_loss:0.4253  g_loss:1.3593
# epoch:184  d_loss:0.4935  g_loss:1.2283
# epoch:185  d_loss:0.4705  g_loss:1.5107
# epoch:186  d_loss:0.5522  g_loss:1.4555
# epoch:187  d_loss:0.6130  g_loss:1.2437
# epoch:188  d_loss:0.7571  g_loss:1.1207
# epoch:189  d_loss:0.5870  g_loss:1.0249
# epoch:190  d_loss:0.5085  g_loss:1.2232
# epoch:191  d_loss:0.7400  g_loss:1.3862
# epoch:192  d_loss:0.5732  g_loss:1.3439
# epoch:193  d_loss:0.6553  g_loss:1.2680
# epoch:194  d_loss:0.6734  g_loss:1.1195
# epoch:195  d_loss:0.7007  g_loss:1.0415
# epoch:196  d_loss:0.6522  g_loss:1.1806
# epoch:197  d_loss:0.5765  g_loss:1.3702
# epoch:198  d_loss:0.5208  g_loss:1.5058
# epoch:199  d_loss:0.5229  g_loss:1.5165
# epoch:200  d_loss:0.6421  g_loss:1.4295
# epoch:201  d_loss:0.5145  g_loss:1.4451
# epoch:202  d_loss:0.5800  g_loss:1.5211
# epoch:203  d_loss:0.4120  g_loss:1.4949
# epoch:204  d_loss:0.4508  g_loss:1.7346
# epoch:205  d_loss:0.3858  g_loss:1.8833
# epoch:206  d_loss:0.3645  g_loss:1.9741
# epoch:207  d_loss:0.4134  g_loss:1.9948
# epoch:208  d_loss:0.4294  g_loss:1.9141
# epoch:209  d_loss:0.3344  g_loss:1.9182
# epoch:210  d_loss:0.4165  g_loss:1.9846
# epoch:211  d_loss:0.4724  g_loss:2.2111
# epoch:212  d_loss:0.3653  g_loss:2.4089
# epoch:213  d_loss:0.4809  g_loss:2.3021
# epoch:214  d_loss:0.4355  g_loss:1.8985
# epoch:215  d_loss:0.4343  g_loss:1.5591
# epoch:216  d_loss:0.5734  g_loss:1.5956
# epoch:217  d_loss:0.3727  g_loss:1.8697
# epoch:218  d_loss:0.4018  g_loss:2.2300
# epoch:219  d_loss:0.5324  g_loss:2.2130
# epoch:220  d_loss:0.3987  g_loss:2.2061
# epoch:221  d_loss:0.5085  g_loss:1.9559
# epoch:222  d_loss:0.6294  g_loss:1.4449
# epoch:223  d_loss:0.6496  g_loss:1.3330
# epoch:224  d_loss:0.4424  g_loss:1.6756
# epoch:225  d_loss:0.4361  g_loss:1.5846
# epoch:226  d_loss:0.5114  g_loss:1.6924
# epoch:227  d_loss:0.5336  g_loss:1.7577
# epoch:228  d_loss:0.5321  g_loss:1.8646
# epoch:229  d_loss:0.5902  g_loss:1.7671
# epoch:230  d_loss:0.4578  g_loss:1.8074
# epoch:231  d_loss:0.6777  g_loss:1.6978
# epoch:232  d_loss:0.6894  g_loss:1.4544
# epoch:233  d_loss:0.7258  g_loss:1.4528
# epoch:234  d_loss:0.5588  g_loss:1.4904
# epoch:235  d_loss:0.4732  g_loss:1.2598
# epoch:236  d_loss:0.5122  g_loss:1.3809
# epoch:237  d_loss:0.5031  g_loss:1.5979
# epoch:238  d_loss:0.4829  g_loss:1.7161
# epoch:239  d_loss:0.4296  g_loss:1.8884
# epoch:240  d_loss:0.4921  g_loss:1.4951
# epoch:241  d_loss:0.5711  g_loss:1.3746
# epoch:242  d_loss:0.6001  g_loss:1.3014
# epoch:243  d_loss:0.5610  g_loss:1.3132
# epoch:244  d_loss:0.5618  g_loss:1.3105
# epoch:245  d_loss:0.4180  g_loss:1.3401
# epoch:246  d_loss:0.4409  g_loss:1.9321
# epoch:247  d_loss:0.3397  g_loss:1.9760
# epoch:248  d_loss:0.4509  g_loss:1.9028
# epoch:249  d_loss:0.4951  g_loss:1.6012
# epoch:250  d_loss:0.4142  g_loss:1.7239
# epoch:251  d_loss:0.3179  g_loss:1.7948
# epoch:252  d_loss:0.4052  g_loss:1.3426
# epoch:253  d_loss:0.3626  g_loss:1.4569
# epoch:254  d_loss:0.4758  g_loss:1.6352
# epoch:255  d_loss:0.4367  g_loss:1.6860
# epoch:256  d_loss:0.4446  g_loss:1.9731
# epoch:257  d_loss:0.4000  g_loss:1.7964
# epoch:258  d_loss:0.4696  g_loss:1.9863
# epoch:259  d_loss:0.4193  g_loss:2.0075
# epoch:260  d_loss:0.3922  g_loss:1.9693
# epoch:261  d_loss:0.3605  g_loss:1.9072
# epoch:262  d_loss:0.4363  g_loss:1.7200
# epoch:263  d_loss:0.4651  g_loss:1.9206
# epoch:264  d_loss:0.5231  g_loss:1.7194
# epoch:265  d_loss:0.5050  g_loss:1.8900
# epoch:266  d_loss:0.4546  g_loss:1.6004
# epoch:267  d_loss:0.6055  g_loss:2.3318
# epoch:268  d_loss:0.5932  g_loss:2.0205
# epoch:269  d_loss:0.6397  g_loss:1.7172
# epoch:270  d_loss:0.6393  g_loss:1.8226
# epoch:271  d_loss:0.4641  g_loss:1.9242
# epoch:272  d_loss:0.4945  g_loss:1.9917
# epoch:273  d_loss:0.4929  g_loss:2.0208
# epoch:274  d_loss:0.5611  g_loss:1.7504
# epoch:275  d_loss:0.4287  g_loss:1.3762
# epoch:276  d_loss:0.6573  g_loss:1.4722
# epoch:277  d_loss:0.5607  g_loss:1.7274
# epoch:278  d_loss:0.3506  g_loss:1.8913
# epoch:279  d_loss:0.3961  g_loss:2.0214
# epoch:280  d_loss:0.3415  g_loss:1.8875
# epoch:281  d_loss:0.4726  g_loss:2.0417
# epoch:282  d_loss:0.3564  g_loss:2.4694
# epoch:283  d_loss:0.3947  g_loss:2.6263
# epoch:284  d_loss:0.4618  g_loss:2.6314
# epoch:285  d_loss:0.5104  g_loss:2.2578
# epoch:286  d_loss:0.3418  g_loss:1.5928
# epoch:287  d_loss:0.4075  g_loss:2.0830
# epoch:288  d_loss:0.4424  g_loss:2.0580
# epoch:289  d_loss:0.5034  g_loss:2.1716
# epoch:290  d_loss:0.6646  g_loss:1.6477
# epoch:291  d_loss:0.4509  g_loss:1.7363
# epoch:292  d_loss:0.4715  g_loss:1.6266
# epoch:293  d_loss:0.5721  g_loss:1.5762
# epoch:294  d_loss:0.4051  g_loss:1.9566
# epoch:295  d_loss:0.5386  g_loss:1.7631
# epoch:296  d_loss:0.4321  g_loss:1.9698
# epoch:297  d_loss:0.5358  g_loss:1.9702
# epoch:298  d_loss:0.5250  g_loss:1.8517
# epoch:299  d_loss:0.3905  g_loss:2.0214
# epoch:300  d_loss:0.5593  g_loss:1.7605
# epoch:301  d_loss:0.4815  g_loss:1.7504
# epoch:302  d_loss:0.3938  g_loss:1.8377
# epoch:303  d_loss:0.5327  g_loss:2.1924
# epoch:304  d_loss:0.5102  g_loss:1.7311
# epoch:305  d_loss:0.5346  g_loss:1.9415
# epoch:306  d_loss:0.4423  g_loss:1.8372
# epoch:307  d_loss:0.4363  g_loss:1.9478
# epoch:308  d_loss:0.4589  g_loss:1.9958
# epoch:309  d_loss:0.4565  g_loss:1.8916
# epoch:310  d_loss:0.5280  g_loss:1.3683
# epoch:311  d_loss:0.4342  g_loss:1.9802
# epoch:312  d_loss:0.4691  g_loss:1.6645
# epoch:313  d_loss:0.4660  g_loss:1.7661
# epoch:314  d_loss:0.6008  g_loss:1.8503
# epoch:315  d_loss:0.4266  g_loss:1.8699
# epoch:316  d_loss:0.5197  g_loss:1.6794
# epoch:317  d_loss:0.5078  g_loss:1.3998
# epoch:318  d_loss:0.4208  g_loss:1.5625
# epoch:319  d_loss:0.5200  g_loss:1.7858
# epoch:320  d_loss:0.5259  g_loss:1.6981
# epoch:321  d_loss:0.4410  g_loss:1.9129
# epoch:322  d_loss:0.5114  g_loss:1.6922
# epoch:323  d_loss:0.4781  g_loss:1.6094
# epoch:324  d_loss:0.4797  g_loss:1.5637
# epoch:325  d_loss:0.4294  g_loss:1.5152
# epoch:326  d_loss:0.3703  g_loss:1.7942
# epoch:327  d_loss:0.3857  g_loss:1.8475
# epoch:328  d_loss:0.3597  g_loss:2.0030
# epoch:329  d_loss:0.4430  g_loss:2.0686
# epoch:330  d_loss:0.5312  g_loss:1.9230
# epoch:331  d_loss:0.4660  g_loss:2.0555
# epoch:332  d_loss:0.4261  g_loss:1.9024
# epoch:333  d_loss:0.3954  g_loss:1.9846
# epoch:334  d_loss:0.4628  g_loss:1.7057
# epoch:335  d_loss:0.4274  g_loss:1.6551
# epoch:336  d_loss:0.3013  g_loss:1.6612
# epoch:337  d_loss:0.2814  g_loss:2.3406
# epoch:338  d_loss:0.3472  g_loss:2.2414
# epoch:339  d_loss:0.3262  g_loss:2.6345
# epoch:340  d_loss:0.4196  g_loss:2.2773
# epoch:341  d_loss:0.3476  g_loss:2.2657
# epoch:342  d_loss:0.3414  g_loss:2.5130
# epoch:343  d_loss:0.2510  g_loss:2.2936
# epoch:344  d_loss:0.2836  g_loss:2.0899
# epoch:345  d_loss:0.2737  g_loss:2.6721
# epoch:346  d_loss:0.4092  g_loss:2.7229
# epoch:347  d_loss:0.2260  g_loss:3.1199
# epoch:348  d_loss:0.2937  g_loss:3.3270
# epoch:349  d_loss:0.3819  g_loss:3.3189
# epoch:350  d_loss:0.2301  g_loss:3.8425
# epoch:351  d_loss:0.2530  g_loss:2.6062
# epoch:352  d_loss:0.2225  g_loss:2.6403
# epoch:353  d_loss:0.2028  g_loss:2.3518
# epoch:354  d_loss:0.2834  g_loss:2.8314
# epoch:355  d_loss:0.1863  g_loss:3.7117
# epoch:356  d_loss:0.2382  g_loss:3.3286
# epoch:357  d_loss:0.1879  g_loss:3.3764
# epoch:358  d_loss:0.2068  g_loss:2.9711
# epoch:359  d_loss:0.1424  g_loss:3.1597
# epoch:360  d_loss:0.3728  g_loss:2.3396
# epoch:361  d_loss:0.2374  g_loss:3.4043
# epoch:362  d_loss:0.2561  g_loss:4.0793
# epoch:363  d_loss:0.2745  g_loss:3.9385
# epoch:364  d_loss:0.2093  g_loss:2.8308
# epoch:365  d_loss:0.2884  g_loss:3.0721
# epoch:366  d_loss:0.3071  g_loss:3.3069
# epoch:367  d_loss:0.4139  g_loss:3.6492
# epoch:368  d_loss:0.3696  g_loss:2.9798
# epoch:369  d_loss:0.4614  g_loss:2.7553
# epoch:370  d_loss:0.4966  g_loss:2.7894
# epoch:371  d_loss:0.3250  g_loss:2.5819
# epoch:372  d_loss:0.3819  g_loss:2.4879
# epoch:373  d_loss:0.2528  g_loss:3.2077
# epoch:374  d_loss:0.4580  g_loss:2.3386
# epoch:375  d_loss:0.6152  g_loss:2.2518
# epoch:376  d_loss:0.5223  g_loss:2.0394
# epoch:377  d_loss:0.3519  g_loss:2.0944
# epoch:378  d_loss:0.4017  g_loss:2.6204
# epoch:379  d_loss:0.4659  g_loss:2.4764
# epoch:380  d_loss:0.4789  g_loss:2.1534
# epoch:381  d_loss:0.4064  g_loss:2.1065
# epoch:382  d_loss:0.3822  g_loss:1.7902
# epoch:383  d_loss:0.4891  g_loss:1.8165
# epoch:384  d_loss:0.4033  g_loss:2.0290
# epoch:385  d_loss:0.5207  g_loss:2.1484
# epoch:386  d_loss:0.3523  g_loss:2.2761
# epoch:387  d_loss:0.3142  g_loss:2.0539
# epoch:388  d_loss:0.5455  g_loss:1.8048
# epoch:389  d_loss:0.3082  g_loss:2.0237
# epoch:390  d_loss:0.3378  g_loss:2.0883
# epoch:391  d_loss:0.2929  g_loss:2.2393
# epoch:392  d_loss:0.3018  g_loss:2.6976
# epoch:393  d_loss:0.2699  g_loss:2.7015
# epoch:394  d_loss:0.4179  g_loss:2.3117
# epoch:395  d_loss:0.3114  g_loss:2.0995
# epoch:396  d_loss:0.2366  g_loss:2.0886
# epoch:397  d_loss:0.3293  g_loss:2.2991
# epoch:398  d_loss:0.3377  g_loss:2.3364
# epoch:399  d_loss:0.3321  g_loss:2.7149
# epoch:400  d_loss:0.2911  g_loss:2.5003
# epoch:401  d_loss:0.3513  g_loss:2.8725
# epoch:402  d_loss:0.3855  g_loss:2.1972
# epoch:403  d_loss:0.3016  g_loss:2.4199
# epoch:404  d_loss:0.3659  g_loss:2.0000
# epoch:405  d_loss:0.3613  g_loss:1.8812
# epoch:406  d_loss:0.3564  g_loss:2.1666
# epoch:407  d_loss:0.2820  g_loss:2.5659
# epoch:408  d_loss:0.2628  g_loss:2.6161
# epoch:409  d_loss:0.5388  g_loss:1.9615
# epoch:410  d_loss:0.2634  g_loss:1.8090
# epoch:411  d_loss:0.3236  g_loss:1.9724
# epoch:412  d_loss:0.4609  g_loss:1.9592
# epoch:413  d_loss:0.3094  g_loss:2.1663
# epoch:414  d_loss:0.4369  g_loss:2.7027
# epoch:415  d_loss:0.3646  g_loss:2.4315
# epoch:416  d_loss:0.2970  g_loss:2.0582
# epoch:417  d_loss:0.3121  g_loss:2.2324
# epoch:418  d_loss:0.2865  g_loss:2.4167
# epoch:419  d_loss:0.3387  g_loss:2.2402
# epoch:420  d_loss:0.2649  g_loss:2.6941
# epoch:421  d_loss:0.3451  g_loss:2.3860
# epoch:422  d_loss:0.4361  g_loss:1.8982
# epoch:423  d_loss:0.4770  g_loss:2.0266
# epoch:424  d_loss:0.3572  g_loss:2.4450
# epoch:425  d_loss:0.2607  g_loss:2.6277
# epoch:426  d_loss:0.2635  g_loss:2.5096
# epoch:427  d_loss:0.3262  g_loss:3.1500
# epoch:428  d_loss:0.3329  g_loss:2.6067
# epoch:429  d_loss:0.4028  g_loss:2.3981
# epoch:430  d_loss:0.3529  g_loss:2.0198
# epoch:431  d_loss:0.2806  g_loss:2.4584
# epoch:432  d_loss:0.3401  g_loss:2.6636
# epoch:433  d_loss:0.3170  g_loss:2.6908
# epoch:434  d_loss:0.3409  g_loss:2.5223
# epoch:435  d_loss:0.2676  g_loss:2.4961
# epoch:436  d_loss:0.2997  g_loss:2.2252
# epoch:437  d_loss:0.3534  g_loss:2.0196
# epoch:438  d_loss:0.3597  g_loss:2.2293
# epoch:439  d_loss:0.2242  g_loss:3.2273
# epoch:440  d_loss:0.4053  g_loss:2.8957
# epoch:441  d_loss:0.3997  g_loss:2.8223
# epoch:442  d_loss:0.3119  g_loss:2.0967
# epoch:443  d_loss:0.2107  g_loss:2.3730
# epoch:444  d_loss:0.2474  g_loss:2.2479
# epoch:445  d_loss:0.2381  g_loss:2.2395
# epoch:446  d_loss:0.2143  g_loss:2.1553
# epoch:447  d_loss:0.2029  g_loss:2.6486
# epoch:448  d_loss:0.2937  g_loss:3.0014
# epoch:449  d_loss:0.3350  g_loss:2.6863
# epoch:450  d_loss:0.2705  g_loss:2.8158
# epoch:451  d_loss:0.1524  g_loss:3.5558
# epoch:452  d_loss:0.2753  g_loss:2.8827
# epoch:453  d_loss:0.2437  g_loss:2.6181
# epoch:454  d_loss:0.3154  g_loss:2.3534
# epoch:455  d_loss:0.2776  g_loss:2.9374
# epoch:456  d_loss:0.3064  g_loss:2.7965
# epoch:457  d_loss:0.2082  g_loss:2.2814
# epoch:458  d_loss:0.2469  g_loss:2.6651
# epoch:459  d_loss:0.2527  g_loss:2.7562
# epoch:460  d_loss:0.3007  g_loss:2.8663
# epoch:461  d_loss:0.2499  g_loss:2.8298
# epoch:462  d_loss:0.2667  g_loss:2.5127
# epoch:463  d_loss:0.2620  g_loss:2.5268
# epoch:464  d_loss:0.2001  g_loss:2.5083
# epoch:465  d_loss:0.2533  g_loss:2.1316
# epoch:466  d_loss:0.3311  g_loss:2.2103
# epoch:467  d_loss:0.3293  g_loss:2.3602
# epoch:468  d_loss:0.2114  g_loss:2.1089
# epoch:469  d_loss:0.3074  g_loss:2.4652
# epoch:470  d_loss:0.3718  g_loss:2.3545
# epoch:471  d_loss:0.3688  g_loss:2.7720
# epoch:472  d_loss:0.3169  g_loss:2.4250
# epoch:473  d_loss:0.3688  g_loss:1.7394
# epoch:474  d_loss:0.3282  g_loss:2.0623
# epoch:475  d_loss:0.2824  g_loss:1.9576
# epoch:476  d_loss:0.2762  g_loss:2.6560
# epoch:477  d_loss:0.3101  g_loss:3.1587
# epoch:478  d_loss:0.3097  g_loss:3.0207
# epoch:479  d_loss:0.3219  g_loss:2.4487
# epoch:480  d_loss:0.3065  g_loss:2.0987
# epoch:481  d_loss:0.3261  g_loss:2.0798
# epoch:482  d_loss:0.4276  g_loss:2.4529
# epoch:483  d_loss:0.3872  g_loss:3.3418
# epoch:484  d_loss:0.2131  g_loss:4.1262
# epoch:485  d_loss:0.4849  g_loss:2.3174
# epoch:486  d_loss:0.4943  g_loss:1.4656
# epoch:487  d_loss:0.4113  g_loss:2.1103
# epoch:488  d_loss:0.4033  g_loss:2.5649
# epoch:489  d_loss:0.2481  g_loss:3.3842
# epoch:490  d_loss:0.3562  g_loss:3.2186
# epoch:491  d_loss:0.2470  g_loss:2.9764
# epoch:492  d_loss:0.3140  g_loss:2.2456
# epoch:493  d_loss:0.2428  g_loss:2.4006
# epoch:494  d_loss:0.2321  g_loss:2.6545
# epoch:495  d_loss:0.1642  g_loss:4.2359
# epoch:496  d_loss:0.2486  g_loss:3.6072
# epoch:497  d_loss:0.2211  g_loss:4.0284
# epoch:498  d_loss:0.2166  g_loss:3.0207
# epoch:499  d_loss:0.2266  g_loss:2.6688
# epoch:500  d_loss:0.1663  g_loss:2.5610
# epoch:501  d_loss:0.2626  g_loss:2.8692
# epoch:502  d_loss:0.2335  g_loss:3.1067
# epoch:503  d_loss:0.1714  g_loss:3.3515
# epoch:504  d_loss:0.2001  g_loss:3.4161
# epoch:505  d_loss:0.2225  g_loss:3.2310
# epoch:506  d_loss:0.1629  g_loss:2.7620
# epoch:507  d_loss:0.3227  g_loss:2.7988
# epoch:508  d_loss:0.2677  g_loss:2.7503
# epoch:509  d_loss:0.2146  g_loss:3.4108
# epoch:510  d_loss:0.2345  g_loss:3.4265
# epoch:511  d_loss:0.1683  g_loss:3.4779
# epoch:512  d_loss:0.2422  g_loss:3.3142
# epoch:513  d_loss:0.1708  g_loss:3.1827
# epoch:514  d_loss:0.1553  g_loss:3.5197
# epoch:515  d_loss:0.1763  g_loss:3.3644
# epoch:516  d_loss:0.2010  g_loss:2.7299
# epoch:517  d_loss:0.1698  g_loss:3.0115
# epoch:518  d_loss:0.2100  g_loss:4.1195
# epoch:519  d_loss:0.2237  g_loss:2.8073
# epoch:520  d_loss:0.1564  g_loss:3.1637
# epoch:521  d_loss:0.1992  g_loss:3.1527
# epoch:522  d_loss:0.2574  g_loss:2.9308
# epoch:523  d_loss:0.2139  g_loss:2.7642
# epoch:524  d_loss:0.2796  g_loss:2.8359
# epoch:525  d_loss:0.2064  g_loss:2.6005
# epoch:526  d_loss:0.2901  g_loss:2.3899
# epoch:527  d_loss:0.2851  g_loss:3.0267
# epoch:528  d_loss:0.2813  g_loss:2.5104
# epoch:529  d_loss:0.3437  g_loss:2.2343
# epoch:530  d_loss:0.3855  g_loss:2.0843
# epoch:531  d_loss:0.2509  g_loss:3.2136
# epoch:532  d_loss:0.3359  g_loss:2.9284
# epoch:533  d_loss:0.3491  g_loss:2.3933
# epoch:534  d_loss:0.2976  g_loss:2.2420
# epoch:535  d_loss:0.2072  g_loss:2.6296
# epoch:536  d_loss:0.2067  g_loss:2.7187
# epoch:537  d_loss:0.2374  g_loss:3.1498
# epoch:538  d_loss:0.2143  g_loss:3.4875
# epoch:539  d_loss:0.2083  g_loss:2.7036
# epoch:540  d_loss:0.2183  g_loss:2.4507
# epoch:541  d_loss:0.2110  g_loss:2.6525
# epoch:542  d_loss:0.2098  g_loss:2.5973
# epoch:543  d_loss:0.2473  g_loss:2.7987
# epoch:544  d_loss:0.2143  g_loss:2.3868
# epoch:545  d_loss:0.3109  g_loss:2.7714
# epoch:546  d_loss:0.2378  g_loss:2.6389
# epoch:547  d_loss:0.1830  g_loss:3.1632
# epoch:548  d_loss:0.3149  g_loss:2.5479
# epoch:549  d_loss:0.2144  g_loss:2.9537
# epoch:550  d_loss:0.2709  g_loss:2.9356
# epoch:551  d_loss:0.1684  g_loss:3.0927
# epoch:552  d_loss:0.3638  g_loss:2.5357
# epoch:553  d_loss:0.3741  g_loss:2.5384
# epoch:554  d_loss:0.3704  g_loss:2.3060
# epoch:555  d_loss:0.2413  g_loss:2.6247
# epoch:556  d_loss:0.1920  g_loss:3.0494
# epoch:557  d_loss:0.2159  g_loss:2.5254
# epoch:558  d_loss:0.2781  g_loss:1.9171
# epoch:559  d_loss:0.2618  g_loss:2.2713
# epoch:560  d_loss:0.3194  g_loss:2.2341
# epoch:561  d_loss:0.1904  g_loss:2.4286
# epoch:562  d_loss:0.1720  g_loss:2.4570
# epoch:563  d_loss:0.2851  g_loss:2.5858
# epoch:564  d_loss:0.2573  g_loss:2.0615
# epoch:565  d_loss:0.1821  g_loss:1.8339
# epoch:566  d_loss:0.1527  g_loss:2.3792
# epoch:567  d_loss:0.1429  g_loss:3.0511
# epoch:568  d_loss:0.2036  g_loss:2.9991
# epoch:569  d_loss:0.1977  g_loss:2.8275
# epoch:570  d_loss:0.1864  g_loss:2.7762
# epoch:571  d_loss:0.2602  g_loss:1.7287
# epoch:572  d_loss:0.1883  g_loss:2.1131
# epoch:573  d_loss:0.2554  g_loss:2.1625
# epoch:574  d_loss:0.0981  g_loss:3.1721
# epoch:575  d_loss:0.0989  g_loss:3.0886
# epoch:576  d_loss:0.1577  g_loss:3.0230
# epoch:577  d_loss:0.1535  g_loss:2.6586
# epoch:578  d_loss:0.1804  g_loss:2.5941
# epoch:579  d_loss:0.1649  g_loss:1.8910
# epoch:580  d_loss:0.1903  g_loss:2.1724
# epoch:581  d_loss:0.1523  g_loss:3.2193
# epoch:582  d_loss:0.1256  g_loss:3.6924
# epoch:583  d_loss:0.1611  g_loss:3.3677
# epoch:584  d_loss:0.2134  g_loss:3.0903
# epoch:585  d_loss:0.1220  g_loss:3.0328
# epoch:586  d_loss:0.1444  g_loss:2.6067
# epoch:587  d_loss:0.3228  g_loss:2.4480
# epoch:588  d_loss:0.1543  g_loss:3.4302
# epoch:589  d_loss:0.1739  g_loss:3.1575
# epoch:590  d_loss:0.3262  g_loss:2.4706
# epoch:591  d_loss:0.1995  g_loss:2.8670
# epoch:592  d_loss:0.1748  g_loss:3.0578
# epoch:593  d_loss:0.1825  g_loss:2.5439
# epoch:594  d_loss:0.2617  g_loss:2.0767
# epoch:595  d_loss:0.3704  g_loss:2.1105
# epoch:596  d_loss:0.2727  g_loss:3.0361
# epoch:597  d_loss:0.3258  g_loss:2.2139
# epoch:598  d_loss:0.3059  g_loss:1.6618
# epoch:599  d_loss:0.3082  g_loss:1.6520
# epoch:600  d_loss:0.3005  g_loss:2.5453
# epoch:601  d_loss:0.3082  g_loss:3.0482
# epoch:602  d_loss:0.4245  g_loss:1.6946
# epoch:603  d_loss:0.4826  g_loss:1.4752
# epoch:604  d_loss:0.4585  g_loss:1.3313
# epoch:605  d_loss:0.4806  g_loss:2.0780
# epoch:606  d_loss:0.5540  g_loss:1.5146
# epoch:607  d_loss:0.6302  g_loss:1.6534
# epoch:608  d_loss:0.5101  g_loss:1.3230
# epoch:609  d_loss:0.4723  g_loss:1.3930
# epoch:610  d_loss:0.4896  g_loss:1.9384
# epoch:611  d_loss:0.5227  g_loss:2.4754
# epoch:612  d_loss:0.3458  g_loss:2.2580
# epoch:613  d_loss:0.5419  g_loss:2.0396
# epoch:614  d_loss:0.3825  g_loss:2.0997
# epoch:615  d_loss:0.2786  g_loss:2.4557
# epoch:616  d_loss:0.3337  g_loss:2.3274
# epoch:617  d_loss:0.2989  g_loss:3.2650
# epoch:618  d_loss:0.3085  g_loss:2.3748
# epoch:619  d_loss:0.3190  g_loss:2.9903
# epoch:620  d_loss:0.3500  g_loss:3.6919
# epoch:621  d_loss:0.4969  g_loss:2.7441
# epoch:622  d_loss:0.5880  g_loss:1.9351
# epoch:623  d_loss:0.6416  g_loss:2.7499
# epoch:624  d_loss:0.7252  g_loss:2.9051
# epoch:625  d_loss:1.6393  g_loss:1.5146
# epoch:626  d_loss:0.7618  g_loss:1.2482
# epoch:627  d_loss:0.4349  g_loss:1.8687
# epoch:628  d_loss:0.2646  g_loss:2.9867
# epoch:629  d_loss:0.3607  g_loss:2.6914
# epoch:630  d_loss:0.3691  g_loss:2.4895
# epoch:631  d_loss:0.3018  g_loss:2.4485
# epoch:632  d_loss:0.5081  g_loss:1.9676
# epoch:633  d_loss:0.5059  g_loss:1.8277
# epoch:634  d_loss:0.3069  g_loss:2.3557
# epoch:635  d_loss:0.2715  g_loss:2.7268
# epoch:636  d_loss:0.4281  g_loss:2.5078
# epoch:637  d_loss:0.2291  g_loss:2.8459
# epoch:638  d_loss:0.3632  g_loss:2.6668
# epoch:639  d_loss:0.1762  g_loss:2.5992
# epoch:640  d_loss:0.5275  g_loss:2.1925
# epoch:641  d_loss:0.7574  g_loss:2.2439
# epoch:642  d_loss:0.4916  g_loss:2.3407
# epoch:643  d_loss:0.3626  g_loss:3.2828
# epoch:644  d_loss:0.3825  g_loss:3.5038
# epoch:645  d_loss:0.5785  g_loss:2.9245
# epoch:646  d_loss:0.4484  g_loss:2.4693
# epoch:647  d_loss:0.4618  g_loss:1.4070
# epoch:648  d_loss:0.4405  g_loss:1.3375
# epoch:649  d_loss:0.5961  g_loss:0.9445
# epoch:650  d_loss:0.6773  g_loss:1.0712
# epoch:651  d_loss:0.5894  g_loss:1.8010
# epoch:652  d_loss:0.4223  g_loss:1.8924
# epoch:653  d_loss:0.4832  g_loss:1.9497
# epoch:654  d_loss:0.5143  g_loss:1.6804
# epoch:655  d_loss:0.5150  g_loss:1.6401
# epoch:656  d_loss:0.6648  g_loss:1.3460
# epoch:657  d_loss:0.4869  g_loss:1.6470
# epoch:658  d_loss:0.4751  g_loss:2.2872
# epoch:659  d_loss:0.2780  g_loss:2.8806
# epoch:660  d_loss:0.3186  g_loss:3.4385
# epoch:661  d_loss:0.4813  g_loss:3.0199
# epoch:662  d_loss:0.7672  g_loss:2.8668
# epoch:663  d_loss:1.2028  g_loss:2.7028
# epoch:664  d_loss:0.7448  g_loss:3.3095
# epoch:665  d_loss:0.7983  g_loss:3.0418
# epoch:666  d_loss:0.9439  g_loss:2.2527
# epoch:667  d_loss:0.5049  g_loss:1.7839
# epoch:668  d_loss:0.4712  g_loss:2.5396
# epoch:669  d_loss:0.5424  g_loss:2.6194
# epoch:670  d_loss:0.3227  g_loss:3.4216
# epoch:671  d_loss:0.4251  g_loss:3.5542
# epoch:672  d_loss:0.2834  g_loss:3.0589
# epoch:673  d_loss:0.3763  g_loss:2.8166
# epoch:674  d_loss:0.3094  g_loss:3.0561
# epoch:675  d_loss:0.4894  g_loss:2.2688
# epoch:676  d_loss:0.5868  g_loss:2.0762
# epoch:677  d_loss:0.3888  g_loss:1.9620
# epoch:678  d_loss:0.3580  g_loss:1.9885
# epoch:679  d_loss:0.4186  g_loss:1.8172
# epoch:680  d_loss:0.6892  g_loss:1.4811
# epoch:681  d_loss:0.6316  g_loss:1.4653
# epoch:682  d_loss:0.5027  g_loss:1.2930
# epoch:683  d_loss:0.5901  g_loss:1.4154
# epoch:684  d_loss:0.6168  g_loss:1.0396
# epoch:685  d_loss:0.6218  g_loss:1.1604
# epoch:686  d_loss:0.6935  g_loss:1.2322
# epoch:687  d_loss:0.6559  g_loss:1.4237
# epoch:688  d_loss:0.7825  g_loss:1.5062
# epoch:689  d_loss:0.7097  g_loss:1.8491
# epoch:690  d_loss:0.7000  g_loss:1.7169
# epoch:691  d_loss:0.6102  g_loss:1.7655
# epoch:692  d_loss:0.7435  g_loss:1.9602
# epoch:693  d_loss:0.5457  g_loss:1.9418
# epoch:694  d_loss:0.6831  g_loss:2.0743
# epoch:695  d_loss:0.4386  g_loss:2.2812
# epoch:696  d_loss:0.5769  g_loss:1.5635
# epoch:697  d_loss:0.6448  g_loss:1.3776
# epoch:698  d_loss:0.8084  g_loss:1.2048
# epoch:699  d_loss:0.5707  g_loss:1.5175
# epoch:700  d_loss:0.5296  g_loss:1.6178
# epoch:701  d_loss:0.5471  g_loss:1.8474
# epoch:702  d_loss:0.4869  g_loss:1.9944
# epoch:703  d_loss:0.3151  g_loss:1.9813
# epoch:704  d_loss:0.2445  g_loss:2.1162
# epoch:705  d_loss:0.3391  g_loss:2.3529
# epoch:706  d_loss:0.3288  g_loss:2.0946
# epoch:707  d_loss:0.2454  g_loss:2.4310
# epoch:708  d_loss:0.2680  g_loss:2.9403
# epoch:709  d_loss:0.2481  g_loss:2.6725
# epoch:710  d_loss:0.1769  g_loss:2.7949
# epoch:711  d_loss:0.2020  g_loss:3.1223
# epoch:712  d_loss:0.1966  g_loss:2.5595
# epoch:713  d_loss:0.2130  g_loss:2.6221
# epoch:714  d_loss:0.1725  g_loss:1.9896
# epoch:715  d_loss:0.2635  g_loss:2.1246
# epoch:716  d_loss:0.2719  g_loss:1.9383
# epoch:717  d_loss:0.5005  g_loss:1.4995
# epoch:718  d_loss:0.4196  g_loss:1.4795
# epoch:719  d_loss:0.4576  g_loss:1.6991
# epoch:720  d_loss:0.5054  g_loss:1.6942
# epoch:721  d_loss:0.6468  g_loss:1.4441
# epoch:722  d_loss:0.8359  g_loss:1.1295
# epoch:723  d_loss:0.6419  g_loss:1.5227
# epoch:724  d_loss:0.6079  g_loss:1.2943
# epoch:725  d_loss:0.4845  g_loss:1.5328
# epoch:726  d_loss:0.3802  g_loss:1.8420
# epoch:727  d_loss:0.4594  g_loss:1.7424
# epoch:728  d_loss:0.3185  g_loss:1.8593
# epoch:729  d_loss:0.2933  g_loss:1.9905
# epoch:730  d_loss:0.3201  g_loss:1.8735
# epoch:731  d_loss:0.3298  g_loss:2.0129
# epoch:732  d_loss:0.2326  g_loss:2.3333
# epoch:733  d_loss:0.3301  g_loss:2.2236
# epoch:734  d_loss:0.4180  g_loss:1.9759
# epoch:735  d_loss:0.3034  g_loss:1.6455
# epoch:736  d_loss:0.4380  g_loss:1.8820
# epoch:737  d_loss:0.4215  g_loss:2.0527
# epoch:738  d_loss:0.5122  g_loss:2.1273
# epoch:739  d_loss:0.4994  g_loss:1.9786
# epoch:740  d_loss:0.4458  g_loss:1.8286
# epoch:741  d_loss:0.4935  g_loss:1.3445
# epoch:742  d_loss:0.6427  g_loss:1.5227
# epoch:743  d_loss:0.6021  g_loss:1.3962
# epoch:744  d_loss:0.5758  g_loss:1.5966
# epoch:745  d_loss:0.6854  g_loss:1.8048
# epoch:746  d_loss:0.8343  g_loss:1.9600
# epoch:747  d_loss:0.5927  g_loss:1.5152
# epoch:748  d_loss:0.5679  g_loss:1.5600
# epoch:749  d_loss:0.6606  g_loss:1.7585
# epoch:750  d_loss:0.6245  g_loss:1.7157
# epoch:751  d_loss:0.5357  g_loss:1.7610
# epoch:752  d_loss:0.3388  g_loss:2.0278
# epoch:753  d_loss:0.4064  g_loss:1.7512
# epoch:754  d_loss:0.3730  g_loss:1.6910
# epoch:755  d_loss:0.3078  g_loss:1.8911
# epoch:756  d_loss:0.3842  g_loss:1.7950
# epoch:757  d_loss:0.4248  g_loss:2.3108
# epoch:758  d_loss:0.4100  g_loss:1.6885
# epoch:759  d_loss:0.2692  g_loss:2.0952
# epoch:760  d_loss:0.2814  g_loss:2.2279
# epoch:761  d_loss:0.3496  g_loss:2.2903
# epoch:762  d_loss:0.3148  g_loss:2.4492
# epoch:763  d_loss:0.3272  g_loss:2.4071
# epoch:764  d_loss:0.2867  g_loss:1.8793
# epoch:765  d_loss:0.3437  g_loss:2.2957
# epoch:766  d_loss:0.2902  g_loss:2.3869
# epoch:767  d_loss:0.2940  g_loss:2.8470
# epoch:768  d_loss:0.3215  g_loss:2.7927
# epoch:769  d_loss:0.2095  g_loss:3.3364
# epoch:770  d_loss:0.1680  g_loss:3.5383
# epoch:771  d_loss:0.2378  g_loss:3.6455
# epoch:772  d_loss:0.2775  g_loss:3.2202
# epoch:773  d_loss:0.3287  g_loss:3.0953
# epoch:774  d_loss:0.3814  g_loss:2.8060
# epoch:775  d_loss:0.2791  g_loss:2.6938
# epoch:776  d_loss:0.3667  g_loss:3.1167
# epoch:777  d_loss:0.2749  g_loss:3.1685
# epoch:778  d_loss:0.4029  g_loss:2.6222
# epoch:779  d_loss:0.3288  g_loss:2.5262
# epoch:780  d_loss:0.6065  g_loss:2.3131
# epoch:781  d_loss:0.3952  g_loss:2.4943
# epoch:782  d_loss:0.4332  g_loss:2.4174
# epoch:783  d_loss:0.4367  g_loss:2.6701
# epoch:784  d_loss:0.5521  g_loss:2.0810
# epoch:785  d_loss:0.4967  g_loss:1.8928
# epoch:786  d_loss:0.5861  g_loss:2.1380
# epoch:787  d_loss:0.4698  g_loss:2.4173
# epoch:788  d_loss:0.4081  g_loss:2.6155
# epoch:789  d_loss:0.3838  g_loss:2.7907
# epoch:790  d_loss:0.5169  g_loss:2.0547
# epoch:791  d_loss:0.5654  g_loss:1.5898
# epoch:792  d_loss:0.4267  g_loss:1.9509
# epoch:793  d_loss:0.4279  g_loss:1.7319
# epoch:794  d_loss:0.3067  g_loss:2.0274
# epoch:795  d_loss:0.6024  g_loss:2.0193
# epoch:796  d_loss:0.3365  g_loss:2.0912
# epoch:797  d_loss:0.3087  g_loss:2.2477
# epoch:798  d_loss:0.4897  g_loss:2.2826
# epoch:799  d_loss:0.3102  g_loss:2.6024
# epoch:800  d_loss:0.4436  g_loss:2.1191
# epoch:801  d_loss:0.3659  g_loss:2.1654
# epoch:802  d_loss:0.3095  g_loss:2.1876
# epoch:803  d_loss:0.3864  g_loss:2.7779
# epoch:804  d_loss:0.3444  g_loss:3.0358
# epoch:805  d_loss:0.3056  g_loss:2.7727
# epoch:806  d_loss:0.3632  g_loss:2.6156
# epoch:807  d_loss:0.2660  g_loss:2.3249
# epoch:808  d_loss:0.3878  g_loss:2.6612
# epoch:809  d_loss:0.3012  g_loss:2.6896
# epoch:810  d_loss:0.4109  g_loss:2.9117
# epoch:811  d_loss:0.5364  g_loss:2.3654
# epoch:812  d_loss:0.5427  g_loss:2.3091
# epoch:813  d_loss:0.4082  g_loss:2.7058
# epoch:814  d_loss:0.5365  g_loss:1.7404
# epoch:815  d_loss:0.7301  g_loss:1.4800
# epoch:816  d_loss:0.6176  g_loss:1.9227
# epoch:817  d_loss:0.4080  g_loss:1.9265
# epoch:818  d_loss:0.6149  g_loss:1.9718
# epoch:819  d_loss:0.4271  g_loss:2.0510
# epoch:820  d_loss:0.6387  g_loss:2.2254
# epoch:821  d_loss:0.6328  g_loss:1.9909
# epoch:822  d_loss:0.6264  g_loss:1.3870
# epoch:823  d_loss:0.6214  g_loss:1.8735
# epoch:824  d_loss:0.4882  g_loss:2.1812
# epoch:825  d_loss:0.5750  g_loss:1.8449
# epoch:826  d_loss:0.4075  g_loss:1.9281
# epoch:827  d_loss:0.4026  g_loss:1.9358
# epoch:828  d_loss:0.4287  g_loss:1.8239
# epoch:829  d_loss:0.4226  g_loss:2.1222
# epoch:830  d_loss:0.2233  g_loss:2.3076
# epoch:831  d_loss:0.3584  g_loss:2.3473
# epoch:832  d_loss:0.3025  g_loss:2.2232
# epoch:833  d_loss:0.2089  g_loss:1.9342
# epoch:834  d_loss:0.3208  g_loss:2.3111
# epoch:835  d_loss:0.2348  g_loss:2.4575
# epoch:836  d_loss:0.3085  g_loss:2.3723
# epoch:837  d_loss:0.1801  g_loss:2.8651
# epoch:838  d_loss:0.2357  g_loss:3.1884
# epoch:839  d_loss:0.2752  g_loss:2.8183
# epoch:840  d_loss:0.2787  g_loss:2.6750
# epoch:841  d_loss:0.2783  g_loss:2.7963
# epoch:842  d_loss:0.2739  g_loss:2.7160
# epoch:843  d_loss:0.1865  g_loss:3.2237
# epoch:844  d_loss:0.3257  g_loss:2.7699
# epoch:845  d_loss:0.3646  g_loss:1.9324
# epoch:846  d_loss:0.2650  g_loss:2.1499
# epoch:847  d_loss:0.2969  g_loss:2.4260
# epoch:848  d_loss:0.1925  g_loss:2.8621
# epoch:849  d_loss:0.2271  g_loss:2.9938
# epoch:850  d_loss:0.3586  g_loss:2.9563
# epoch:851  d_loss:0.3532  g_loss:3.0202
# epoch:852  d_loss:0.3986  g_loss:2.3159
# epoch:853  d_loss:0.4905  g_loss:1.7553
# epoch:854  d_loss:0.3352  g_loss:1.9280
# epoch:855  d_loss:0.2908  g_loss:2.5109
# epoch:856  d_loss:0.3065  g_loss:2.2290
# epoch:857  d_loss:0.4177  g_loss:2.1261
# epoch:858  d_loss:0.4006  g_loss:1.9578
# epoch:859  d_loss:0.4893  g_loss:2.1488
# epoch:860  d_loss:0.5246  g_loss:1.9459
# epoch:861  d_loss:0.5218  g_loss:1.8983
# epoch:862  d_loss:0.4603  g_loss:1.7221
# epoch:863  d_loss:0.3814  g_loss:2.0559
# epoch:864  d_loss:0.3777  g_loss:2.3650
# epoch:865  d_loss:0.3899  g_loss:2.0740
# epoch:866  d_loss:0.4397  g_loss:2.1238
# epoch:867  d_loss:0.4670  g_loss:2.4155
# epoch:868  d_loss:0.4461  g_loss:2.4957
# epoch:869  d_loss:0.2741  g_loss:2.0379
# epoch:870  d_loss:0.5120  g_loss:2.2304
# epoch:871  d_loss:0.3078  g_loss:2.3261
# epoch:872  d_loss:0.3903  g_loss:2.2301
# epoch:873  d_loss:0.3602  g_loss:2.3362
# epoch:874  d_loss:0.2359  g_loss:2.3897
# epoch:875  d_loss:0.3201  g_loss:2.5213
# epoch:876  d_loss:0.2449  g_loss:2.2685
# epoch:877  d_loss:0.2314  g_loss:2.9266
# epoch:878  d_loss:0.3121  g_loss:2.5144
# epoch:879  d_loss:0.3831  g_loss:2.3174
# epoch:880  d_loss:0.2447  g_loss:2.6021
# epoch:881  d_loss:0.2397  g_loss:1.6767
# epoch:882  d_loss:0.2518  g_loss:2.5072
# epoch:883  d_loss:0.2971  g_loss:2.3008
# epoch:884  d_loss:0.3606  g_loss:2.7957
# epoch:885  d_loss:0.3141  g_loss:2.3028
# epoch:886  d_loss:0.3029  g_loss:2.5671
# epoch:887  d_loss:0.2888  g_loss:2.6742
# epoch:888  d_loss:0.2886  g_loss:2.6295
# epoch:889  d_loss:0.3703  g_loss:2.3484
# epoch:890  d_loss:0.2499  g_loss:2.1961
# epoch:891  d_loss:0.4456  g_loss:2.0325
# epoch:892  d_loss:0.5085  g_loss:2.5227
# epoch:893  d_loss:0.2303  g_loss:3.2679
# epoch:894  d_loss:0.4103  g_loss:2.9551
# epoch:895  d_loss:0.6569  g_loss:2.5009
# epoch:896  d_loss:0.4982  g_loss:1.8558
# epoch:897  d_loss:0.4969  g_loss:2.1486
# epoch:898  d_loss:0.3989  g_loss:2.1643
# epoch:899  d_loss:0.3958  g_loss:2.0604
# epoch:900  d_loss:0.4589  g_loss:2.4127
# epoch:901  d_loss:0.5691  g_loss:2.1164
# epoch:902  d_loss:0.5427  g_loss:1.5852
# epoch:903  d_loss:0.6770  g_loss:1.6684
# epoch:904  d_loss:0.4977  g_loss:1.3883
# epoch:905  d_loss:0.4367  g_loss:2.1960
# epoch:906  d_loss:0.5647  g_loss:1.7686
# epoch:907  d_loss:0.5223  g_loss:2.0749
# epoch:908  d_loss:0.6762  g_loss:1.5834
# epoch:909  d_loss:0.3920  g_loss:1.7652
# epoch:910  d_loss:0.4984  g_loss:1.6108
# epoch:911  d_loss:0.4636  g_loss:1.9801
# epoch:912  d_loss:0.3063  g_loss:2.3522
# epoch:913  d_loss:0.3846  g_loss:2.6360
# epoch:914  d_loss:0.4032  g_loss:2.2624
# epoch:915  d_loss:0.3674  g_loss:2.0432
# epoch:916  d_loss:0.3641  g_loss:2.0039
# epoch:917  d_loss:0.3191  g_loss:2.0469
# epoch:918  d_loss:0.2933  g_loss:2.3073
# epoch:919  d_loss:0.4375  g_loss:2.1756
# epoch:920  d_loss:0.3332  g_loss:2.7173
# epoch:921  d_loss:0.3697  g_loss:2.3607
# epoch:922  d_loss:0.2917  g_loss:2.6666
# epoch:923  d_loss:0.2711  g_loss:2.5084
# epoch:924  d_loss:0.2674  g_loss:2.3634
# epoch:925  d_loss:0.2960  g_loss:2.3498
# epoch:926  d_loss:0.2663  g_loss:2.2464
# epoch:927  d_loss:0.3028  g_loss:2.3329
# epoch:928  d_loss:0.1926  g_loss:2.5878
# epoch:929  d_loss:0.3010  g_loss:2.6903
# epoch:930  d_loss:0.3704  g_loss:2.3133
# epoch:931  d_loss:0.2810  g_loss:2.5052
# epoch:932  d_loss:0.2702  g_loss:2.8140
# epoch:933  d_loss:0.3093  g_loss:2.4260
# epoch:934  d_loss:0.2406  g_loss:2.4170
# epoch:935  d_loss:0.3602  g_loss:2.5589
# epoch:936  d_loss:0.3091  g_loss:2.2402
# epoch:937  d_loss:0.3584  g_loss:1.8796
# epoch:938  d_loss:0.4386  g_loss:2.0758
# epoch:939  d_loss:0.3030  g_loss:2.1013
# epoch:940  d_loss:0.3667  g_loss:2.5007
# epoch:941  d_loss:0.3221  g_loss:2.7194
# epoch:942  d_loss:0.3862  g_loss:2.9484
# epoch:943  d_loss:0.4834  g_loss:1.7009
# epoch:944  d_loss:0.3846  g_loss:1.4864
# epoch:945  d_loss:0.4011  g_loss:1.8120
# epoch:946  d_loss:0.3839  g_loss:1.9660
# epoch:947  d_loss:0.4320  g_loss:2.1049
# epoch:948  d_loss:0.3026  g_loss:2.3351
# epoch:949  d_loss:0.4494  g_loss:2.1798
# epoch:950  d_loss:0.3891  g_loss:1.9674
# epoch:951  d_loss:0.2829  g_loss:1.8969
# epoch:952  d_loss:0.3386  g_loss:1.7503
# epoch:953  d_loss:0.2810  g_loss:1.8126
# epoch:954  d_loss:0.3705  g_loss:1.8891
# epoch:955  d_loss:0.3031  g_loss:2.3587
# epoch:956  d_loss:0.3987  g_loss:2.2055
# epoch:957  d_loss:0.3327  g_loss:2.6086
# epoch:958  d_loss:0.4844  g_loss:2.5346
# epoch:959  d_loss:0.4573  g_loss:1.7091
# epoch:960  d_loss:0.3510  g_loss:1.7408
# epoch:961  d_loss:0.4965  g_loss:1.3733
# epoch:962  d_loss:0.3281  g_loss:1.9592
# epoch:963  d_loss:0.3293  g_loss:2.5712
# epoch:964  d_loss:0.2996  g_loss:3.1421
# epoch:965  d_loss:0.5598  g_loss:2.0797
# epoch:966  d_loss:0.5461  g_loss:2.0301
# epoch:967  d_loss:0.4488  g_loss:1.3242
# epoch:968  d_loss:0.4536  g_loss:1.5676
# epoch:969  d_loss:0.4327  g_loss:2.2709
# epoch:970  d_loss:0.6556  g_loss:1.7916
# epoch:971  d_loss:0.5298  g_loss:2.2297
# epoch:972  d_loss:0.4465  g_loss:2.3151
# epoch:973  d_loss:0.4517  g_loss:1.7934
# epoch:974  d_loss:0.4803  g_loss:1.7379
# epoch:975  d_loss:0.3904  g_loss:1.8657
# epoch:976  d_loss:0.2805  g_loss:2.2289
# epoch:977  d_loss:0.3539  g_loss:2.6729
# epoch:978  d_loss:0.4225  g_loss:2.4182
# epoch:979  d_loss:0.3177  g_loss:2.1858
# epoch:980  d_loss:0.4285  g_loss:1.8072
# epoch:981  d_loss:0.2919  g_loss:1.7311
# epoch:982  d_loss:0.3848  g_loss:2.2044
# epoch:983  d_loss:0.4064  g_loss:2.1824
# epoch:984  d_loss:0.4058  g_loss:2.1542
# epoch:985  d_loss:0.3279  g_loss:2.2387
# epoch:986  d_loss:0.3737  g_loss:2.1818
# epoch:987  d_loss:0.2876  g_loss:2.3471
# epoch:988  d_loss:0.4910  g_loss:2.1647
# epoch:989  d_loss:0.3087  g_loss:2.1560
# epoch:990  d_loss:0.3990  g_loss:2.3492
# epoch:991  d_loss:0.4042  g_loss:2.2906
# epoch:992  d_loss:0.2964  g_loss:3.0391
# epoch:993  d_loss:0.3812  g_loss:2.8271
# epoch:994  d_loss:0.4380  g_loss:2.8756
# epoch:995  d_loss:0.5212  g_loss:1.8189
# epoch:996  d_loss:0.3490  g_loss:1.5314
# epoch:997  d_loss:0.4743  g_loss:1.2663
# epoch:998  d_loss:0.3936  g_loss:1.6470
# epoch:999  d_loss:0.3457  g_loss:2.2828
# epoch:1000  d_loss:0.3342  g_loss:2.2933
# epoch:1001  d_loss:0.5472  g_loss:1.9789
# epoch:1002  d_loss:0.3856  g_loss:2.3678
# epoch:1003  d_loss:0.5882  g_loss:1.4621
# epoch:1004  d_loss:0.5091  g_loss:1.6418
# epoch:1005  d_loss:0.4783  g_loss:1.5767
# epoch:1006  d_loss:0.4549  g_loss:2.2561
# epoch:1007  d_loss:0.4598  g_loss:2.3338
# epoch:1008  d_loss:0.5038  g_loss:2.0723
# epoch:1009  d_loss:0.4655  g_loss:1.9620
# epoch:1010  d_loss:0.6202  g_loss:1.4779
# epoch:1011  d_loss:0.4890  g_loss:1.7210
# epoch:1012  d_loss:0.4593  g_loss:1.8573
# epoch:1013  d_loss:0.3499  g_loss:2.0766
# epoch:1014  d_loss:0.4062  g_loss:2.1387
# epoch:1015  d_loss:0.4741  g_loss:2.1591
# epoch:1016  d_loss:0.4605  g_loss:1.9630
# epoch:1017  d_loss:0.3260  g_loss:2.1685
# epoch:1018  d_loss:0.3425  g_loss:1.9880
# epoch:1019  d_loss:0.2226  g_loss:2.1234
# epoch:1020  d_loss:0.3387  g_loss:2.5104
# epoch:1021  d_loss:0.1901  g_loss:2.6980
# epoch:1022  d_loss:0.3621  g_loss:2.2130
# epoch:1023  d_loss:0.2547  g_loss:2.4471
# epoch:1024  d_loss:0.3735  g_loss:2.0263
# epoch:1025  d_loss:0.3478  g_loss:2.0143
# epoch:1026  d_loss:0.3042  g_loss:1.7561
# epoch:1027  d_loss:0.3797  g_loss:1.8318
# epoch:1028  d_loss:0.3185  g_loss:2.3747
# epoch:1029  d_loss:0.3135  g_loss:2.5825
# epoch:1030  d_loss:0.2673  g_loss:2.5022
# epoch:1031  d_loss:0.3396  g_loss:2.2258
# epoch:1032  d_loss:0.3409  g_loss:1.9707
# epoch:1033  d_loss:0.4154  g_loss:1.8004
# epoch:1034  d_loss:0.2262  g_loss:2.2912
# epoch:1035  d_loss:0.3911  g_loss:2.2254
# epoch:1036  d_loss:0.4543  g_loss:2.0655
# epoch:1037  d_loss:0.4088  g_loss:1.9026
# epoch:1038  d_loss:0.3301  g_loss:2.1074
# epoch:1039  d_loss:0.4099  g_loss:2.5735
# epoch:1040  d_loss:0.5329  g_loss:2.1482
# epoch:1041  d_loss:0.4707  g_loss:1.7068
# epoch:1042  d_loss:0.6781  g_loss:1.5326
# epoch:1043  d_loss:0.4430  g_loss:1.6719
# epoch:1044  d_loss:0.3083  g_loss:2.1219
# epoch:1045  d_loss:0.4838  g_loss:1.9549
# epoch:1046  d_loss:0.4327  g_loss:1.8821
# epoch:1047  d_loss:0.4722  g_loss:2.1429
# epoch:1048  d_loss:0.4511  g_loss:1.7219
# epoch:1049  d_loss:0.5932  g_loss:1.6694
# epoch:1050  d_loss:0.6022  g_loss:1.9488
# epoch:1051  d_loss:0.4431  g_loss:1.8847
# epoch:1052  d_loss:0.4932  g_loss:1.9138
# epoch:1053  d_loss:0.4852  g_loss:1.9344
# epoch:1054  d_loss:0.3116  g_loss:1.9989
# epoch:1055  d_loss:0.4648  g_loss:1.9445
# epoch:1056  d_loss:0.3574  g_loss:2.3795
# epoch:1057  d_loss:0.4441  g_loss:1.7700
# epoch:1058  d_loss:0.3851  g_loss:1.9566
# epoch:1059  d_loss:0.3879  g_loss:1.9747
# epoch:1060  d_loss:0.3664  g_loss:1.9526
# epoch:1061  d_loss:0.3379  g_loss:2.6060
# epoch:1062  d_loss:0.3090  g_loss:2.4528
# epoch:1063  d_loss:0.2864  g_loss:2.5569
# epoch:1064  d_loss:0.3862  g_loss:2.2578
# epoch:1065  d_loss:0.3035  g_loss:2.3294
# epoch:1066  d_loss:0.3304  g_loss:2.0147
# epoch:1067  d_loss:0.3365  g_loss:2.0962
# epoch:1068  d_loss:0.3212  g_loss:2.3188
# epoch:1069  d_loss:0.2160  g_loss:2.6316
# epoch:1070  d_loss:0.2827  g_loss:2.6759
# epoch:1071  d_loss:0.2136  g_loss:2.6204
# epoch:1072  d_loss:0.3093  g_loss:2.8207
# epoch:1073  d_loss:0.2338  g_loss:2.6650
# epoch:1074  d_loss:0.2904  g_loss:2.4236
# epoch:1075  d_loss:0.3039  g_loss:2.2191
# epoch:1076  d_loss:0.3407  g_loss:1.8635
# epoch:1077  d_loss:0.2416  g_loss:2.6696
# epoch:1078  d_loss:0.3604  g_loss:2.1679
# epoch:1079  d_loss:0.4109  g_loss:2.4261
# epoch:1080  d_loss:0.3531  g_loss:2.4177
# epoch:1081  d_loss:0.2807  g_loss:2.3907
# epoch:1082  d_loss:0.4921  g_loss:2.4444
# epoch:1083  d_loss:0.5061  g_loss:2.4228
# epoch:1084  d_loss:0.5067  g_loss:1.4954
# epoch:1085  d_loss:0.5203  g_loss:1.7093
# epoch:1086  d_loss:0.6232  g_loss:1.7292
# epoch:1087  d_loss:0.5466  g_loss:2.1247
# epoch:1088  d_loss:0.5867  g_loss:2.1600
# epoch:1089  d_loss:0.5261  g_loss:2.0140
# epoch:1090  d_loss:0.6591  g_loss:1.7643
# epoch:1091  d_loss:0.7100  g_loss:1.3731
# epoch:1092  d_loss:0.3411  g_loss:1.9229
# epoch:1093  d_loss:0.4404  g_loss:1.9403
# epoch:1094  d_loss:0.5093  g_loss:1.8711
# epoch:1095  d_loss:0.5101  g_loss:2.5899
# epoch:1096  d_loss:0.4598  g_loss:2.5270
# epoch:1097  d_loss:0.4109  g_loss:1.9371
# epoch:1098  d_loss:0.3572  g_loss:1.7203
# epoch:1099  d_loss:0.4768  g_loss:1.6079
# epoch:1100  d_loss:0.4616  g_loss:2.0664
# epoch:1101  d_loss:0.3324  g_loss:2.3595
# epoch:1102  d_loss:0.2760  g_loss:3.2644
# epoch:1103  d_loss:0.3620  g_loss:3.0490
# epoch:1104  d_loss:0.4266  g_loss:2.3162
# epoch:1105  d_loss:0.3942  g_loss:1.8742
# epoch:1106  d_loss:0.4215  g_loss:1.9863
# epoch:1107  d_loss:0.3372  g_loss:2.0343
# epoch:1108  d_loss:0.2588  g_loss:2.6041
# epoch:1109  d_loss:0.4409  g_loss:2.5606
# epoch:1110  d_loss:0.4888  g_loss:2.5984
# epoch:1111  d_loss:0.4260  g_loss:2.0230
# epoch:1112  d_loss:0.3827  g_loss:1.8136
# epoch:1113  d_loss:0.3975  g_loss:1.8171
# epoch:1114  d_loss:0.3086  g_loss:1.9460
# epoch:1115  d_loss:0.4271  g_loss:2.0305
# epoch:1116  d_loss:0.4451  g_loss:2.0378
# epoch:1117  d_loss:0.3020  g_loss:2.0681
# epoch:1118  d_loss:0.4278  g_loss:2.0333
# epoch:1119  d_loss:0.5286  g_loss:1.9082
# epoch:1120  d_loss:0.5764  g_loss:1.9004
# epoch:1121  d_loss:0.6309  g_loss:1.7486
# epoch:1122  d_loss:0.4719  g_loss:1.8973
# epoch:1123  d_loss:0.5398  g_loss:2.0218
# epoch:1124  d_loss:0.6258  g_loss:1.9527
# epoch:1125  d_loss:0.5099  g_loss:1.9141
# epoch:1126  d_loss:0.5369  g_loss:1.5225
# epoch:1127  d_loss:0.5295  g_loss:1.3558
# epoch:1128  d_loss:0.3308  g_loss:1.7372
# epoch:1129  d_loss:0.5044  g_loss:1.7015
# epoch:1130  d_loss:0.4332  g_loss:2.1112
# epoch:1131  d_loss:0.3857  g_loss:1.8173
# epoch:1132  d_loss:0.3346  g_loss:1.9970
# epoch:1133  d_loss:0.3856  g_loss:1.9079
# epoch:1134  d_loss:0.4286  g_loss:1.7723
# epoch:1135  d_loss:0.3838  g_loss:2.1969
# epoch:1136  d_loss:0.4458  g_loss:2.1693
# epoch:1137  d_loss:0.2788  g_loss:2.2205
# epoch:1138  d_loss:0.3345  g_loss:2.2444
# epoch:1139  d_loss:0.3088  g_loss:2.2220
# epoch:1140  d_loss:0.3040  g_loss:1.9499
# epoch:1141  d_loss:0.2908  g_loss:2.0698
# epoch:1142  d_loss:0.3583  g_loss:2.2179
# epoch:1143  d_loss:0.2296  g_loss:2.8394
# epoch:1144  d_loss:0.4512  g_loss:2.1707
# epoch:1145  d_loss:0.4499  g_loss:2.1906
# epoch:1146  d_loss:0.4365  g_loss:2.2335
# epoch:1147  d_loss:0.3987  g_loss:2.1481
# epoch:1148  d_loss:0.3596  g_loss:2.1479
# epoch:1149  d_loss:0.3461  g_loss:2.3738
# epoch:1150  d_loss:0.3035  g_loss:2.5172
# epoch:1151  d_loss:0.3666  g_loss:2.7243
# epoch:1152  d_loss:0.3860  g_loss:2.4289
# epoch:1153  d_loss:0.4699  g_loss:1.8148
# epoch:1154  d_loss:0.3601  g_loss:1.7838
# epoch:1155  d_loss:0.5093  g_loss:1.2368
# epoch:1156  d_loss:0.4858  g_loss:1.8634
# epoch:1157  d_loss:0.4679  g_loss:1.6909
# epoch:1158  d_loss:0.4098  g_loss:2.2954
# epoch:1159  d_loss:0.4220  g_loss:2.0827
# epoch:1160  d_loss:0.5207  g_loss:1.5228
# epoch:1161  d_loss:0.3464  g_loss:2.1434
# epoch:1162  d_loss:0.6159  g_loss:1.6804
# epoch:1163  d_loss:0.6115  g_loss:1.7468
# epoch:1164  d_loss:0.3552  g_loss:1.9238
# epoch:1165  d_loss:0.4858  g_loss:1.7029
# epoch:1166  d_loss:0.4121  g_loss:2.1985
# epoch:1167  d_loss:0.6114  g_loss:1.8238
# epoch:1168  d_loss:0.4721  g_loss:1.8075
# epoch:1169  d_loss:0.3794  g_loss:2.0077
# epoch:1170  d_loss:0.5449  g_loss:1.8036
# epoch:1171  d_loss:0.4835  g_loss:1.7372
# epoch:1172  d_loss:0.3388  g_loss:1.7756
# epoch:1173  d_loss:0.4167  g_loss:1.7858
# epoch:1174  d_loss:0.4250  g_loss:1.7460
# epoch:1175  d_loss:0.3481  g_loss:2.3264
# epoch:1176  d_loss:0.4922  g_loss:2.1758
# ...
# epoch:3620  d_loss:0.4372  g_loss:1.7894
# epoch:3621  d_loss:0.4463  g_loss:1.7259
# epoch:3622  d_loss:0.3842  g_loss:1.7518
# epoch:3623  d_loss:0.5936  g_loss:1.3738
# epoch:3624  d_loss:0.6095  g_loss:1.6542
# epoch:3625  d_loss:0.5389  g_loss:1.6094
# epoch:3626  d_loss:0.3500  g_loss:2.1397
# epoch:3627  d_loss:0.4203  g_loss:1.7568
# epoch:3628  d_loss:0.7013  g_loss:1.8371
# epoch:3629  d_loss:0.5046  g_loss:1.5456
# epoch:3630  d_loss:0.5403  g_loss:1.4054
# epoch:3631  d_loss:0.3757  g_loss:1.7355
# epoch:3632  d_loss:0.3948  g_loss:1.7710
# epoch:3633  d_loss:0.4471  g_loss:1.9481
# epoch:3634  d_loss:0.5431  g_loss:2.0403
# epoch:3635  d_loss:0.5873  g_loss:1.5580
# epoch:3636  d_loss:0.3862  g_loss:1.8301
# epoch:3637  d_loss:0.5597  g_loss:1.8786
# epoch:3638  d_loss:0.3728  g_loss:1.6129
# epoch:3639  d_loss:0.4103  g_loss:2.0598
# epoch:3640  d_loss:0.3780  g_loss:2.0822
# epoch:3641  d_loss:0.4752  g_loss:1.4643
# epoch:3642  d_loss:0.4319  g_loss:1.7441
# epoch:3643  d_loss:0.5458  g_loss:1.5098
# epoch:3644  d_loss:0.3298  g_loss:1.8199
# epoch:3645  d_loss:0.3704  g_loss:2.1158
# epoch:3646  d_loss:0.6042  g_loss:2.3279
# epoch:3647  d_loss:0.5250  g_loss:2.0755
# epoch:3648  d_loss:0.5576  g_loss:1.6855
# epoch:3649  d_loss:0.5861  g_loss:1.6027
# epoch:3650  d_loss:0.2894  g_loss:1.8614
# epoch:3651  d_loss:0.6285  g_loss:1.3070
# epoch:3652  d_loss:0.5386  g_loss:1.7690
# epoch:3653  d_loss:0.4216  g_loss:2.0227
# epoch:3654  d_loss:0.4743  g_loss:1.7807
# epoch:3655  d_loss:0.5441  g_loss:1.6048
# epoch:3656  d_loss:0.6002  g_loss:1.7798
# epoch:3657  d_loss:0.5343  g_loss:1.4004
# epoch:3658  d_loss:0.6151  g_loss:1.4258
# epoch:3659  d_loss:0.4630  g_loss:1.7863
# epoch:3660  d_loss:0.4434  g_loss:2.2822
# epoch:3661  d_loss:0.4553  g_loss:2.1978
# epoch:3662  d_loss:0.5955  g_loss:1.6327
# epoch:3663  d_loss:0.5087  g_loss:1.4980
# epoch:3664  d_loss:0.4912  g_loss:1.5361
# epoch:3665  d_loss:0.4594  g_loss:1.7255
# epoch:3666  d_loss:0.4618  g_loss:1.5466
# epoch:3667  d_loss:0.5255  g_loss:1.8363
# epoch:3668  d_loss:0.4872  g_loss:1.8745
# epoch:3669  d_loss:0.5258  g_loss:1.9912
# epoch:3670  d_loss:0.4830  g_loss:1.9128
# epoch:3671  d_loss:0.5414  g_loss:2.0175
# epoch:3672  d_loss:0.7508  g_loss:1.5318
# epoch:3673  d_loss:0.4737  g_loss:1.5649
# epoch:3674  d_loss:0.4763  g_loss:1.6554
# epoch:3675  d_loss:0.5002  g_loss:2.1062
# epoch:3676  d_loss:0.5774  g_loss:2.0586
# epoch:3677  d_loss:0.4516  g_loss:2.0502
# epoch:3678  d_loss:0.5741  g_loss:1.8900
# epoch:3679  d_loss:0.5878  g_loss:1.5411
# epoch:3680  d_loss:0.5023  g_loss:1.3051
# epoch:3681  d_loss:0.4704  g_loss:1.4288
# epoch:3682  d_loss:0.4904  g_loss:1.3783
# epoch:3683  d_loss:0.5461  g_loss:2.2163
# epoch:3684  d_loss:0.4039  g_loss:2.1287
# epoch:3685  d_loss:0.4187  g_loss:2.2677
# epoch:3686  d_loss:0.4105  g_loss:1.8323
# epoch:3687  d_loss:0.4246  g_loss:1.7692
# epoch:3688  d_loss:0.4364  g_loss:1.6662
# epoch:3689  d_loss:0.5569  g_loss:1.7025
# epoch:3690  d_loss:0.4618  g_loss:1.5515
# epoch:3691  d_loss:0.4907  g_loss:1.7921
# epoch:3692  d_loss:0.3306  g_loss:2.2322
# epoch:3693  d_loss:0.3585  g_loss:2.0159
# epoch:3694  d_loss:0.2799  g_loss:2.3507
# epoch:3695  d_loss:0.5201  g_loss:1.7287
# epoch:3696  d_loss:0.3903  g_loss:1.8764
# epoch:3697  d_loss:0.5415  g_loss:1.5328
# epoch:3698  d_loss:0.4509  g_loss:1.8646
# epoch:3699  d_loss:0.4819  g_loss:1.7313
# epoch:3700  d_loss:0.4038  g_loss:2.0536
# epoch:3701  d_loss:0.5165  g_loss:1.4414
# epoch:3702  d_loss:0.6327  g_loss:1.5958
# epoch:3703  d_loss:0.5400  g_loss:1.6675
# epoch:3704  d_loss:0.5707  g_loss:1.7073
# epoch:3705  d_loss:0.4839  g_loss:1.5533
# epoch:3706  d_loss:0.7514  g_loss:1.6268
# epoch:3707  d_loss:0.5342  g_loss:1.6745
# epoch:3708  d_loss:0.4751  g_loss:1.6267
# epoch:3709  d_loss:0.5975  g_loss:1.4563
# epoch:3710  d_loss:0.6151  g_loss:1.3857
# epoch:3711  d_loss:0.5408  g_loss:1.3645
# epoch:3712  d_loss:0.3616  g_loss:1.6708
# epoch:3713  d_loss:0.4885  g_loss:1.8967
# epoch:3714  d_loss:0.4754  g_loss:1.7505
# epoch:3715  d_loss:0.4297  g_loss:1.8354
# epoch:3716  d_loss:0.5521  g_loss:2.0024
# epoch:3717  d_loss:0.4020  g_loss:1.8497
# epoch:3718  d_loss:0.3729  g_loss:1.8039
# epoch:3719  d_loss:0.3244  g_loss:1.6286
# epoch:3720  d_loss:0.4228  g_loss:1.8798
# epoch:3721  d_loss:0.5335  g_loss:1.8568
# epoch:3722  d_loss:0.4166  g_loss:1.9560
# epoch:3723  d_loss:0.3352  g_loss:2.1773
# epoch:3724  d_loss:0.4604  g_loss:2.1481
# epoch:3725  d_loss:0.5583  g_loss:1.9081
# epoch:3726  d_loss:0.4753  g_loss:1.5232
# epoch:3727  d_loss:0.5041  g_loss:1.5643
# epoch:3728  d_loss:0.6101  g_loss:1.0527
# epoch:3729  d_loss:0.4638  g_loss:2.1970
# epoch:3730  d_loss:0.3632  g_loss:1.9990
# epoch:3731  d_loss:0.4508  g_loss:1.8349
# epoch:3732  d_loss:0.5655  g_loss:1.8092
# epoch:3733  d_loss:0.5061  g_loss:1.2415
# epoch:3734  d_loss:0.4047  g_loss:1.4845
# epoch:3735  d_loss:0.4495  g_loss:1.8156
# epoch:3736  d_loss:0.4584  g_loss:1.6213
# epoch:3737  d_loss:0.4170  g_loss:1.9434
# epoch:3738  d_loss:0.4976  g_loss:1.6050
# epoch:3739  d_loss:0.4405  g_loss:1.8814
# epoch:3740  d_loss:0.5090  g_loss:1.3517
# epoch:3741  d_loss:0.3807  g_loss:1.6352
# epoch:3742  d_loss:0.5676  g_loss:1.2102
# epoch:3743  d_loss:0.4749  g_loss:1.8329
# epoch:3744  d_loss:0.3701  g_loss:2.2738
# epoch:3745  d_loss:0.5071  g_loss:2.0417
# epoch:3746  d_loss:0.5379  g_loss:1.8824
# epoch:3747  d_loss:0.5912  g_loss:1.3489
# epoch:3748  d_loss:0.4672  g_loss:1.0242
# epoch:3749  d_loss:0.6104  g_loss:1.2846
# epoch:3750  d_loss:0.5760  g_loss:1.3448
# epoch:3751  d_loss:0.3391  g_loss:1.7756
# epoch:3752  d_loss:0.3450  g_loss:2.2728
# epoch:3753  d_loss:0.5061  g_loss:1.7923
# epoch:3754  d_loss:0.4797  g_loss:1.9140
# epoch:3755  d_loss:0.5617  g_loss:1.5028
# epoch:3756  d_loss:0.4578  g_loss:1.3515
# epoch:3757  d_loss:0.4854  g_loss:1.3737
# epoch:3758  d_loss:0.5618  g_loss:1.4191
# epoch:3759  d_loss:0.5303  g_loss:1.5639
# epoch:3760  d_loss:0.4560  g_loss:1.7952
# epoch:3761  d_loss:0.3954  g_loss:1.7168
# epoch:3762  d_loss:0.4818  g_loss:1.6182
# epoch:3763  d_loss:0.5273  g_loss:1.7284
# epoch:3764  d_loss:0.5703  g_loss:1.6450
# epoch:3765  d_loss:0.4475  g_loss:2.0017
# epoch:3766  d_loss:0.4211  g_loss:1.8181
# epoch:3767  d_loss:0.5215  g_loss:1.6955
# epoch:3768  d_loss:0.5379  g_loss:1.7076
# epoch:3769  d_loss:0.5049  g_loss:1.6080
# epoch:3770  d_loss:0.3858  g_loss:2.2731
# epoch:3771  d_loss:0.3628  g_loss:2.1960
# epoch:3772  d_loss:0.5447  g_loss:1.8687
# epoch:3773  d_loss:0.4373  g_loss:1.8829
# epoch:3774  d_loss:0.5683  g_loss:1.4002
# epoch:3775  d_loss:0.5028  g_loss:1.3577
# epoch:3776  d_loss:0.3251  g_loss:1.7200
# epoch:3777  d_loss:0.5516  g_loss:1.6021
# epoch:3778  d_loss:0.4755  g_loss:2.0216
# epoch:3779  d_loss:0.4865  g_loss:1.6057
# epoch:3780  d_loss:0.5062  g_loss:1.7798
# epoch:3781  d_loss:0.3496  g_loss:2.0057
# epoch:3782  d_loss:0.4213  g_loss:1.7934
# epoch:3783  d_loss:0.6070  g_loss:1.2505
# epoch:3784  d_loss:0.5498  g_loss:1.5770
# epoch:3785  d_loss:0.4966  g_loss:1.4702
# epoch:3786  d_loss:0.3754  g_loss:1.7076
# epoch:3787  d_loss:0.3953  g_loss:2.1728
# epoch:3788  d_loss:0.4579  g_loss:1.8859
# epoch:3789  d_loss:0.4378  g_loss:1.6969
# epoch:3790  d_loss:0.5145  g_loss:1.7493
# epoch:3791  d_loss:0.5284  g_loss:1.7555
# epoch:3792  d_loss:0.4574  g_loss:1.3685
# epoch:3793  d_loss:0.4797  g_loss:1.9949
# epoch:3794  d_loss:0.5447  g_loss:1.7655
# epoch:3795  d_loss:0.5076  g_loss:1.9675
# epoch:3796  d_loss:0.5380  g_loss:2.0169
# epoch:3797  d_loss:0.4811  g_loss:1.4737
# epoch:3798  d_loss:0.4491  g_loss:1.4286
# epoch:3799  d_loss:0.5102  g_loss:1.6772
# epoch:3800  d_loss:0.5479  g_loss:1.4839
# epoch:3801  d_loss:0.5747  g_loss:1.6208
# epoch:3802  d_loss:0.6495  g_loss:1.5381
# epoch:3803  d_loss:0.3613  g_loss:2.0123
# epoch:3804  d_loss:0.5488  g_loss:1.6710
# epoch:3805  d_loss:0.6039  g_loss:1.6540
# epoch:3806  d_loss:0.5520  g_loss:1.5290
# epoch:3807  d_loss:0.5067  g_loss:1.6032
# epoch:3808  d_loss:0.4038  g_loss:1.6908
# epoch:3809  d_loss:0.4313  g_loss:1.8791
# epoch:3810  d_loss:0.5071  g_loss:1.8023
# epoch:3811  d_loss:0.4263  g_loss:2.0638
# epoch:3812  d_loss:0.5045  g_loss:1.8137
# epoch:3813  d_loss:0.3760  g_loss:1.9681
# epoch:3814  d_loss:0.4017  g_loss:1.8478
# epoch:3815  d_loss:0.4367  g_loss:1.8000
# epoch:3816  d_loss:0.4542  g_loss:1.6653
# epoch:3817  d_loss:0.4630  g_loss:1.9195
# epoch:3818  d_loss:0.4369  g_loss:1.3928
# epoch:3819  d_loss:0.4160  g_loss:1.7770
# epoch:3820  d_loss:0.5493  g_loss:1.8748
# epoch:3821  d_loss:0.5457  g_loss:1.5150
# epoch:3822  d_loss:0.4846  g_loss:1.8610
# epoch:3823  d_loss:0.4713  g_loss:1.7389
# epoch:3824  d_loss:0.4915  g_loss:1.2424
# epoch:3825  d_loss:0.6669  g_loss:1.3734
# epoch:3826  d_loss:0.4547  g_loss:1.3437
# epoch:3827  d_loss:0.4333  g_loss:1.6965
# epoch:3828  d_loss:0.5517  g_loss:1.4592
# epoch:3829  d_loss:0.4777  g_loss:1.8124
# epoch:3830  d_loss:0.4286  g_loss:1.9674
# epoch:3831  d_loss:0.4836  g_loss:1.3910
# epoch:3832  d_loss:0.5092  g_loss:1.3161
# epoch:3833  d_loss:0.4434  g_loss:1.6578
# epoch:3834  d_loss:0.3655  g_loss:1.9190
# epoch:3835  d_loss:0.4433  g_loss:2.2291
# epoch:3836  d_loss:0.4436  g_loss:1.8581
# epoch:3837  d_loss:0.4339  g_loss:2.3278
# epoch:3838  d_loss:0.6292  g_loss:1.7513
# epoch:3839  d_loss:0.6648  g_loss:1.8251
# epoch:3840  d_loss:0.5146  g_loss:1.5516
# epoch:3841  d_loss:0.4072  g_loss:1.6837
# epoch:3842  d_loss:0.3925  g_loss:1.5220
# epoch:3843  d_loss:0.5734  g_loss:1.7807
# epoch:3844  d_loss:0.5286  g_loss:1.5717
# epoch:3845  d_loss:0.5083  g_loss:1.6811
# epoch:3846  d_loss:0.6015  g_loss:1.2967
# epoch:3847  d_loss:0.5291  g_loss:1.7896
# epoch:3848  d_loss:0.5372  g_loss:1.7699
# epoch:3849  d_loss:0.4478  g_loss:2.0869
# epoch:3850  d_loss:0.5200  g_loss:1.8891
# epoch:3851  d_loss:0.3978  g_loss:2.1341
# epoch:3852  d_loss:0.4102  g_loss:1.9625
# epoch:3853  d_loss:0.3949  g_loss:2.0682
# epoch:3854  d_loss:0.5082  g_loss:1.7240
# epoch:3855  d_loss:0.5872  g_loss:1.5285
# epoch:3856  d_loss:0.6348  g_loss:1.3761
# epoch:3857  d_loss:0.4773  g_loss:1.4396
# epoch:3858  d_loss:0.4088  g_loss:1.6410
# epoch:3859  d_loss:0.4332  g_loss:1.7035
# epoch:3860  d_loss:0.3701  g_loss:1.8200
# epoch:3861  d_loss:0.5128  g_loss:1.6388
# epoch:3862  d_loss:0.4830  g_loss:1.4811
# epoch:3863  d_loss:0.4791  g_loss:1.5964
# epoch:3864  d_loss:0.6143  g_loss:1.3687
# epoch:3865  d_loss:0.5274  g_loss:1.6958
# epoch:3866  d_loss:0.4171  g_loss:2.0372
# epoch:3867  d_loss:0.3917  g_loss:1.8684
# epoch:3868  d_loss:0.4763  g_loss:1.7838
# epoch:3869  d_loss:0.4653  g_loss:1.9423
# epoch:3870  d_loss:0.4051  g_loss:1.8421
# epoch:3871  d_loss:0.3708  g_loss:2.2148
# epoch:3872  d_loss:0.4952  g_loss:2.0884
# epoch:3873  d_loss:0.3667  g_loss:1.8892
# epoch:3874  d_loss:0.3947  g_loss:2.0753
# epoch:3875  d_loss:0.5918  g_loss:1.6839
# epoch:3876  d_loss:0.4561  g_loss:1.4497
# epoch:3877  d_loss:0.4313  g_loss:1.7826
# epoch:3878  d_loss:0.5727  g_loss:1.5807
# epoch:3879  d_loss:0.4235  g_loss:2.1716
# epoch:3880  d_loss:0.3508  g_loss:1.7740
# epoch:3881  d_loss:0.4166  g_loss:1.9431
# epoch:3882  d_loss:0.4135  g_loss:1.8792
# epoch:3883  d_loss:0.4242  g_loss:1.7857
# epoch:3884  d_loss:0.4683  g_loss:1.7048
# epoch:3885  d_loss:0.5437  g_loss:1.8654
# epoch:3886  d_loss:0.4885  g_loss:1.8530
# epoch:3887  d_loss:0.4194  g_loss:1.8638
# epoch:3888  d_loss:0.4356  g_loss:1.5213
# epoch:3889  d_loss:0.4656  g_loss:1.7753
# epoch:3890  d_loss:0.3706  g_loss:1.8936
# epoch:3891  d_loss:0.3670  g_loss:2.0328
# epoch:3892  d_loss:0.5211  g_loss:1.6394
# epoch:3893  d_loss:0.5582  g_loss:1.2455
# epoch:3894  d_loss:0.6269  g_loss:1.4465
# epoch:3895  d_loss:0.5277  g_loss:2.3867
# epoch:3896  d_loss:0.5837  g_loss:2.0714
# epoch:3897  d_loss:0.4396  g_loss:2.0330
# epoch:3898  d_loss:0.6235  g_loss:1.4999
# epoch:3899  d_loss:0.5812  g_loss:1.3435
# epoch:3900  d_loss:0.5445  g_loss:1.4758
# epoch:3901  d_loss:0.5051  g_loss:1.3749
# epoch:3902  d_loss:0.5521  g_loss:1.6842
# epoch:3903  d_loss:0.5258  g_loss:1.5699
# epoch:3904  d_loss:0.4500  g_loss:1.8473
# epoch:3905  d_loss:0.5760  g_loss:1.9226
# epoch:3906  d_loss:0.5378  g_loss:1.5428
# epoch:3907  d_loss:0.4958  g_loss:1.4090
# epoch:3908  d_loss:0.4323  g_loss:1.7044
# epoch:3909  d_loss:0.5931  g_loss:1.6205
# epoch:3910  d_loss:0.5863  g_loss:1.2057
# epoch:3911  d_loss:0.4825  g_loss:1.4213
# epoch:3912  d_loss:0.5364  g_loss:1.4175
# epoch:3913  d_loss:0.4480  g_loss:1.5808
# epoch:3914  d_loss:0.4536  g_loss:1.9497
# epoch:3915  d_loss:0.3950  g_loss:2.3275
# epoch:3916  d_loss:0.5511  g_loss:1.6084
# epoch:3917  d_loss:0.4215  g_loss:1.7898
# epoch:3918  d_loss:0.4124  g_loss:1.5411
# epoch:3919  d_loss:0.5046  g_loss:1.6524
# epoch:3920  d_loss:0.4795  g_loss:1.5596
# epoch:3921  d_loss:0.5113  g_loss:1.5022
# epoch:3922  d_loss:0.3179  g_loss:2.2858
# epoch:3923  d_loss:0.4916  g_loss:1.9415
# epoch:3924  d_loss:0.4923  g_loss:1.4741
# epoch:3925  d_loss:0.6243  g_loss:1.6429
# epoch:3926  d_loss:0.5751  g_loss:1.3820
# epoch:3927  d_loss:0.5188  g_loss:1.3410
# epoch:3928  d_loss:0.3903  g_loss:1.5541
# epoch:3929  d_loss:0.4235  g_loss:2.0434
# epoch:3930  d_loss:0.4202  g_loss:1.7051
# epoch:3931  d_loss:0.5239  g_loss:1.8068
# epoch:3932  d_loss:0.5466  g_loss:1.6624
# epoch:3933  d_loss:0.5298  g_loss:1.7386
# epoch:3934  d_loss:0.5427  g_loss:1.6744
# epoch:3935  d_loss:0.6718  g_loss:1.6501
# epoch:3936  d_loss:0.5734  g_loss:1.5904
# epoch:3937  d_loss:0.4685  g_loss:1.5829
# epoch:3938  d_loss:0.5502  g_loss:1.5686
# epoch:3939  d_loss:0.6005  g_loss:1.8409
# epoch:3940  d_loss:0.5184  g_loss:1.3667
# epoch:3941  d_loss:0.4116  g_loss:1.4714
# epoch:3942  d_loss:0.5148  g_loss:1.4495
# epoch:3943  d_loss:0.4425  g_loss:1.6219
# epoch:3944  d_loss:0.3922  g_loss:1.6691
# epoch:3945  d_loss:0.4415  g_loss:1.9261
# epoch:3946  d_loss:0.5192  g_loss:1.4900
# epoch:3947  d_loss:0.4960  g_loss:1.8680
# epoch:3948  d_loss:0.4402  g_loss:2.1415
# epoch:3949  d_loss:0.4845  g_loss:2.0133
# epoch:3950  d_loss:0.4839  g_loss:1.9067
# epoch:3951  d_loss:0.5588  g_loss:1.5818
# epoch:3952  d_loss:0.4458  g_loss:1.0706
# epoch:3953  d_loss:0.4493  g_loss:1.3007
# epoch:3954  d_loss:0.4035  g_loss:1.5748
# epoch:3955  d_loss:0.4466  g_loss:1.9208
# epoch:3956  d_loss:0.5797  g_loss:1.8781
# epoch:3957  d_loss:0.3931  g_loss:2.1856
# epoch:3958  d_loss:0.4911  g_loss:2.2924
# epoch:3959  d_loss:0.5899  g_loss:1.5711
# epoch:3960  d_loss:0.4264  g_loss:1.5811
# epoch:3961  d_loss:0.5471  g_loss:1.3299
# epoch:3962  d_loss:0.5306  g_loss:1.3810
# epoch:3963  d_loss:0.4192  g_loss:2.0979
# epoch:3964  d_loss:0.5284  g_loss:1.5195
# epoch:3965  d_loss:0.5335  g_loss:1.7268
# epoch:3966  d_loss:0.5442  g_loss:1.8601
# epoch:3967  d_loss:0.6360  g_loss:1.5490
# epoch:3968  d_loss:0.4077  g_loss:2.1703
# epoch:3969  d_loss:0.5304  g_loss:1.6666
# epoch:3970  d_loss:0.4422  g_loss:1.5810
# epoch:3971  d_loss:0.4621  g_loss:1.6424
# epoch:3972  d_loss:0.5499  g_loss:1.6223
# epoch:3973  d_loss:0.3861  g_loss:1.7196
# epoch:3974  d_loss:0.4369  g_loss:1.5835
# epoch:3975  d_loss:0.4857  g_loss:1.7379
# epoch:3976  d_loss:0.6182  g_loss:1.6058
# epoch:3977  d_loss:0.4470  g_loss:1.9038
# epoch:3978  d_loss:0.6023  g_loss:1.4425
# epoch:3979  d_loss:0.5523  g_loss:1.2629
# epoch:3980  d_loss:0.5417  g_loss:1.5283
# epoch:3981  d_loss:0.5149  g_loss:1.5680
# epoch:3982  d_loss:0.5624  g_loss:1.4361
# epoch:3983  d_loss:0.6188  g_loss:1.7061
# epoch:3984  d_loss:0.5791  g_loss:1.4104
# epoch:3985  d_loss:0.3966  g_loss:1.4749
# epoch:3986  d_loss:0.4895  g_loss:1.5447
# epoch:3987  d_loss:0.5288  g_loss:1.4236
# epoch:3988  d_loss:0.4374  g_loss:1.5636
# epoch:3989  d_loss:0.4693  g_loss:1.8919
# epoch:3990  d_loss:0.4668  g_loss:1.7581
# epoch:3991  d_loss:0.3318  g_loss:1.6748
# epoch:3992  d_loss:0.3773  g_loss:1.7549
# epoch:3993  d_loss:0.4994  g_loss:1.5817
# epoch:3994  d_loss:0.4745  g_loss:1.8014
# epoch:3995  d_loss:0.4115  g_loss:1.3346
# epoch:3996  d_loss:0.4758  g_loss:1.5917
# epoch:3997  d_loss:0.4268  g_loss:1.6462
# epoch:3998  d_loss:0.2845  g_loss:2.1264
# epoch:3999  d_loss:0.5069  g_loss:1.9271
# epoch:4000  d_loss:0.4439  g_loss:1.9491
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_27260/494428664.py:93: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(5, 5)

# %% [markdown]
# ## 오토인코더 (AE)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
import matplotlib.pyplot as plt
import numpy as np

#MNIST데이터 셋을 불러옵니다.

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

#생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분이 이어집니다. 
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인해 봅니다.
autoencoder.summary()

# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

#학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  #테스트할 이미지를 랜덤하게 불러옵니다.
ae_imgs = autoencoder.predict(X_test)  #앞서 만든 오토인코더 모델에 집어 넣습니다.

plt.figure(figsize=(7, 2))  #출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):    #랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(2, 7, i + 1) 
   plt.imshow(X_test[image_idx].reshape(28, 28))  #테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28))  #오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 16)       0
#  )
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 8)         1160
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 8)           584
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 8)           584
#
#  up_sampling2d_2 (UpSampling  (None, 8, 8, 8)          0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 8)           584
#
#  up_sampling2d_3 (UpSampling  (None, 16, 16, 8)        0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 16)        1168
#
#  up_sampling2d_4 (UpSampling  (None, 28, 28, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 45s 96ms/step - loss: 0.2157 - val_loss: 0.1406
# Epoch 2/50
# 469/469 [==============================] - 44s 93ms/step - loss: 0.1267 - val_loss: 0.1159
# Epoch 3/50
# 469/469 [==============================] - 41s 87ms/step - loss: 0.1123 - val_loss: 0.1068
# Epoch 4/50
# 469/469 [==============================] - 41s 87ms/step - loss: 0.1052 - val_loss: 0.1017
# Epoch 5/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.1013 - val_loss: 0.0988
# Epoch 6/50
# 469/469 [==============================] - 35s 74ms/step - loss: 0.0988 - val_loss: 0.0970
# Epoch 7/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.0971 - val_loss: 0.0953
# Epoch 8/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0956 - val_loss: 0.0941
# Epoch 9/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0946 - val_loss: 0.0932
# Epoch 10/50
# 469/469 [==============================] - 40s 84ms/step - loss: 0.0935 - val_loss: 0.0920
# Epoch 11/50
# 469/469 [==============================] - 41s 87ms/step - loss: 0.0927 - val_loss: 0.0910
# Epoch 12/50
# 469/469 [==============================] - 39s 84ms/step - loss: 0.0919 - val_loss: 0.0904
# Epoch 13/50
# 469/469 [==============================] - 39s 84ms/step - loss: 0.0913 - val_loss: 0.0898
# Epoch 14/50
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0907 - val_loss: 0.0892
# Epoch 15/50
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0902 - val_loss: 0.0891
# Epoch 16/50
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0898 - val_loss: 0.0885
# Epoch 17/50
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0893 - val_loss: 0.0880
# Epoch 18/50
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0890 - val_loss: 0.0878
# Epoch 19/50
# 469/469 [==============================] - 42s 89ms/step - loss: 0.0886 - val_loss: 0.0881
# Epoch 20/50
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0883 - val_loss: 0.0869
# Epoch 21/50
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0880 - val_loss: 0.0866
# Epoch 22/50
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0876 - val_loss: 0.0864
# Epoch 23/50
# 469/469 [==============================] - 41s 87ms/step - loss: 0.0874 - val_loss: 0.0863
# Epoch 24/50
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0870 - val_loss: 0.0859
# Epoch 25/50
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0868 - val_loss: 0.0858
# Epoch 26/50
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0866 - val_loss: 0.0853
# Epoch 27/50
# 469/469 [==============================] - 39s 83ms/step - loss: 0.0863 - val_loss: 0.0850
# Epoch 28/50
# 469/469 [==============================] - 38s 82ms/step - loss: 0.0861 - val_loss: 0.0848
# Epoch 29/50
# 469/469 [==============================] - 38s 82ms/step - loss: 0.0859 - val_loss: 0.0847
# Epoch 30/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.0857 - val_loss: 0.0847
# Epoch 31/50
# 469/469 [==============================] - 42s 90ms/step - loss: 0.0854 - val_loss: 0.0846
# Epoch 32/50
# 469/469 [==============================] - 44s 95ms/step - loss: 0.0853 - val_loss: 0.0840
# Epoch 33/50
# 469/469 [==============================] - 76s 162ms/step - loss: 0.0851 - val_loss: 0.0838
# Epoch 34/50
# 469/469 [==============================] - 59s 125ms/step - loss: 0.0849 - val_loss: 0.0837
# Epoch 35/50
# 469/469 [==============================] - 49s 104ms/step - loss: 0.0848 - val_loss: 0.0836
# Epoch 36/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.0846 - val_loss: 0.0836
# Epoch 37/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0844 - val_loss: 0.0836
# Epoch 38/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0843 - val_loss: 0.0832
# Epoch 39/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0841 - val_loss: 0.0833
# Epoch 40/50
# 469/469 [==============================] - 35s 74ms/step - loss: 0.0840 - val_loss: 0.0827
# Epoch 41/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0838 - val_loss: 0.0825
# Epoch 42/50
# 469/469 [==============================] - 35s 74ms/step - loss: 0.0837 - val_loss: 0.0825
# Epoch 43/50
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0835 - val_loss: 0.0823
# Epoch 44/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.0834 - val_loss: 0.0822
# Epoch 45/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0833 - val_loss: 0.0822
# Epoch 46/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.0831 - val_loss: 0.0823
# Epoch 47/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.0831 - val_loss: 0.0825
# Epoch 48/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0829 - val_loss: 0.0818
# Epoch 49/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.0828 - val_loss: 0.0816
# Epoch 50/50
# 469/469 [==============================] - 40s 85ms/step - loss: 0.0827 - val_loss: 0.0815
