# %% [markdown]
# ## 코로나후 네이버 블로그 여행관련 데이터 크롤링

# %%
import sys
import os

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from selenium import webdriver
import time
from tqdm import tqdm_notebook

# %%
query_txt = input('1.크롤링할 키워드는 무엇입니까?:')
start_date = input('2. 조회를 시작할 날짜를 입력하세요:')
end_date = input('3. 조회를 종료할 날짜를 입력하세요')
# Out:
# 1.크롤링할 키워드는 무엇입니까?:캠핑장소
# 2. 조회를 시작할 날짜를 입력하세요:
# 3. 조회를 종료할 날짜를 입력하세요

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('http://naver.com')
time.sleep(2)

element=driver.find_element_by_id("query")
element.send_keys(query_txt)
element.submit()

driver.find_element_by_link_text("VIEW").click()
time.sleep(1)

driver.find_element_by_link_text("블로그").click()
time.sleep(1)

driver.find_element_by_link_text("옵션").click()
time.sleep(1)

driver.find_element_by_link_text("직접입력옵션펼치기").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/2914185354.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/2914185354.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element=driver.find_element_by_id("query")
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/2914185354.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("VIEW").click()
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/2914185354.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("블로그").click()
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/2914185354.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("옵션").click()
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/2914185354.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("직접입력옵션펼치기").click()

# %%
driver.find_element_by_link_text("2021").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/3097611315.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("2021").click()

# %%
driver.find_element_by_link_text("1").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/1856955342.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("1").click()

# %%
driver.find_element_by_link_text("1").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/1856955342.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("1").click()

# %%
driver.find_element_by_link_text("2021").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/3097611315.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("2021").click()

# %%
driver.find_element_by_link_text("12").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/288938466.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("12").click()
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_56304/288938466.py in <module>
# ----> 1 driver.find_element_by_link_text("12").click()
#       2 time.sleep(1)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      79     def click(self) -> None:
#      80         """Clicks the element."""
# ---> 81         self._execute(Command.CLICK_ELEMENT)
#      82
#      83     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=97.0.4692.71)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00A76903+2517251]
# 	Ordinal0 [0x00A0F8E1+2095329]
# 	Ordinal0 [0x00912848+1058888]
# 	Ordinal0 [0x00914F44+1068868]
# 	Ordinal0 [0x00914E0E+1068558]
# 	Ordinal0 [0x00915070+1069168]
# 	Ordinal0 [0x0093EC4C+1240140]
# 	Ordinal0 [0x00933F63+1195875]
# 	Ordinal0 [0x009564D3+1336531]
# 	Ordinal0 [0x00933A36+1194550]
# 	Ordinal0 [0x009565BA+1336762]
# 	Ordinal0 [0x00965BBF+1399743]
# 	Ordinal0 [0x0095639B+1336219]
# 	Ordinal0 [0x009327A7+1189799]
# 	Ordinal0 [0x00933609+1193481]
# 	GetHandleVerifier [0x00C05904+1577972]
# 	GetHandleVerifier [0x00CB0B97+2279047]
# 	GetHandleVerifier [0x00B06D09+534521]
# 	GetHandleVerifier [0x00B05DB9+530601]
# 	Ordinal0 [0x00A14FF9+2117625]
# 	Ordinal0 [0x00A198A8+2136232]
# 	Ordinal0 [0x00A199E2+2136546]
# 	Ordinal0 [0x00A23541+2176321]
# 	BaseThreadInitThunk [0x765C6739+25]
# 	RtlGetFullPathName_UEx [0x77988AFF+1215]
# 	RtlGetFullPathName_UEx [0x77988ACD+1165]

# %%
driver.find_element_by_link_text("31").click()
time.sleep(1)

# %%
def scroll_down(driver):
    driver.execute_script("window.scrollTo(0, 99999999)")
    time.sleep(1)

# n: 스크롤할 횟수 설정
n = 50
i = 0
while i < n:
    scroll_down(driver)
    i = i+1

# %%
# 블로그 글 url들 수집
url_list = []
title_list = []

# URL_raw 크롤링 시작
article_raw = driver.find_elements_by_css_selector(".api_txt_lines.total_tit")
article_raw[0]

# 크롤링한 url 정제 시작
for article in article_raw:
    url = article.get_attribute('href')   
    url_list.append(url)

time.sleep(1)
    
# 제목 크롤링 시작    
for article in article_raw:
    title = article.text
    title_list.append(title)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_56304/3414791471.py:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   article_raw = driver.find_elements_by_css_selector(".api_txt_lines.total_tit")

# %%
df = pd.DataFrame({'url':url_list, 'title':title_list})
df
# Out:
#                                                     url  \
# 0     https://blog.naver.com/dldyddl?Redirect=Log&lo...
# 1     https://blog.naver.com/crom234?Redirect=Log&lo...
# 2     https://blog.naver.com/jayooni?Redirect=Log&lo...
# 3     https://blog.naver.com/wlsrud1318?Redirect=Log...
# 4     https://blog.naver.com/sunbeeno1?Redirect=Log&...
# ...                                                 ...
# 1045  https://blog.naver.com/dldyddl?Redirect=Log&lo...
# 1046  https://blog.naver.com/nadiany?Redirect=Log&lo...
# 1047  https://blog.naver.com/b_k_b_s?Redirect=Log&lo...
# 1048  https://blog.naver.com/hp692kk?Redirect=Log&lo...
# 1049  https://blog.naver.com/2gayoung9?Redirect=Log&...
#
#                                      title
# 0               강원도 강릉 옥계해변 노지 차박캠핑장소 돌아보니
# 1            차박 장소 추천 낚시 가능한 영월 무료 노지 차박캠핑
# 2       경상남도 [창원] 마산합포구 진전면 용댐 계곡 노지 캠핑 장소
# 3            전남캠핑장소추천 여수캠핑장 더스타오토캠핑장 B1 후기
# 4        봄봄봄 서울 근교 캠핑장소 마운트프로 돔텐트4 들고 왔어요~
# ...                                    ...
# 1045          강원도 동해 스텔스 차박캠핑 차크닉 가능한 어달해변
# 1046  [경남캠핑장]해발550m에 위치한 찐캠핑! 함양 숲속애캠핑장...
# 1047   [차박] 비비동부부만 아는 차박캠핑장소에서 조용히 우리끼리...
# 1048  강화도 차박 노지캠핑... 선두5리어판장 with 스타렉스 캠핑카
# 1049             [용인 캠핑]모노캠프, 캠핑 추천 분위기 맛집
#
# [1050 rows x 2 columns]

# %%
# url_list 저장
df.to_excel("2021캠핑장소naver_blog.xlsx")

# %%
from wordcloud import WordCloud, STOPWORDS

import numpy as np
from PIL import Image

# %%
import matplotlib.pyplot as plt
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager,rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %matplotlib inline

# %%
text = open('../data/2021차박장소.txt', 'r', encoding='utf8').read()
stopwords = set(STOPWORDS)

# %%
text
# Out:
# '통영 차박 장소 추천 수륙해수욕장 낚시 포인트\n속초 차박장소 1박2일 차박여행\n차박 캠핑을 위해 준비한... 쓸만하네~(천안노지 차박장소추천)\n제주 바다 피크닉 : 나만알고싶은 제주도 차크닉 차박 장소\n차박 장소 추천 영덕 장사해수욕장 캠핑 요금표 알려드려요\n제주 차박 장소 이호테우해변, 함덕 서우봉해변 바람아 왜그러니..\n차박 장소 추천 안성 고삼저수지\n캠핑 준비물 리스트 & 차박 장소 추천!\n서울근교, 경기도 화성 궁평항 산책하기 좋은 곳 차박장소\n강릉 차박 장소 순긋해변 사근진해변 추천\n부산 차박 장소추천, 감성캠핑 할땐 언제나 퓨어수 생수 챙기기\n노지캠핑 :: 조용한 경기도 차박/차크닉 장소 (무료, 취사가능)\n국내 무료차박, 차크닉 장소 추천.\n동해바다 차박 장소 추천 울진 구산해수욕장 캠핑장\n차박 장소 추천 낚시 가능한 영월 무료 노지 차박캠핑\n차박 입문서! 차박 준비물, 차박장소 추천까지 차박의 모든 것\n양평 차박여행, 차박 장소 추천, 캠핑카 대여, 캠핑카 렌트\n포항 차박 장소 추천 월포 해수욕장 해변 차박지\n제주도 차박캠핑 금은모래해수욕장, 금릉해변 장소 꼭 다시...\n단양 생태체육공원 차박장소 노지캠핑 차박성지 단양 구경시장...\n캠프고 블랙코팅 헥사타프 자랑~(feat. 태안 차박 장소 추천)\n차박 장소 추천 / 서울 근교 차박, 차박지, 차크닉, 캠핑 장소\n경남 여행 : 고성 무료 노지 차박 장소 추천\n2일차 차박여행 / 캠핑장 차박장소 추천지 오대산 소금강...\n강원도 고성 노지캠핑, 낚시 차박하기 좋은 장소 이곳은.....\n노지차박/차박 장소 추천] 기천저수지 feat. 화장실, 요금...\n거제도 차박 장소 추천 거제 흥남해수욕장 밤샘 낚시 어때요?\n천안 계곡 캠핑장 차박 장소 추천 노지 캠핑 차박텐트도 귀찮다.\n차박장소 추천 포항 도구해수욕장 가볼만한곳\n강원도 양양 차박장소 정암해수욕장 다녀온 이야기!\n양양 여행 가볼만한곳 : 정암 해수욕장 해변 바다 차박 장소 추천\n제주 차박여행 광치기해변 신양섭지해수욕장 차박 장소 후기\n태안 안면도 차박 장소 추천 바람아래 해수욕장 과 영목항\n보낸 막바지 가을!( feat. 천문대캠핑장 차박 장소 추천)\n언택트 여행 트렌드 차박 캠핑! 차박 장소 추천, 어디서...\n강원도 동해 망상해수욕장 산책겸 차박캠핑 장소 둘러보기...\n전국의 한적한 차박 장소들\n가평 차박 장소 대성리 국민관광지 차크닉하기 좋은 곳\n포항 이가리 닻 전망대 & 간이해변 차박 장소 추천 이유는?\n가을 차박장소추천 억새멍 꽃멍 노지차박캠핑\n인천 차박 장소 추천 소나무 숲이 반겨주는 실미도해수욕장\n차박장소 추천 서울근교 화성방조제, 궁평항 차크닉 노지캠핑...\n제주 서쪽에서 가장 좋은 차박 장소 6월의 [금능해수욕장 주차장]\n노지차박일기 / 노지 차박장소추천 속초 강릉 바다 순긋해변...\n강릉 차박 장소 추천! 이곳만큼 차박하기 좋은곳 찾기 어려울걸?!\n여름 차박 장소 추천 평창 육백마지기 차박 후 데이지 구경\n제주도 차박 캠핑 용품대여부터 일출명소 차박지 성공 장소 추천\n인천 차박 장소 추천, 인천 영종도 다녀온 솔직후기! (ft. 에어...\n강원도 가볼만한곳 설악산 한계령휴게소 차박장소추천\n자유롭게 떠날 수 있는 차박캠핑 [차박 장소 추천]\n동해안 차박 장소 추천 영덕 장사해수욕장 캠핑 여행\n차박장소추천 노지캠핑 이제는 주차장 차박 캠핑까지...\n[부산] 가덕도 천성항 / 천성항 차박캠핑장소\n[인천 차박 장소 추천] 숨겨진 차크닉 명소 왕산 마리나\n제주 일몰 명소 금능해수욕장 차박장소 추천\n차박 장소 추천 #대부도 메추리섬 캠핑 (feat....\n포항 오도항 차박, 동해 바다가 있는 곳 소개 / 차박 장소 추천\n충남 보령 캠핑장 및 차박 장소 추천! 무창포 오토캠핑장\n대전 차박장소 조용하고 힐링 되는 노루벌\n힐링장소 궁평해송유원지와 낙조감상하며 차박하기좋은 궁평항^^~\n제주도 차박 캠핑 제주 차박장소 추천 명성은 이대로 끝이...\n목계솔밭, 목계나루, 수주팔봉의 평일 풍경 차박 장소 추천!\n천안 벚꽃 드라이브 노지캠핑 차박장소 차크닉 다녀옴~\n충주 가볼만한곳 목계솔밭 캠핑장 무료 노지 차박장소추천...\n동해안 차박 장소 추천 삼척 맹방해수욕장, 영덕 장사해수욕장...\n경주 문무대왕릉 & 나정고운모래해변 스텔스 차박 장소로 어때?\n충남 태안 차박 장소 추천 마도 노지캠핑 여건은?\n차박 장소 추천 단양생태체육공원 LNT와 공정캠핑으로 쉽고...\n스텔스 차박 장소 추천 군산 새만금방조제 돌고레쉼터\n충주 목계솔밭 캠핑장 노지 차박 장소로 딱 좋아\n청주 노지캠핑 & 차박 장소 추천 천경대 비오는 날 우중 차박캠핑\n지나가다 발견한 청주 노지 차박 캠핑 장소\n차박장소 추천 궁평항 서울근교 바다 힐링 여행\n전북 차박 장소 추천 군산 새만금방조제 해너미휴게소\n괴산 무료 차박 장소 추천 이탄교 아래 노지캠핑 하기 딱 좋아\n차박하기 좋은차? 레이 차박 후기, 경기도 차박 장소 추천!\n영종도 스텔스 차박 장소 추천,실미도등 차박지 6곳 소개..\n전북 군산 캠핑장 및 오토, 모토, 노지, 캠핑카 차박 장소 추천...\n인천 차박 장소 추천 아라뱃길에서 아반떼에 매트 깔음ㅋ\n제부도 차박 장소 추천과 무료 노지캠핑 텐트 치기 좋은곳 소개\n팰리세이드 차박 장소 추천 평창 산너미목장 육십마지기\n서울 근교 차박 장소, 하남 미사경정공원 차크닉\n제주도 차박 장소 추천 같은 곳을 찾았다. 1시간 헤매인...\n울산 주전몽돌해수욕장 캠프닉, 차박장소\n조용하고 안전하게 머물다 오는 차크닉, 차박 장소 추천\n바다가 보이는 나만의 비밀 차박장소\n동해안 차박 장소 추천, 울산 경주 포항 차박지 8곳\n2021 서울 근교 무료 노지 차박 캠핑 장소 추천 : 경기도 인천...\n거제 죽림 해수욕장, 인기 차박 장소, 거제 아이들과 놀기...\n차박장소추천 마음이 내킬 때 언제든 떠나보세요\n함박눈 내리는 홍성 차박 장소, 식물원\n차박하기 좋은차 & 차박 장소 추천, 투싼 해변 즐기기!\n차박 장소 추천, 사람 없고 차박하기 좋은곳 화성 기천저수지!\n나주 석관정나루 나들이, 영산강 차박 가능 장소\n가볼만한곳 맹방해수욕장 방탄소년단 앨범재킷 촬영지 차박장소\n경기도 경치 좋은곳 파주 공릉천 무료 노지 차박 캠핑장소 추천...\n차박 장소 추천, 차박하기 좋은곳 인천 영종도 마시안해변!\n충북 괴산 달천 무료 노지 차박 캠핑 장소, 가을 경치좋은...\n레이 차크닉 : 둘만의 경북 울진 노지차박 가능한 장소로...\n장소추천. 차박 장소 ㅡ 벤츠A220 벤츠a220 해치백 차박 도전기\n영덕 장사상륙작전전승기념관 차박 장소 구경\n강원도 차박 장소 추천 강릉 속초 동해 평창 차박지 9곳\n[인천 차박 장소 추천] 실미도 유원지 당일치기로 다녀 왔어요♥\n서울 근교 겨울 차박 캠핑 장소 추천, 임진강 임진교 : 경기도...\n서울근교 차크닉, 강릉 차박 장소 추천! (feat. 일출)\n경북 경주 차박 장소 추천 관성솔밭해변 해수욕장 노지캠핑 명소\n경기도 포천 무료 노지 차박 캠핑 장소 : 별보기 좋은곳, 야경...\n한탄강 유원지 트레킹, 노지 캠핑 차박 장소 추천\n연천 가볼만한 곳, 산책하기 좋은 곳, 무료 노지 차박 캠핑 장소\n제주도 차박 추천장소\n강원도 강릉 옥계해변 노지 차박캠핑장소 돌아보니\n충남 당진 차박 장소 추천, 서해안 해변 차박지 6곳 소개\n영흥도 용담리해변 차박 노지 캠핑하기 조용한 장소\n울산 차박 장소 슬도 - 감성차박 (feat. 정보공유)\n양양 차박 장소 추천, 양양 남애3리 해수욕장 과 죽도해변 야영장\n강원도 노지캠핑 제드오토듀얼팔레스2 차박텐트, 노지차박장소\n코로나 시대 여행법 \'차박\' 차박하기 좋은 장소 추천\n경기도 차박 장소 추천 (캠핑 No)\n서울 근교 차박 장소 추천 BEST 5\n밀양 바이크타고 가볼만한곳 밀양 드라이브 밀양 차박장소 추천\n야경이 아름다운 서울 근교 차박 장소 추천 ( 슬기로운 차박 생활 )\n숨은 노지 차박 캠핑 장소, 서울 근교 1박 2일 바다 여행 코스\n무의도 실미도해수욕장 해변트레킹 서울근교차박장소... ...

# %%
import nltk

# %%
from konlpy.tag import Twitter; t = Twitter()
tokens_ko = t.nouns(text) 
tokens_ko
# Out:
# ['통영',
#  '차박',
#  '장소',
#  '추천',
#  '수륙',
#  '해수욕장',
#  '낚시',
#  '포인트',
#  '속초',
#  '차박',
#  '장소',
#  '박',
#  '차박',
#  '여행',
#  '차박',
#  '캠핑',
#  '위해',
#  '준비',
#  '만하',
#  '천안',
#  '노지',
#  '차박',
#  '장소',
#  '추천',
#  '제주',
#  '바다',
#  '피크닉',
#  '나',
#  '제주도',
#  '차',
#  '닉',
#  '차박',
#  '장소',
#  '차박',
#  '장소',
#  '추천',
#  '영덕',
#  '장사',
#  '해수욕장',
#  '캠핑',
#  '금표',
#  '제주',
#  '차박',
#  '장소',
#  '이호',
#  '테',
#  '우해',
#  '변',
#  '함덕',
#  '서우',
#  '봉',
#  '해변',
#  '바람',
#  '왜',
#  '차박',
#  '장소',
#  '추천',
#  '안성',
#  '고삼',
#  '저수지',
#  '캠핑',
#  '준비물',
#  '리스트',
#  '차박',
#  '장소',
#  '추천',
#  '서울',
#  '근교',
#  '경기도',
#  '화성',
#  '궁평항',
#  '산책',
#  '곳',
#  '차박',
#  '장소',
#  '강릉',
#  '차박',
#  '장소',
#  '순',
#  '해변',
#  '진',
#  '해변',
#  '추천',
#  '부산',
#  '차박',
#  '장소',
#  '추천',
#  '감성',
#  '캠핑',
#  '땐',
#  '퓨어',
#  '수',
#  '생수',
#  '노지',
#  '캠핑',
#  '경기도',
#  '차박',
#  '차',
#  '닉',
#  '장소',
#  '무료',
#  '취사',
#  '가능',
#  '국내',
#  '무료',
#  '차박',
#  '차',
#  '닉',
#  '장소',
#  '추천',
#  '동해',
#  '바다',
#  '차박',
#  '장소',
#  '추천',
#  '울진',
#  '구산',
#  '해수욕장',
#  '캠핑장',
#  '차박',
#  '장소',
#  '추천',
#  '낚시',
#  '영월',
#  '무료',
#  '노지',
#  '차박',
#  '캠핑',
#  '차박',
#  '입문',
#  '차박',
#  '준비물',
#  '차박',
#  '장소',
#  '추천',
#  '차',
#  '박의',
#  '모든',
#  '것',
#  '양평',
#  '차박',
#  '여행',
#  '차박',
#  '장소',
#  '추천',
#  '캠핑카',
#  '대여',
#  '캠핑카',
#  '렌트',
#  '포항',
#  '차박',
#  '장소',
#  '추천',
#  '월포',
#  '해수욕장',
#  '해변',
#  '차',
#  '박지',
#  '제주도',
#  '차박',
#  '캠핑',
#  '금은',
#  '모래',
#  '해수욕장',
#  '금릉',
#  '해변',
#  '장소',
#  '꼭',
#  '다시',
#  '단양',
#  '생태',
#  '체육',
#  '공원',
#  '차박',
#  '장소',
#  '노지',
#  '캠핑',
#  '차',
#  '박성지',
#  '단양',
#  '구경',
#  '시장',
#  '캠프',
#  '블랙',
#  '코팅',
#  '헥사타프',
#  '자랑',
#  '태안',
#  '차박',
#  '장소',
#  '추천',
#  '차박',
#  '장소',
#  '추천',
#  '서울',
#  '근교',
#  '차박',
#  '차',
#  '박지',
#  '차',
#  '닉',
#  '캠핑',
#  '장소',
#  '경남',
#  '여행',
#  '고성',
#  '무료',
#  '노지',
#  '차박',
#  '장소',
#  '추천',
#  '차박',
#  '여행',
#  '캠핑장',
#  '차박',
#  '장소',
#  '추천',
#  '오대산',
#  '소금강',
#  '강원도',
#  '고성',
#  '노지',
#  '캠핑',
#  '낚시',
#  '차',
#  '장소',
#  '곳',
#  '노지',
#  '차박',
#  '차박',
#  '장소',
#  '추천',
#  '저수지',
#  '화장실',
#  '요금',
#  '거제도',
#  '차박',
#  '장소',
#  '추천',
#  '거제',
#  '흥남',
#  '해수욕장',
#  '밤샘',
#  '낚시',
#  '천안',
#  '계곡',
#  '캠핑장',
#  '차박',
#  '장소',
#  '추천',
#  '노지',
#  '캠핑',
#  '차박',
#  '텐트',
#  '차박',
#  '장소',
#  '추천',
#  '포항',
#  '도구',
#  '해수욕장',
#  '곳',
#  '강원도',
#  '양양',
#  '차박',
#  '장소',
#  '정암',
#  '해수욕장',
#  '이야기',
#  '양양',
#  '여행',
#  '곳',
#  '정암',
#  '해수욕장',
#  '해변',
#  '바다',
#  '차박',
#  '장소',
#  '추천',
#  '제주',
#  '차박',
#  '여행',
#  '광',
#  '치기',
#  '해변',
#  '섭',
#  '해수욕장',
#  '차박',
#  '장소',
#  '후기',
#  '태안',
#  '안면도',
#  '차박',
#  '장소',
#  '추천',
#  '바람',
#  '아래',
#  '해수욕장',
#  '과',
#  '영목항',
#  '막바지',
#  '가을',
#  '천문대',
#  '캠핑장',
#  '차박',
#  '장소',
#  '추천',
#  '언택트',
#  '여행',
#  '트렌드',
#  '차박',
#  '캠핑',
#  '차박',
#  '장소',
#  '추천',
#  '강원도',
#  '동해',
#  '망상',
#  '해수욕장',
#  '산책',
#  '겸',
#  '차박',
#  '캠핑',
#  '장소',
#  '둘러보기',
#  '전국',
#  '차박',
#  '장소',
#  '가평',
#  '차박',
#  '장소',
#  '성리',
#  '국민',
#  '관광지',
#  '차',
#  '닉',
#  '곳',
#  '포항',
#  '닻',
#  '전망대',
#  '간이',
#  '해변',
#  '차박',
#  '장소',
#  '추천',
#  '이유',
#  '가을',
#  '차박',
#  '장소',
#  '추천',
#  '멍',
#  '꽃멍',
#  '노지',
#  '차박',
#  '캠핑',
#  '인천',
#  '차박',
#  '장소',
#  '추천',
#  '소나무',
#  '숲',
#  '실미도',
#  '해수욕장',
#  '차박',
#  '장소',
#  '추천',
#  '서울',
#  '근교',
#  '화성',
#  '방조제',
#  '궁평항',
#  '차',
#  '닉',
#  '노지',
#  '캠핑',
#  '제주',
#  '서쪽',
#  '가장',
#  '차박',
#  '장소',
#  '금능',
#  '해수욕장',
#  '주차장',
#  '노지',
#  '차박',
#  '일기',
#  '노지',
#  '차박',
#  '장소',
#  '추천',
#  '속초',
#  '강릉',
#  '바다',
#  '순',
#  '해변',
#  '강릉',
#  '차박',
#  '장소',
#  '추천',
#  '곳',
#  '차',
#  '곳',
#  '찾기',
#  '걸',
#  '여름',
#  '차박',
#  '장소',
#  '추천',
#  '평창',
#  '마지기',
#  '차박',
#  '후',
#  '데이지',
#  '구경',
#  '제주도',
#  '차박',
#  '캠핑',
#  '용품',
#  '대여',
#  '일출명소',
#  '차',
#  '박지',
#  '성공',
#  '장소',
#  '추천',
#  '인천',
#  '차박',
#  '장소',
#  '추천',
#  '인천',
#  '영종도',
#  '솔직',
#  '후기',
#  '에어',
#  '강원도',
#  '곳',
#  '설악산',
#  '한계령',
#  '휴게소',
#  '차박',
#  '장소',
#  '추천',
#  '수',
#  '차박',
#  '캠핑',
#  '차박',
#  '장소',
#  '추천',
#  '동해안',
#  '차박',
#  '장소',
#  '추천',
#  '영덕',
#  '장사',
#  '해수욕장',
#  '캠핑',
#  '여행',
#  '차박',
#  '장소',
#  '추천',
#  '노지',
#  '캠핑',
#  '이제',
#  '주차장',
#  '차박',
#  '캠핑',
#  '부산',
#  '가덕도',
#  '천성항',
#  '천성항',
#  '차박',
#  '캠핑',
#  '장소',
#  '인천',
#  '차박',
#  '장소',
#  '추천',
#  '차',
#  '닉',
#  '명소',
#  '왕산',
#  '마리나',
#  '제주',
#  '일몰',
#  '명소',
#  '금능',
#  '해수욕장',
#  '차박',
#  '장소',
#  '추천',
#  '차박',
#  '장소',
#  '추천',
#  '메추리섬',
#  '캠핑',
#  '포항',
#  '도항',
#  '차박',
#  '동해',
#  '바다',
#  '곳',
#  '소개',
#  '차박',
#  '장소',
#  '추천',
#  '충남',
#  '보령',
#  '캠핑장',
#  '및',
#  '차박',
#  '장소',
#  '추천',
#  '무창',
#  '포',
#  '오토',
#  '캠핑장',
#  '대전',
#  '차박',
#  '장소',
#  '힐링',
#  '노루',
#  '벌',
#  '힐링',
#  '장소',
#  '궁평',
#  '해송',
#  '유원지',
#  '낙',
#  '감상',
#  '차',
#  '궁평항',
#  '제주도',
#  '차박',
#  '캠핑',
#  '제주',
#  '차박',
#  '장소',
#  '추천',
#  '명성',
#  '끝',
#  '목계',
#  '솔밭',
#  '목계',
#  '나루',
#  '봉',
#  '평일',
#  '풍경',
#  '차박',
#  '장소',
#  '추천',
#  '천안',
#  '벚꽃',
#  '드라이브',
#  '노지',
#  '캠핑',
#  '차박',
#  '장소',
#  '차',
#  '닉',
#  '충주',
#  '곳',
#  '목계',
#  '솔밭',
#  '캠핑장',
#  '무료',
#  '노지',
#  '차박',
#  '장소',
#  '추천',
#  '동해안',
#  '차박',
#  '장소',
#  '추천',
#  '삼척',
#  '맹방',
#  '해수욕장',
#  '영덕',
#  '장사',
#  '해수욕장',
#  '경주',
#  '문무대왕릉',
#  '나정',
#  '운모',
#  '해변',
#  '스텔스',
#  '차박',
#  '장소',
#  '충남',
#  '태안',
#  '차박',
#  '장소',
#  '추천',
#  '마도',
#  '노지',
#  '캠핑',
#  '여건',
#  '차박',
#  '장소',
#  '추천',
#  '생태',
#  '체육',
#  '공원',
#  '공정',
#  '캠핑',
#  '스텔스',
#  '차박',
#  '장소',
#  '추천',
#  '군산',
#  '새만금',
#  '방조제',
#  '돌고레쉼터',
#  '충주',
#  '목계',
#  '솔밭',
#  '캠핑장',
#  '노지',
#  '차박',
#  '장소',
#  '청주',
#  '노지',
#  '캠핑',
#  '차박',
#  '장소',
#  '추천',
#  '경대',
#  '날',
#  '우중',
#  '차박',
#  '캠핑',
#  '발견',
#  '청주',
#  '노지',
#  '차박',
#  '캠핑',
#  '장소',
#  '차박',
#  '장소',
#  '추천',
#  '궁평항',
#  '서울',
#  '근교',
#  '바다',
#  '힐링',
#  '여행',
#  '전북',
#  '차박',
#  '장소',
#  '추천',
#  '군산',
#  '새만금',
#  '방조제',
#  '해너미',
#  '휴게소',
#  '괴산',
#  '무료',
#  '차박',
#  '장소',
#  '추천',
#  '이탄',
#  '교',
#  '아래',
#  '노지',
#  '캠핑',
#  '차',
#  '차',
#  '레이',
#  '차박',
#  '후기',
#  '경기도',
#  '차박',
#  '장소',
#  '추천',
#  '영종도',
#  '스텔스',
#  '차박',
#  '장소',
#  '추천',
#  '실미도',
#  '등',
#  '차',
#  '박지',
#  '곳',
#  '소개',
#  '전북',
#  '군산',
#  '캠핑장',
#  '및',
#  '오토',
#  '모토',
#  '노지',
#  '캠핑카',
#  '차박',
#  '장소',
#  '추천',
#  '인천',
#  '차박',
#  '장소',
#  '추천',
#  '아라뱃길',
#  '아반떼',
#  '매트',
#  '제부도',
#  '차박',
#  '장소',
#  '추천',
#  '무료',
#  '노지',
#  '캠핑',
#  '텐트',
#  '치기',
#  '곳',
#  '소개',
#  '팰리세이드',
#  '차박',
#  '장소',
#  '추천',
#  '평창',
#  '산너',
#  '목장',
#  '마지기',
#  '서울',
#  '근교',
#  '차박',
#  '장소',
#  '하남',
#  '미사',
#  '경정',
#  '공원',
#  '차',
#  '닉',
#  '제주도',
#  '차박',
#  '장소',
#  '추천',
#  '곳',
#  '헤매인',
#  '울산',
#  '몽돌',
#  '해수욕장',
#  '캠프',
#  '닉',
#  '차박',
#  '장소',
#  '차',
#  '닉',
#  '차박',
#  '장소',
#  '추천',
#  '바다',
#  '나',
#  '비밀',
#  '차박',
#  '장소',
#  '동해안',
#  '차박',
#  '장소',
#  '추천',
#  '울산',
#  '경주',
#  '포항',
#  '차',
#  '박지',
#  '곳',
#  '서울',
#  '근교',
#  '무료',
#  '노지',
#  '차박',
#  '캠핑',
#  '장소',
#  '추천',
#  '경기도',
#  '인천',
#  '거제',
#  '죽림',
#  '해수욕장',
#  '인기',
#  '차박',
#  '장소',
#  '거제',
#  '아이',
#  '차박',
#  '장소',
#  '추천',
#  '마음',
#  '내킬',
#  '때',
#  '언제',
#  '함박눈',
#  '홍성',
#  '차박',
#  '장소',
#  '식물원',
#  '차',
#  '차',
#  '차박',
#  '장소',
#  '추천',
#  '투싼',
#  '해변',
#  '차박',
#  '장소',
#  '추천',
#  '사람',
#  '차',
#  '곳',
#  '화성',
#  '저수지',
#  '나주',
#  '관정',
#  '나루',
#  '나들이',
#  '영산강',
#  '차박',
#  '가능',
#  '장소',
#  '곳',
#  '맹방',
#  '해수욕장',
#  '방탄소년단',
#  '앨범',
#  '재킷',
#  '촬영',
#  '차박',
#  '장소',
#  '경기도',
#  '경치',
#  '곳',
#  '파주',
#  '공릉천',
#  '무료',
#  '노지',
#  '차박',
#  '캠핑',
#  '장소',
#  '추천',
#  '차박',
#  '장소',
#  '추천',
#  '차',
#  '곳',
#  '인천',
#  '영종도',
#  '해변',
#  '충북',
#  '괴산',
#  '달천',
#  '무료',
#  '노지',
#  '차박',
#  '캠핑',
#  '장소',
#  '가을',
#  '경치',
#  '레이',
#  '차',
#  '닉',
#  '둘',
#  '경북',
#  '울진',
#  '노지',
#  '차박',
#  '장소',
#  '장소',
#  '추천',
#  '차박',
#  '장소',
#  '벤츠',
#  '벤츠',
#  '해치백',
#  '차박',
#  '도전',
#  '기',
#  '영덕',
#  '장사',
#  '상륙작전',
#  '전승',
#  '기념관',
#  '차박',
#  '장소',
#  '구경',
#  '강원도',
#  '차박',
#  '장소',
#  '추천',
#  '강릉',
#  '속초',
#  '동해',
#  '평창',
#  '차',
#  '박지',
#  '곳',
#  '인천',
#  '차박',
#  '장소',
#  '추천',
#  '실미도',
#  '유원지',
#  '당일치기',
#  '서울',
#  '근교',
#  '겨울',
#  '차박',
#  '캠핑',
#  '장소',
#  '추천',
#  '임진강',
#  '임진',
#  '교',
#  '경기도',
#  '서울',
#  '근교',
#  '차',
#  '닉',
#  '강릉',
#  '차박',
#  '장소',
#  '추천',
#  '일출',
#  '경북',
#  '경주',
#  '차박',
#  '장소',
#  '추천',
#  '관성',
#  '솔밭',
#  '해변',
#  '해수욕장',
#  '노지',
#  '캠핑',
#  '명소',
#  '경기도',
#  '포천',
#  '무료',
#  '노지',
#  '차박',
#  '캠핑',
#  '장소',
#  '보기',
#  '곳',
#  '야경',
#  '한탄강',
#  '유원지',
#  '트레킹',
#  '노지',
#  '캠핑',
#  '차박',
#  '장소',
#  '추천',
#  '연천',
#  '곳',
#  '산책',
#  '곳',
#  '무료',
#  '노지',
#  '차박',
#  '캠핑',
#  '장소',
#  '제주도',
#  '차박',
#  '추천',
#  '장소',
#  '강원도',
#  '강릉',
#  '옥계',
#  '해변',
#  '노지',
#  '차박',
#  '캠핑',
#  '장소',
#  '충남',
#  '당진',
#  '차박',
#  '장소',
#  '추천',
#  '서해안',
#  '해변',
#  '차',
#  '박지',
#  '곳',
#  '소개',
#  '영흥도',
#  '용담',
#  '리',
#  '해변',
#  '차박',
#  '노지',
#  '캠핑',
#  '장소',
#  '울산',
#  '차박',
#  '장소',
#  '슬',
#  '감성',
#  '차박',
#  '정보',
#  '공유',
#  '양양',
#  '차박',
#  '장소',
#  ...]

# %%
len(tokens_ko)
# Out:
# 8703

# %%
from collections import Counter
tokens_counts = Counter(tokens_ko)
tokens_counts
# Out:
# Counter({'통영': 6,
#          '차박': 1178,
#          '장소': 827,
#          '추천': 461,
#          '수륙': 3,
#          '해수욕장': 104,
#          '낚시': 42,
#          '포인트': 15,
#          '속초': 17,
#          '박': 40,
#          '여행': 86,
#          '캠핑': 418,
#          '위해': 1,
#          '준비': 5,
#          '만하': 1,
#          '천안': 10,
#          '노지': 264,
#          '제주': 16,
#          '바다': 42,
#          '피크닉': 18,
#          '나': 17,
#          '제주도': 15,
#          '차': 266,
#          '닉': 141,
#          '영덕': 9,
#          '장사': 8,
#          '금표': 1,
#          '이호': 2,
#          '테': 1,
#          '우해': 1,
#          '변': 8,
#          '함덕': 2,
#          '서우': 2,
#          '봉': 10,
#          '해변': 83,
#          '바람': 5,
#          '왜': 1,
#          '안성': 4,
#          '고삼': 4,
#          '저수지': 34,
#          '준비물': 14,
#          '리스트': 6,
#          '서울': 69,
#          '근교': 87,
#          '경기도': 80,
#          '화성': 25,
#          '궁평항': 23,
#          '산책': 8,
#          '곳': 105,
#          '강릉': 26,
#          '순': 4,
#          '진': 4,
#          '부산': 44,
#          '감성': 18,
#          '땐': 1,
#          '퓨어': 1,
#          '수': 10,
#          '생수': 1,
#          '무료': 73,
#          '취사': 7,
#          '가능': 13,
#          '국내': 9,
#          '동해': 12,
#          '울진': 2,
#          '구산': 1,
#          '캠핑장': 113,
#          '영월': 11,
#          '입문': 3,
#          '박의': 2,
#          '모든': 3,
#          '것': 2,
#          '양평': 3,
#          '캠핑카': 13,
#          '대여': 5,
#          '렌트': 3,
#          '포항': 35,
#          '월포': 1,
#          '박지': 51,
#          '금은': 1,
#          '모래': 2,
#          '금릉': 1,
#          '꼭': 6,
#          '다시': 1,
#          '단양': 8,
#          '생태': 13,
#          '체육': 4,
#          '공원': 46,
#          '박성지': 8,
#          '구경': 5,
#          '시장': 4,
#          '캠프': 6,
#          '블랙': 1,
#          '코팅': 1,
#          '헥사타프': 1,
#          '자랑': 1,
#          '태안': 13,
#          '경남': 24,
#          '고성': 9,
#          '오대산': 1,
#          '소금강': 1,
#          '강원도': 60,
#          '화장실': 21,
#          '요금': 2,
#          '거제도': 9,
#          '거제': 9,
#          '흥남': 1,
#          '밤샘': 2,
#          '계곡': 19,
#          '텐트': 15,
#          '도구': 4,
#          '양양': 20,
#          '정암': 2,
#          '이야기': 3,
#          '광': 4,
#          '치기': 4,
#          '섭': 2,
#          '후기': 26,
#          '안면도': 3,
#          '아래': 3,
#          '과': 4,
#          '영목항': 1,
#          '막바지': 1,
#          '가을': 11,
#          '천문대': 1,
#          '언택트': 4,
#          '트렌드': 2,
#          '망상': 1,
#          '겸': 2,
#          '둘러보기': 4,
#          '전국': 10,
#          '가평': 7,
#          '성리': 4,
#          '국민': 3,
#          '관광지': 8,
#          '닻': 2,
#          '전망대': 4,
#          '간이': 4,
#          '이유': 5,
#          '멍': 1,
#          '꽃멍': 1,
#          '인천': 43,
#          '소나무': 1,
#          '숲': 4,
#          '실미도': 6,
#          '방조제': 6,
#          '서쪽': 1,
#          '가장': 1,
#          '금능': 4,
#          '주차장': 10,
#          '일기': 1,
#          '찾기': 2,
#          '걸': 2,
#          '여름': 8,
#          '평창': 10,
#          '마지기': 8,
#          '후': 1,
#          '데이지': 1,
#          '용품': 14,
#          '일출명소': 1,
#          '성공': 4,
#          '영종도': 16,
#          '솔직': 3,
#          '에어': 1,
#          '설악산': 1,
#          '한계령': 1,
#          '휴게소': 6,
#          '동해안': 7,
#          '이제': 1,
#          '가덕도': 11,
#          '천성항': 6,
#          '명소': 39,
#          '왕산': 4,
#          '마리나': 2,
#          '일몰': 12,
#          '메추리섬': 2,
#          '도항': 1,
#          '소개': 14,
#          '충남': 15,
#          '보령': 5,
#          '및': 12,
#          '무창': 1,
#          '포': 9,
#          '오토': 12,
#          '대전': 9,
#          '힐링': 13,
#          '노루': 2,
#          '벌': 5,
#          '궁평': 4,
#          '해송': 1,
#          '유원지': 19,
#          '낙': 2,
#          '감상': 2,
#          '명성': 1,
#          '끝': 1,
#          '목계': 7,
#          '솔밭': 16,
#          '나루': 3,
#          '평일': 1,
#          '풍경': 8,
#          '벚꽃': 2,
#          '드라이브': 10,
#          '충주': 16,
#          '삼척': 11,
#          '맹방': 7,
#          '경주': 27,
#          '문무대왕릉': 4,
#          '나정': 4,
#          '운모': 4,
#          '스텔스': 24,
#          '마도': 1,
#          '여건': 4,
#          '공정': 1,
#          '군산': 10,
#          '새만금': 5,
#          '돌고레쉼터': 1,
#          '청주': 2,
#          '경대': 1,
#          '날': 6,
#          '우중': 4,
#          '발견': 5,
#          '전북': 9,
#          '해너미': 1,
#          '괴산': 5,
#          '이탄': 1,
#          '교': 9,
#          '레이': 14,
#          '등': 6,
#          '모토': 1,
#          '아라뱃길': 3,
#          '아반떼': 1,
#          '매트': 8,
#          '제부도': 3,
#          '팰리세이드': 2,
#          '산너': 1,
#          '목장': 1,
#          '하남': 2,
#          '미사': 2,
#          '경정': 1,
#          '헤매인': 1,
#          '울산': 22,
#          '몽돌': 5,
#          '비밀': 5,
#          '죽림': 1,
#          '인기': 3,
#          '아이': 12,
#          '마음': 1,
#          '내킬': 1,
#          '때': 3,
#          '언제': 1,
#          '함박눈': 1,
#          '홍성': 3,
#          '식물원': 1,
#          '투싼': 2,
#          '사람': 7,
#          '나주': 2,
#          '관정': 1,
#          '나들이': 8,
#          '영산강': 2,
#          '방탄소년단': 1,
#          '앨범': 1,
#          '재킷': 1,
#          '촬영': 13,
#          '경치': 5,
#          '파주': 8,
#          '공릉천': 1,
#          '충북': 8,
#          '달천': 1,
#          '둘': 1,
#          '경북': 25,
#          '벤츠': 2,
#          '해치백': 1,
#          '도전': 5,
#          '기': 3,
#          '상륙작전': 3,
#          '전승': 3,
#          '기념관': 3,
#          '당일치기': 14,
#          '겨울': 15,
#          '임진강': 3,
#          '임진': 2,
#          '일출': 9,
#          '관성': 8,
#          '포천': 4,
#          '보기': 2,
#          '야경': 4,
#          '한탄강': 4,
#          '트레킹': 3,
#          '연천': 7,
#          '옥계': 3,
#          '당진': 8,
#          '서해안': 4,
#          '영흥도': 3,
#          '용담': 4,
#          '리': 7,
#          '슬': 5,
#          '정보': 7,
#          '공유': 11,
#          '남애': 2,
#          '죽도': 4,
#          '야영장': 9,
#          '제드': 1,
#          '듀얼': 1,
#          '팔레': 1,
#          '스': 1,
#          '코로나': 2,
#          '시대': 1,
#          '법': 5,
#          '밀양': 8,
#          '바이크': 1,
#          '타고': 3,
#          '생활': 5,
#          '코스': 13,
#          '무의도': 3,
#          '교차': 4,
#          '안산': 7,
#          '대부도': 14,
#          '탄도항': 8,
#          '미니': 9,
#          '주전': 3,
#          '여기': 4,
#          '자주': 1,
#          '가지': 5,
#          '트레일': 1,
#          '블': 1,
#          '레이저': 1,
#          '전주': 2,
#          '봄': 3,
#          '교동도': 3,
#          '바다낚시': 2,
#          '강화': 4,
#          '장호': 1,
#          '강': 7,
#          '꿀팁': 10,
#          '아이템': 2,
#          '장비': 3,
#          '맛집': 17,
#          '서해': 11,
#          '주차': 12,
#          '문무왕릉': 1,
#          '폐쇄된': 7,
#          '개': 8,
#          '목록': 5,
#          '칠곡군': 1,
#          '시설': 4,
#          '이동': 5,
#          '섬': 7,
#          '신시모도': 2,
#          '충청도': 7,
#          '부여': 4,
#          '선': 1,
#          '지금': 1,
#          '별': 5,
#          '아침': 2,
#          '운무': 1,
#          '산정': 2,
#          '맥': 4,
#          '세이버': 4,
#          '전라도': 6,
#          '주상절리': 2,
#          '어유': 3,
#          '지리': 3,
#          '성지': 15,
#          '내': 1,
#          '명당': 2,
#          '사이트': 3,
#          '단점': 1,
#          '막교': 1,
#          '생각': 1,
#          '씨앤': 1,
#          '홍천': 9,
#          '한덕': 1,
#          '주변': 4,
#          '의령': 2,
#          '우애': 1,
#          '정': 1,
#          '전기차': 2,
#          '원주': 6,
#          '물색': 2,
#          '중': 2,
#          '스파크': 2,
#          '남양주': 6,
#          '다산': 1,
#          '시화': 4,
#          '거북섬': 3,
#          '청송': 2,
#          '얼음': 1,
#          '골': 3,
#          '최고': 5,
#          '해돋이': 2,
#          '농장': 1,
#          '창': 1,
#          '우리': 1,
#          '잔디': 1,
#          '패킹': 5,
#          '공존': 1,
#          '정원': 2,
#          '피위': 4,
#          '여수': 10,
#          '한국': 2,
#          '베니스': 3,
#          '독채': 1,
#          '이용': 4,
#          '단독': 1,
#          '수원': 4,
#          '간만': 2,
#          '의외': 2,
#          '부': 2,
#          '곡': 2,
#          '대구': 15,
#          '새해': 2,
#          '전남': 10,
#          '광양': 2,
#          '신규': 5,
#          '갯': 2,
#          '마을': 9,
#          '알': 10,
#          '소금': 1,
#          '랜드': 1,
#          '무': 1,
#          '광명항': 2,
#          '공영': 3,
#          '방문': 4,
#          '조마면': 1,
#          '장': 1,
#          '물놀이': 6,
#          '처음': 1,
#          '노가리': 1,
#          '상주': 4,
#          '장각': 1,
#          '폭포': 2,
#          '나무': 1,
#          '교량': 1,
#          '서산': 8,
#          '불멍': 4,
#          '세트': 3,
#          '옥': 1,
#          '화대': 1,
#          '근처': 12,
#          '오지': 3,
#          '솔로': 3,
#          '하동': 2,
#          '물': 6,
#          '소리': 1,
#          '근황': 1,
#          '유치원': 1,
#          '어디': 11,
#          '슈퍼맨': 1,
#          '재방송': 1,
#          '더욱': 1,
#          '풍요롭': 1,
#          '조건': 2,
#          '마섬': 2,
#          '포구': 4,
#          '오랑': 1,
#          '무드등': 1,
#          '가습기': 1,
#          '오픈': 1,
#          '캠린': 3,
#          '요즘': 4,
#          '유행': 1,
#          '해안가': 1,
#          '여행지': 5,
#          '일대': 2,
#          '청도': 6,
#          '기교': 1,
#          '강뷰': 3,
#          '이색': 1,
#          '체험': 7,
#          '저도연육교': 1,
#          '콰이강': 1,
#          '다리': 2,
#          '자': 1,
#          '연애': 1,
#          '첫': 18,
#          '대성공': 1,
#          '인근': 13,
#          '촌': 2,
#          '사전': 1,
#          '조사': 1,
#          '아이리버': 1,
#          '충전': 1,
#          '채': 1,
#          '집': 3,
#          '구애': 1,
#          '모기': 1,
#          '또': 1,
#          '놀': 3,
#          '거리': 4,
#          '먹거리': 2,
#          '초보': 6,
#          '러': 2,
#          '위': 5,
#          '에티켓': 1,
#          '청옥산': 4,
#          '맑은': 2,
#          '공기': 2,
#          '강화도': 14,
#          '갯벌': 6,
#          '의항': 1,
#          '한낮': 1,
#          '어린이': 1,
#          '민물': 3,
#          '시흥': 1,
#          '요': 1,
#          '주말': 7,
#          '부분월식': 1,
#          '블러드': 1,
#          '문': 2,
#          '자은도': 1,
#          '길': 10,
#          '분계': 1,
#          '고창': 4,
#          '동호해수욕장': 3,
#          '스타렉스': 2,
#          '황금': 1,
#          '연어': 1,
#          '월미도': 1,
#          '조개': 3,
#          '구이': 3,
#          '가리비': 1,
#          '무한리필': 1,
#          '청춘': 1,
#          '대관령': 2,
#          '안반': 5,
#          '데기': 5,
#          '리뷰': 4,
#          '김제': 3,
#          '능': 2,
#          '심포항': 3,
#          '신안': 3,
#          '오션': 5,
#          '뷰': 19,
#          '국동항': 1,
#          '곡성': 3,
#          '놀이터': 1,
#          '강변': 2,
#          '행주산성': 1,
#          '역사': 2,
#          '트랭이타': 1,
#          '고고씽': 1,
#          '옆': 2,
#          '자다르': 2,
#          '당일': 11,
#          '황포': 2,
#          '비룡': 2,
#          '대교': 4,
#          '닷지': 1,
#          '램': 1,
#          '트레일러': 2,
#          '차량': 7,
#          '선적': 1,
#          '차로': 1,
#          '측도': 1,
#          '바': 1,
#          '선재도': 3,
#          '타프': 2,
#          '포함': 1,
#          '커튼': 5,
#          '카': 10,
#          '재': 4,
#          '마동': 1,
#          '신흥': 2,
#          '기령': 1,
#          '영훈': 1,
#          '자연': 3,
#          '셀': 2,
#          '토스': 2,
#          '편': 4,
#          '좌': 1,
#          '방진': 1,
#          '남해': 8,
#          '랭': 1,
#          '숙소': 1,
#          '제대로': 1,
#          '동선': 1,
#          '바지': 1,
#          '시즌': 1,
#          '항': 7,
#          '녹동항': 2,
#          '순천': 1,
#          '용인': 8,
#          '침강': 3,
#          '류지': 3,
#          '수산시장': 1,
#          '를': 1,
#          '업데이트': 1,
#          '바닷가': 3,
#          '막': 1,
#          '한강': 7,
#          '함': 2,
#          '망원': 1,
#          '망리': 1,
#          '장점': 1,
#          '방법': 4,
#          '춘천': 5,
#          '빙어': 2,
#          '월리': 1,
#          '화진해수욕장': 3,
#          '묘미': 1,
#          '경관': 1,
#          '편의': 3,
#          '전곡항': 1,
#          '경기': 2,
#          '마리나항': 1,
#          '봉평': 1,
#          '가기': 4,
#          '선유도': 4,
#          '모임': 1,
#          '몽돌위': 1,
#          '피칭': 1,
#          '뉴스': 1,
#          '포티지': 1,
#          '함양': 6,
#          '박정': 1,
#          '볼': 1,
#          '돈': 3,
#          '산': 4,
#          '애견': 3,
#          '동반': 2,
#          '박후기': 2,
#          '거창': 4,
#          '감악산': 3,
#          '아스타': 3,
#          '국화': 3,
#          '꽃': 3,
#          '주왕산': 1,
#          '주산지': 1,
#          '제격': 1,
#          '기장': 5,
#          '달맞이': 2,
#          '구지': 1,
#          '고래': 1,
#          '불': 2,
#          '청양': 1,
#          '까치': 1,
#          '캠': 4,
#          '점': 2,
#          '편의점': 2,
#          '제': 2,
#          '완도': 2,
#          '신지': 2,
#          '충청': 2,
#          '어디가': 1,
#          '팔도': 1,
#          '유랑': 1,
#          '팁': 3,
#          '산차': 5,
#          '남': 1,
#          '돌고래': 2,
#          '터': 8,
#          '앞': 2,
#          '만리': 3,
#          '꼬리': 1,
#          '마이': 1,
#          '딘': 1,
#          '우레': 1,
#          '기본': 2,
#          '고양시': 2,
#          '관광': 1,
#          '팸': 1,
#          '투어': 2,
#          '고양': 1,
#          '궁평리': 4,
#          '배알도해수욕장': 1,
#          '소로': 3,
#          '옛날': 1,
#          '라면': 3,
#          '개구': 1,
#          '삼길포항': 4,
#          '언덕': 1,
#          '아산호': 1,
#          '평택': 5,
#          '호': 3,
#          '별빛산책': 1,
#          '최애': 1,
#          '도리': 1,
#          '최적': 2,
#          '노을': 7,
#          '금강': 1,
#          '옥천': 1,
#          '송지호': 7,
#          '생활의달인': 3,
#          '달인': 3,
#          '위치': 12,
#          '프로': 1,
#          '압록': 3,
#          '가야': 2,
#          '계절': 1,
#          '요리': 2,
#          '공주': 3,
#          '공산성': 1,
#          '단장': 1,
#          '금곡교': 1,
#          '폐쇄': 1,
#          '반려견': 2,
#          '족장': 1,
#          '잘못': 2,
#          '벌금': 1,
#          '원': 1,
#          '숲속': 1,
#          '밤': 2,
#          '쏘렌토': 1,
#          '경험': 1,
#          '아기': 2,
#          '소래': 2,
#          '습지': 2,
#          '화순': 4,
#          '금모래': 2,
#          '인제': 3,
#          '반딧불': 1,
#          '안내': 2,
#          '댕댕': 1,
#          '전차': 1,
#          '대청호': 1,
#          '로하스': 1,
#          '북면': 2,
#          '풍력발전': 2,
#          '최종': 1,
#          '정리': 5,
#          '뜻': 1,
#          '부터': 1,
#          '유의사항': 1,
#          '관련': 1,
#          '고군산군도': 1,
#          '자전거': 2,
#          '라이딩': 1,
#          '신시도': 1,
#          '유명': 3,
#          '장박': 1,
#          '크리스마스': 2,
#          '창문': 1,
#          '트리': 3,
#          '벽': 1,
#          '조명': 1,
#          '행잉': 1,
#          '먼트': 1,
#          '화성시': 2,
#          '해지': 1,
#          '마산': 4,
#          '진전면': 1,
#          '용댐': 1,
#          '녹산': 1,
#          '고향': 1,
#          '동산': 3,
#          '롯데리아': 1,
#          '축제': 1,
#          '금지': 1,
#          '부안': 5,
#          '졸음': 1,
#          '산책길': 1,
#          '해넘이': 1,
#          '선정': 2,
#          '초보자': 2,
#          '지침': 1,
#          '군데': 1,
#          '비교': 1,
#          '인사': 1,
#          '답사': 1,
#          '감': 4,
#          '민공': 1,
#          '고고': 1,
#          '경인아라뱃길': 4,
#          '도로': 2,
#          '어플': 1,
#          '쓰레기': 1,
#          '천연': 1,
#          '보고': 2,
#          '린': 1,
#          '연포': 1,
#          '광주': 11,
#          '굿': 3,
#          '가야산': 1,
#          '백운동': 1,
#          '해양': 1,
#          '앞바다': 1,
#          '눈': 2,
#          '모로': 1,
#          '활공': 1,
#          '바위': 6,
#          '이내': 1,
#          '간월호': 1,
#          '흥왕': 1,
#          '정말': 2,
#          '노는언니': 1,
#          '화': 2,
#          '흥동': 1,
#          '영지': 1,
#          '어른': 1,
#          '꼽': 1,
#          '북구': 1,
#          '가정': 1,
#          '초밥': 1,
#          '피크': 2,
#          '스퀘어': 1,
#          '청천': 1,
#          '베스트': 4,
#          '오류': 2,
#          '고아라': 2,
#          '선택': 1,
#          '과태료': 1,
#          '나래': 2,
#          '경산': 2,
#          '강서구': 1,
#          '주의': 5,
#          '사항': 5,
#          '완료': 1,
#          '카니발': 2,
#          '꽃샘추위': 1,
#          '풍천': 1,
#          '장어': 1,
#          '구봉도': 2,
#          '센터': 1,
#          '왜목': 1,
#          '스팟': 4,
#          '도중': 1,
#          '맞이': 2,
#          '폭우': 1,
#          '호우경보': 1,
#          '금광': 1,
#          '호수': 5,
#          '박두진': 1,
#          '문학': 1,
#          '소형': 1,
#          '카라반': 5,
#          '담양': 1,
#          '참고': 1,
#          '죽장면': 1,
#          '죽장': 1,
#          '칠암항': 1,
#          '군위': 3,
#          '인': 3,
#          '사': 3,
#          '이의': 1,
#          '미니멀리즘': 1,
#          '필수': 2,
#          '템': 2,
#          '물이': 2,
#          '퇴근': 1,
#          '바로': 1,
#          '충주시': 1,
#          '충북영동': 1,
#          '금산': 2,
#          '창원': 5,
#          '진해': 3,
#          '수도': 3,
#          '연락처': 2,
#          '부천': 1,
#          '블라디': 1,
#          '보스': 1,
#          '톡': 1,
#          '하바롭스크': 1,
#          '구간': 1,
#          '비치': 1,
#          '용소': 1,
#          '현장': 1,
#          '스타벅스': 1,
#          '영종': 1,
#          '운': 2,
#          '서점': 1,
#          '메뉴': 1,
#          '테이크아웃': 1,
#          '더': 2,
#          '이상': 1,
#          '아이두': 2,
#          '젠': 3,
#          '충주호': 1,
#          '김해': 2,
#          '생방송': 2,
#          '오늘': 6,
#          '저녁': 3,
#          '이국주': 1,
#          '전남편': 1,
#          '슬리피': 1,
#          '결혼': 1,
#          '소식': 1,
#          '반응': 1,
#          '다이어트': 1,
#          '광고': 1,
#          '전부': 1,
#          '수도권': 3,
#          '오기': 1,
#          '행담도': 1,
#          '순례': 1,
#          '미노': 1,
#          '친구': 2,
#          '만': 1,
#          '캠핑카여행': 1,
#          '씨': 1,
#          '사이드': 2,
#          '구산면': 1,
#          '양덕': 1,
#          '준': 1,
#          '인어': 1,
#          '아저씨': 1,
#          '휴가': 2,
#          '평': 1,
#          '화천': 2,
#          '바퀴': 1,
#          '보성': 1,
#          '월산': 1,
#          '정박': 2,
#          '남당항': 1,
#          '답': 1,
#          '건': 2,
#          '클린': 3,
#          '은': 3,
#          '석교': 3,
#          '병천': 2,
#          '금요일': 1,
#          '날씨': 3,
#          '맑음': 2,
#          '안개': 4,
#          '도착': 2,
#          '견': 1,
#          '겨울철': 1,
#          '무엇': 1,
#          '뮤': 1,
#          '지엄': 1,
#          '카페': 3,
#          '베뉴': 1,
#          '티랩': 1,
#          '푸조': 1,
#          '시트로엥': 1,
#          '그랜드': 1,
#          '스페이스': 1,
#          '기록': 3,
#          '용': 7,
#          '지역': 2,
#          '장성': 3,
#          '황룡강': 1,
#          '키즈': 1,
#          '박도': 1,
#          '전기': 2,
#          '스포티지': 3,
#          '하이브리드': 1,
#          '도보': 1,
#          '대계': 1,
#          '예약': 2,
#          '생애': 3,
#          '최초': 1,
#          '지니': 4,
#          '장차': 1,
#          '문중': 1,
#          '방파제': 3,
#          '고하도': 1,
#          '변산': 1,
#          '주소': 1,
#          '영화': 2,
#          '함평': 1,
#          '돌': 3,
#          '머리': 1,
#          '원두막': 1,
#          '해방': 1,
#          '타운': 1,
#          '허재': 1,
#          '이름': 1,
#          '제바': 1,
#          '시': 1,
#          '문경': 3,
#          '해바라기': 1,
#          '안성맞춤': 1,
#          '여름철': 1,
#          '성산': 1,
#          '일출봉': 1,
#          '장관': 1,
#          '데이트': 7,
#          '닭갈비': 1,
#          '현대': 1,
#          '자동차': 1,
#          '설악': 1,
#          '산들': 1,
#          '동시': 1,
#          '번가': 1,
#          '송정': 1,
#          '향기': 1,
#          '테마': 1,
#          '파크': 1,
#          '순위': 1,
#          '창포': 1,
#          '마검포항': 1,
#          '초지진': 1,
#          '토퍼': 1,
#          '안동': 2,
#          '암산': 1,
#          '로': 1,
#          '차박후': 1,
#          '선녀': 1,
#          '거북': 1,
#          '경상남도': 1,
#          '안전': 1,
#          '칙': 1,
#          '사천': 4,
#          '비토': 1,
#          '천안시': 1,
#          '동남구': 1,
#          '동강': 2,
#          '신관': 1,
#          '차창': 1,
#          '두번째': 3,
#          '마곡': 1,
#          ...})

# %%
len(tokens_counts)
# Out:
# 1494

# %%
#데이터정제하기
STOPWORDS = ['차', '장소', '여행', '블', '차박', '곳', '추천', '캠핑', '닉']

token_ko_selected = []
for token in tokens_ko:
    if token not in STOPWORDS:
        token_ko_selected.append(token)
        
token_counts_selected = Counter(token_ko_selected)
token_counts_selected.most_common(200)
# Out:
# [('노지', 264),
#  ('캠핑장', 113),
#  ('해수욕장', 104),
#  ('근교', 87),
#  ('해변', 83),
#  ('경기도', 80),
#  ('무료', 73),
#  ('서울', 69),
#  ('강원도', 60),
#  ('박지', 51),
#  ('공원', 46),
#  ('부산', 44),
#  ('인천', 43),
#  ('낚시', 42),
#  ('바다', 42),
#  ('박', 40),
#  ('명소', 39),
#  ('포항', 35),
#  ('저수지', 34),
#  ('경주', 27),
#  ('강릉', 26),
#  ('후기', 26),
#  ('화성', 25),
#  ('경북', 25),
#  ('경남', 24),
#  ('스텔스', 24),
#  ('궁평항', 23),
#  ('울산', 22),
#  ('화장실', 21),
#  ('양양', 20),
#  ('계곡', 19),
#  ('유원지', 19),
#  ('뷰', 19),
#  ('피크닉', 18),
#  ('감성', 18),
#  ('첫', 18),
#  ('속초', 17),
#  ('나', 17),
#  ('맛집', 17),
#  ('제주', 16),
#  ('영종도', 16),
#  ('솔밭', 16),
#  ('충주', 16),
#  ('포인트', 15),
#  ('제주도', 15),
#  ('텐트', 15),
#  ('충남', 15),
#  ('겨울', 15),
#  ('성지', 15),
#  ('대구', 15),
#  ('준비물', 14),
#  ('용품', 14),
#  ('소개', 14),
#  ('레이', 14),
#  ('당일치기', 14),
#  ('대부도', 14),
#  ('강화도', 14),
#  ('가능', 13),
#  ('캠핑카', 13),
#  ('생태', 13),
#  ('태안', 13),
#  ('힐링', 13),
#  ('촬영', 13),
#  ('코스', 13),
#  ('인근', 13),
#  ('동해', 12),
#  ('일몰', 12),
#  ('및', 12),
#  ('오토', 12),
#  ('아이', 12),
#  ('주차', 12),
#  ('근처', 12),
#  ('위치', 12),
#  ('영월', 11),
#  ('가을', 11),
#  ('가덕도', 11),
#  ('삼척', 11),
#  ('공유', 11),
#  ('서해', 11),
#  ('어디', 11),
#  ('당일', 11),
#  ('광주', 11),
#  ('천안', 10),
#  ('봉', 10),
#  ('수', 10),
#  ('전국', 10),
#  ('주차장', 10),
#  ('평창', 10),
#  ('드라이브', 10),
#  ('군산', 10),
#  ('꿀팁', 10),
#  ('여수', 10),
#  ('전남', 10),
#  ('알', 10),
#  ('길', 10),
#  ('카', 10),
#  ('영덕', 9),
#  ('국내', 9),
#  ('고성', 9),
#  ('거제도', 9),
#  ('거제', 9),
#  ('포', 9),
#  ('대전', 9),
#  ('전북', 9),
#  ('교', 9),
#  ('일출', 9),
#  ('야영장', 9),
#  ('미니', 9),
#  ('홍천', 9),
#  ('마을', 9),
#  ('장사', 8),
#  ('변', 8),
#  ('산책', 8),
#  ('단양', 8),
#  ('박성지', 8),
#  ('관광지', 8),
#  ('여름', 8),
#  ('마지기', 8),
#  ('풍경', 8),
#  ('매트', 8),
#  ('나들이', 8),
#  ('파주', 8),
#  ('충북', 8),
#  ('관성', 8),
#  ('당진', 8),
#  ('밀양', 8),
#  ('탄도항', 8),
#  ('개', 8),
#  ('서산', 8),
#  ('남해', 8),
#  ('용인', 8),
#  ('터', 8),
#  ('취사', 7),
#  ('가평', 7),
#  ('동해안', 7),
#  ('목계', 7),
#  ('맹방', 7),
#  ('사람', 7),
#  ('연천', 7),
#  ('리', 7),
#  ('정보', 7),
#  ('안산', 7),
#  ('강', 7),
#  ('폐쇄된', 7),
#  ('섬', 7),
#  ('충청도', 7),
#  ('체험', 7),
#  ('주말', 7),
#  ('차량', 7),
#  ('항', 7),
#  ('한강', 7),
#  ('노을', 7),
#  ('송지호', 7),
#  ('용', 7),
#  ('데이트', 7),
#  ('통영', 6),
#  ('리스트', 6),
#  ('꼭', 6),
#  ('캠프', 6),
#  ('실미도', 6),
#  ('방조제', 6),
#  ('휴게소', 6),
#  ('천성항', 6),
#  ('날', 6),
#  ('등', 6),
#  ('전라도', 6),
#  ('원주', 6),
#  ('남양주', 6),
#  ('물놀이', 6),
#  ('물', 6),
#  ('청도', 6),
#  ('초보', 6),
#  ('갯벌', 6),
#  ('함양', 6),
#  ('바위', 6),
#  ('오늘', 6),
#  ('준비', 5),
#  ('바람', 5),
#  ('대여', 5),
#  ('구경', 5),
#  ('이유', 5),
#  ('보령', 5),
#  ('벌', 5),
#  ('새만금', 5),
#  ('발견', 5),
#  ('괴산', 5),
#  ('몽돌', 5),
#  ('비밀', 5),
#  ('경치', 5),
#  ('도전', 5),
#  ('슬', 5),
#  ('법', 5),
#  ('생활', 5),
#  ('가지', 5),
#  ('목록', 5),
#  ('이동', 5),
#  ('별', 5),
#  ('최고', 5),
#  ('패킹', 5),
#  ('신규', 5)]

# %%
len(token_counts_selected)
# Out:
# 1485

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import platform

font_path = "c:/Windows/Fonts/malgun.ttf"

# %%
wordcloud=WordCloud(font_path = font_path,
                background_color="white",
                   max_words=100,
                   relative_scaling=0.3,
                   width = 500,
                   height = 500
                   ).generate_from_frequencies(token_counts_selected)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %% [markdown]
# ## 그래프그리기

# %%
import pandas as pd

# %%
text = pd.read_excel('../data/2021여행지.xlsx')
text.head()
# Out:
#    여행지  검색수
# 0  제주도  257
# 1  강원도   75
# 2   경주   57
# 3   서울   40
# 4   강릉   37

# %%
df = pd.DataFrame(text)
df
# Out:
#      여행지  검색수
# 0    제주도  257
# 1    강원도   75
# 2     경주   57
# 3     서울   40
# 4     강릉   37
# 5     인천   33
# 6     부산   38
# 7     경북   28
# 8    경기도   27
# 9     속초   23
# 10    동해   20
# 11    광양   20
# 12    전북   19
# 13    여수   18
# 14   울릉도   18
# 15    전남   17
# 16    거제   17
# 17    문경   16
# 18    경남   16
# 19    평창   16
# 20   거제도   16
# 21    영덕   15
# 22    충남   15
# 23    대전   15
# 24    파주   14
# 25   전라도   14
# 26    군산   13
# 27   강화도   13
# 28    목포   12
# 29    고성   12
# 30    랜선   12
# 31    태안   12
# 32    밀양   12
# 33    미국   11
# 34    남해   11
# 35    포항   11
# 36    광주   11
# 37    양평   10
# 38    홍콩   10
# 39    담양   10
# 40    정선   10
# 41    충북   10
# 42    양양   10
# 43    삼척   10
# 44     괌   10
# 45    고창   10
# 46    문경    9
# 47    울산    9
# 48  이탈리아    9
# 49  아프리카    9
# 50    통영    9

# %%
df1 = df.groupby('여행지').sum('검색수') 
print(df1)
# Out:
#       검색수
# 여행지
# 강릉     37
# 강원도    75
# 강화도    13
# 거제     17
# 거제도    16
# 경기도    27
# 경남     16
# 경북     28
# 경주     57
# 고성     12
# 고창     10
# 괌      10
# 광양     20
# 광주     11
# 군산     13
# 남해     11
# 담양     10
# 대전     15
# 동해     20
# 랜선     12
# 목포     12
# 문경     25
# 미국     11
# 밀양     12
# 부산     38
# 삼척     10
# 서울     40
# 속초     23
# 아프리카    9
# 양양     10
# 양평     10
# 여수     18
# 영덕     15
# 울릉도    18
# 울산      9
# 이탈리아    9
# 인천     33
# 전남     17
# 전라도    14
# 전북     19
# 정선     10
# 제주도   257
# 충남     15
# 충북     10
# 태안     12
# 통영      9
# 파주     14
# 평창     16
# 포항     11
# 홍콩     10

# %%
df2 = df1.sort_values(by='검색수', ascending=False).head(20)
df2
# Out:
#      검색수
# 여행지
# 제주도  257
# 강원도   75
# 경주    57
# 서울    40
# 부산    38
# 강릉    37
# 인천    33
# 경북    28
# 경기도   27
# 문경    25
# 속초    23
# 광양    20
# 동해    20
# 전북    19
# 여수    18
# 울릉도   18
# 거제    17
# 전남    17
# 평창    16
# 거제도   16

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
colors = sns.color_palette('deep',len(df2.index))

plt.figure(figsize=(12,8))
plt.bar(df2.index, df2['검색수'], color=colors)
plt.xticks(df2.index,fontsize=10)
plt.xlabel('여행지', fontsize=10)
plt.ylabel('검색수', fontsize=10)
plt.ylim([0,270])

plt.show()

# %% [markdown]
# ## 2019년 2021년 비교데이터

# %%
text = pd.read_excel('../data/네이버블로그비교.xlsx')
text
# Out:
#      내용  2019  2021
# 0  당일치기    31    56
# 1    가족    22    44
# 2    힐링     6    27
# 3    뚜벅     6    12
# 4    국내    19    91
# 5    해외    44     7

# %%
text1 = text.groupby('내용').sum('2019') 
print(text1)
# Out:
#       2019  2021
# 내용
# 가족      22    44
# 국내      19    91
# 당일치기    31    56
# 뚜벅       6    12
# 해외      44     7
# 힐링       6    27

# %%
text2 = text1.sort_values(by='내용', ascending=True).head(6)
text2
# Out:
#       2019  2021
# 내용
# 가족      22    44
# 국내      19    91
# 당일치기    31    56
# 뚜벅       6    12
# 해외      44     7
# 힐링       6    27

# %%
import pandas as pd

a = [31,22,6,6,19,44]
b = [56,44,27,12,91,7]
c = ['당일치기', '가족', '힐링', '뚜벅', '국내', '해외']

df = pd.DataFrame({'2019':a, '2021':b,}, index = c)
df
# Out:
#       2019  2021
# 당일치기    31    56
# 가족      22    44
# 힐링       6    27
# 뚜벅       6    12
# 국내      19    91
# 해외      44     7

# %%
from matplotlib import pyplot
import numpy as np

fig,ax = plt.subplots(figsize=(12,6))
bar_width=0.25

index = np.arange(6)

b1 = plt.bar(index, df['2019'], bar_width, alpha=0.4, color='red', label='2019')
b2 = plt.bar(index + bar_width, df['2021'], bar_width, alpha=0.4, color='blue', label='2021')

plt.xticks(np.arange(bar_width, 6 + bar_width, 1),c)

plt.xlabel('내용', size = 13)
plt.ylabel('빈도수', size = 13)
plt.legend()
plt.show()
