# %%
import numpy as np
import pandas as pd
import json
import folium
import webbrowser

# %%
import googlemaps

# %%
my_key = "AIzaSyCWno-azCJKds3yZoWK1cx6euNDWA5EU_0"

# %%
maps = googlemaps.Client(key=my_key)  # my_key값 입력
lat = []  # 위도
lng = []  # 경도

# %%
places = ["가평", "강화도", "대부도", '파주', '양양','양평', '동해', '삼척', '정동진', '정선', '고성', '진천', '단양', '태안', '대전', '고창', '광양', '전라도광주', '목포', '문경', '영덕', '울릉도', '울산', '울진','포항', '밀양', '합천', '남해', '거제도']

# %%
i = 0
for place in places:
    i = i + 1
    try:
        print(i, place)

    # 지오코딩 API 결과값 호출하여 geo_location 변수에 저장
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])

    except:
        lat.append('')
        lng.append('')
        print(i)
# Out:
# 1 가평
# 2 강화도
# 3 대부도
# 4 파주
# 5 양양
# 6 양평
# 7 동해
# 8 삼척
# 9 정동진
# 10 정선
# 11 고성
# 12 진천
# 13 단양
# 14 태안
# 15 대전
# 16 고창
# 17 광양
# 18 전라도광주
# 19 목포
# 20 문경
# 21 영덕
# 22 울릉도
# 23 울산
# 24 울진
# 25 포항
# 26 밀양
# 27 합천
# 28 남해
# 29 거제도

# %%
df = pd.DataFrame({'위도': lat, '경도': lng}, index=places)
print(df)
# Out:
#               위도          경도
# 가평     37.831540  127.509883
# 강화도    37.713174  126.451128
# 대부도    37.241540  126.578629
# 파주     37.759869  126.780178
# 양양     38.075392  128.618850
# 양평     37.491219  127.487561
# 동해     37.524719  129.114292
# 삼척     37.449868  129.165206
# 정동진    37.689201  129.024327
# 정선     37.380755  128.660951
# 고성     38.380129  128.467438
# 진천     36.855380  127.436112
# 단양     36.984547  128.365519
# 태안     36.745642  126.298053
# 대전     36.350412  127.384547
# 고창     35.435822  126.702081
# 광양     34.940697  127.695888
# 전라도광주  35.159545  126.852601
# 목포     34.811835  126.392166
# 문경     36.586148  128.186797
# 영덕     36.415080  129.365968
# 울릉도    37.506368  130.857154
# 울산     35.538377  129.311360
# 울진     36.993066  129.400419
# 포항     36.019018  129.343481
# 밀양     35.503760  128.746442
# 합천     35.566576  128.165799
# 남해     34.837672  127.892423
# 거제도    34.886914  128.623886

# %%
df1 = pd.read_excel('../data/신규지역여행지단어추출빈도수.xlsx')
df1.head()
# Out:
#     지역  가족  힐링  당일치기  숲공원
# 0   가평   0   1     1    1
# 1  강화도   0   2     2    0
# 2  대부도   0   0     3    0
# 3   파주   0   1     3    2
# 4   양양   0   0     0    0

# %%
df1['위도']=lat
df1['경도']=lng
df1.head()
# Out:
#     지역  가족  힐링  당일치기  숲공원         위도          경도
# 0   가평   0   1     1    1  37.831540  127.509883
# 1  강화도   0   2     2    0  37.713174  126.451128
# 2  대부도   0   0     3    0  37.241540  126.578629
# 3   파주   0   1     3    2  37.759869  126.780178
# 4   양양   0   0     0    0  38.075392  128.618850

# %%
df1.to_excel('../data/신규지역여행지단어추출빈도수_1.xlsx')

# %%
map = folium.Map(location=[37.27538, 127.05488], zoom_start=7, tiles='openstreetmap')

# %%
map.save('../data/travel.html')

# %%
df2 = pd.read_excel('../data/신규지역여행지단어추출빈도수_1.xlsx')
df2.head()
# Out:
#    Unnamed: 0   지역  가족  힐링  당일치기  숲공원         위도          경도
# 0           0   가평   0   1     1    1  37.831540  127.509883
# 1           1  강화도   0   2     2    0  37.713174  126.451128
# 2           2  대부도   0   0     3    0  37.241540  126.578629
# 3           3   파주   0   1     3    2  37.759869  126.780178
# 4           4   양양   0   0     0    0  38.075392  128.618850

# %%
for name, lat, lng in zip(df2.지역, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
                        radius=10,  # 원의 반지름
                        color='brown',  # 원의 둘레 색상
                        fill=True,
                        fill_color='coral',  # 원을 채우는 색
                        fill_opacity=0.3,  # 투명도
                        popup=name
                        ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 숲 공원 히트맵추가

# %%
import json
import folium
from folium.plugins import HeatMap

# %%
df3 = pd.read_excel('../data/신규지역여행지단어추출빈도수_1.xlsx')
df3.head()
# Out:
#     지역  가족  힐링  당일치기  숲공원         위도          경도
# 0   가평   0   1     1    1  37.831540  127.509883
# 1  강화도   0   2     2    0  37.713174  126.451128
# 2  대부도   0   0     3    0  37.241540  126.578629
# 3   파주   0   1     3    2  37.759869  126.780178
# 4   양양   0   0     0    0  38.075392  128.618850

# %%
map = folium.Map(location=[37.27538, 127.05488], zoom_start=7, tiles='openstreetmap')

# %%
for name, lat, lng in zip(df2.지역, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
                        radius=10,  # 원의 반지름
                        color='brown',  # 원의 둘레 색상
                        fill=True,
                        fill_color='coral',  # 원을 채우는 색
                        fill_opacity=0.3,  # 투명도
                        popup=name
                        ).add_to(map)

for n in df.index:
    if df['지역'][n] != 'Multiple':
        folium.Marker([crime_anal_raw['lat'][n], crime_anal_raw['lng'][n]],
                     popup=crime_anal_raw['관서명'][n],
                     icon=folium.features.CustomIcon('http://pngwing.com', icon_size=(50,50))).add_to(map)  
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
