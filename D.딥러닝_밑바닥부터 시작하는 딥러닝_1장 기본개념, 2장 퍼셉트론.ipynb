# %% [markdown]
# ## 딥러닝(Deep Learning)
# * 1.딥러닝의 기분 개념과 작동원리
# 다중처리게층(multiple provessing layers)으로 구성된 계산모델을 사용하여 여러 수준의 추상화 통해 데이터 표현<br>
# (음성인식, 이미지 객체 인식, 객체 탐지, 신약품의 발견, 유전자학, 자율주행차)
# * 2.Recent Revial
# * 3.딥러닝의 주요 기법
# * Sigmoid 함수는 모든 실수 입력 값을 0보다 크고 1보다 작은 미분 가능한 수로 변환하는 특징을 갖습니다 -> 함수의 한계점이 있어 ReLu 함수로 바꿈 -> 확률 그라디언트 하강(SGD)느린속도 개선 -> 데이터를 계속 쌓으니 딥러닝 됨
#     * 1.CNN(Convolutional Neural Nestworks):어떤 사물을 볼때 전체를 보지 않는다.(눈,코,입등)
#     * 2.Drop out:뉴럴 네트웍을 끊어서 몇개 노드를 줄이자. training시 몇개의 뉴런을 쉬게 한다. 나머지만 가지고 훈련, 총동원해서 예측(Overfitting 문제 해결 위해)
#     * 3.Distributed representations and language processing:사진의 상황을 묘사하는 기술,입력 이미지에 대한 순환망에 의한 자동 생성된 캡션, 이미지를 CNN처리한후 RNN을 통해 캡션 문장을 생성
#     * 4.Embedding기법:언어처리분야-딥러닝 기술의 도입으로 획기저인 발전, 단어 임베딩(의미가 유사하면 거리도 가깝도록 임베딩, 단어 의미의 유사성은 문장 안에서 인접한 단어의 분포가 얼마나 유사한지를 기준으로 판단, 기본적인 신경망 구조로 학습 가능)
#     * 5.RNN : 일반적인 딥러닝 보다 언어, 사람의 문장을 이해하는데 더 뛰어남
# 참고자료:딥러닝의30가지 적용사례:https://brunch.co.kr/@itschloe1/23
# 참고 교재:http://www.kyobobook.co.kr/product/detailViewKor.laf?mallGb=KOR&ejkGb=KOR&barcode=9788968484636

# %% [markdown]
# ## 밑바닥부터 시작하는 딥러닝

# %% [markdown]
# * 1장<br>
# http://nbviewer.jupyter.org/github/SDRLurker/deep-learning/blob/master/1장.ipynb
#
# * 2장<br>
# http://nbviewer.jupyter.org/github/SDRLurker/deep-learning/blob/master/2장.ipynb
#
# * 3장<br>
# http://nbviewer.jupyter.org/github/SDRLurker/deep-learning/blob/master/3장.ipynb

# %% [markdown]
# # 2장 퍼셉트론
# 뉴런에서 보내온 신호의 총합이 정해진 한계를 넘어설때만 1을 출력한다

# %% [markdown]
# ### 1. AND게이트

# %%
def AND(x1,x2):
    w1, w2, theta = 0.5, 0.5, 0.7 #초기값인 가중치1 가중치2 임계값설정
    tmp = w1*x1 + w2*x2 #식을 만들어줌 
    if tmp <= theta: #theta보다 작다면 return 0
        return 0
    elif tmp > theta : #theta보다 크다면 return1
        return 1

# %%
print(AND(0,0))  #0.5*0 + 0.5*0 <= 0.7
print(AND(1,0))  #0.5*1 + 0.5*0 <= 0.7
print(AND(0,1))  #0.5*0 + 0.5*1 <= 0.7
print(AND(1,1))  #0.5*1 + 0.5*1 > 0.7
# Out:
# 0
# 0
# 0
# 1

# %% [markdown]
# ### 2. NAND게이트

# %%
def NAND(x1,x2):
    w1, w2, theta = -0.5, -0.5, -0.7 #초기값인 가중치1 가중치2 임계값설정
    tmp = w1*x1 + w2*x2 #식을 만들어줌 
    if tmp <= theta: #theta보다 작다면 return 0
        return 0
    elif tmp > theta : #theta보다 크다면 return1
        return 1

# %%
print(NAND(0,0))  #-0.5*0 + -0.5*0 > -0.7
print(NAND(1,0))  #-0.5*1 + -0.5*0 > -0.7
print(NAND(0,1))  #-0.5*0 + -0.5*1 > -0.7
print(NAND(1,1))  #-0.5*1 + -0.5*1 <= -0.7
# Out:
# 1
# 1
# 1
# 0

# %% [markdown]
# ### 3. OR 게이트

# %%
def OR(x1,x2):
    w1, w2, theta = 0.5, 0.5, 0.3 #초기값인 가중치1 가중치2 임계값설정
    tmp = w1*x1 + w2*x2 #식을 만들어줌 
    if tmp <= theta: #theta보다 작다면 return 0
        return 0
    elif tmp > theta : #theta보다 크다면 return1
        return 1

# %%
print(OR(0,0))  #0.5*0 + 0.5*0 <= 0.3
print(OR(1,0))  #0.5*1 + 0.5*0 > 0.3
print(OR(0,1))  #0.5*0 + 0.5*1 > 0.3
print(OR(1,1))  #0.5*1 + 0.5*1 > 0.3
# Out:
# 0
# 1
# 1
# 1

# %% [markdown]
# ### theta값을 b라는 편향(bias)로 바꾸는 다른 방식으로 구현

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
img = imread('../data/2.png')
plt.imshow(img)
plt.show()

# %%
import numpy as np

# %%
x = np.array([0,1]) #x1=0, x2=1
w= np.array([0.5,0.5]) #w1=0.5, w2=0.5
b= -0.7 #편향 = -0.7
w*x # [0*0.5, 1*0.5]
np.sum(w*x)
# Out:
# 0.5

# %%
np.sum(w*x)+b
# Out:
# -0.19999999999999996

# %%
def AND(x1, x2):
    x = np.array([x1,x2]) #x1 x2 배열 생성
    w= np.array([0.5,0.5]) #w1=0.5, w2=0.5
    b= -0.7 #편향 = -0.7
    tmp =np.sum(w*x)+b #식을 만들어줌 
    if tmp <= 0:
        return 0 #tmp가 0보다 작거나 같으면 0출력
    else: 
        return 1 #tmp가 0보다 크면 1출력

# %%
print(AND(0,0))  #(0.5*0 + 0.5*0) +(-0.7) <= 0
print(AND(1,0))  #(0.5*1 + 0.5*0) +(-0.7) <= 0
print(AND(0,1))  #(0.5*0 + 0.5*1) +(-0.7) <= 0
print(AND(1,1))  #(0.5*1 + 0.5*1) +(-0.7) > 0
# Out:
# 0
# 0
# 0
# 1

# %%
def NAND(x1, x2):
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5]) # AND와는 가중치(w와 b)만 다르다.
    b = 0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1

# %%
print(NAND(0,0))  #(-0.5*0 + -0.5*0) +0.7 > 0
print(NAND(1,0))  #(-0.5*1 + -0.5*0) +0.7 > 0
print(NAND(0,1))  #(-0.5*0 + -0.5*1) +0.7 > 0
print(NAND(1,1))  #(-0.5*1 + -0.5*1) +0.7 <- 0
# Out:
# 1
# 1
# 1
# 0

# %%
def OR(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5]) # AND와는 가중치(w와 b)만 다르다.
    b = -0.2
    tmp = np.sum(w*x) + b #활성화식
    if tmp <= 0:
        return 0
    else:
        return 1

# %%
print(OR(0,0))  #(0.5*0 + 0.5*0) +(-0.2) <= 0
print(OR(1,0))  #(0.5*1 + 0.5*0) +(-0.2) > 0
print(OR(0,1))  #(0.5*0 + 0.5*1) +(-0.2) > 0
print(OR(1,1))  #(0.5*1 + 0.5*1) +(-0.2) > 0
# Out:
# 0
# 1
# 1
# 1

# %%
def XOR(x1, x2):
    s1 = NAND(x1, x2)
    s2 = OR(x1, x2)
    y = AND(s1, s2)
    return y
print(XOR(0,0))  
print(XOR(1,0))  
print(XOR(0,1)) 
print(XOR(1,1))
# Out:
# 0
# 1
# 1
# 0

# %%
img = imread('../data/3.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# * 하나의 식으로는 안되니 DEEP하게 레이어를 쌓는 것이 딥러닝이다.
# * NAND와 OR에 다가 AND까지 대입하며 문제 해결
# * s1,s2는 히든 레이어라 함.(XOR게이트의 진리표)

# %%
img = imread('../data/4.jpg')
plt.imshow(img)
plt.show()
