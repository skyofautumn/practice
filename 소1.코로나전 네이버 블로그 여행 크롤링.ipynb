# %% [markdown]
# ## 코로나전 네이버 블로그 바로 들어가서 기간 설정 검색

# %%
import sys
import os

import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from selenium import webdriver
import time
from tqdm import tqdm_notebook

# %%
query_txt = input('1.크롤링할 키워드는 무엇입니까?:')
start_date = input('2. 조회를 시작할 날짜를 입력하세요:')
end_date = input('3. 조회를 종료할 날짜를 입력하세요')

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get('http://naver.com')
time.sleep(2)

element=driver.find_element_by_id("query")
element.send_keys(query_txt)
element.submit()

driver.find_element_by_link_text("VIEW").click()
time.sleep(1)

driver.find_element_by_link_text("블로그").click()
time.sleep(1)

driver.find_element_by_link_text("옵션").click()
time.sleep(1)

driver.find_element_by_link_text("직접입력옵션펼치기").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/2914185354.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/2914185354.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element=driver.find_element_by_id("query")
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/2914185354.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("VIEW").click()
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/2914185354.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("블로그").click()
# ...

# %%
driver.find_element_by_link_text("2019").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/1539779010.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("2019").click()

# %%
driver.find_element_by_link_text("1").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/1856955342.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("1").click()

# %%
driver.find_element_by_link_text("1").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/1856955342.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("1").click()

# %%
driver.find_element_by_link_text("2019").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/1539779010.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("2019").click()

# %%
driver.find_element_by_link_text("12").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/288938466.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("12").click()

# %%
driver.find_element_by_link_text("31").click()
time.sleep(1)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/3502739528.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text("31").click()

# %%
item_li = driver.find_elements_by_css_selector(".option .txt")

for i in range(0, len(item_li)):
    print(item_li[i].text)
# Out:
# 전체
# 블로그
# 카페
# 관련도순
# 최신순
# 전체
# 1시간
# 1일
# 1주
# 1개월
# 3개월
# 6개월
# 1년
# 직접입력옵션
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_58144/2053421347.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   item_li = driver.find_elements_by_css_selector(".option .txt")

# %%
def scroll_down(driver):
    driver.execute_script("window.scrollTo(0, 99999999)")
    time.sleep(1)

# n: 스크롤할 횟수 설정
n = 100
i = 0
while i < n:
    scroll_down(driver)
    i = i+1

# %%
# 블로그 글 url들 수집
url_list = []
title_list = []

# URL_raw 크롤링 시작
article_raw = driver.find_elements_by_css_selector(".api_txt_lines.total_tit")
article_raw[0]

# 크롤링한 url 정제 시작
for article in article_raw:
    url = article.get_attribute('href')   
    url_list.append(url)

time.sleep(1)
    
# 제목 크롤링 시작    
for article in article_raw:
    title = article.text
    title_list.append(title)
# Out:
# C:\Users\dlfrl\AppData\Local\Temp/ipykernel_44500/3414791471.py:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   article_raw = driver.find_elements_by_css_selector(".api_txt_lines.total_tit")

# %%
df = pd.DataFrame({'url':url_list, 'title':title_list})
df
# Out:
#                                                     url  \
# 0     https://blog.naver.com/bolikeme?Redirect=Log&l...
# 1     https://blog.naver.com/scpark1214?Redirect=Log...
# 2     https://blog.naver.com/alchemist_0?Redirect=Lo...
# 3     https://blog.naver.com/treksta051?Redirect=Log...
# 4     https://blog.naver.com/webhouse73?Redirect=Log...
# ...                                                 ...
# 1045  https://blog.naver.com/kyutto?Redirect=Log&log...
# 1046  https://blog.naver.com/taebaek670?Redirect=Log...
# 1047  https://blog.naver.com/sweet14487?Redirect=Log...
# 1048  https://blog.naver.com/softetch?Redirect=Log&l...
# 1049  https://blog.naver.com/gppcgppc?Redirect=Log&l...
#
#                                        title
# 0                   무안 차박 무료캠핑장소 :) 조금나루해수욕장
# 1          우도 섬 속의 섬, 백패킹, 캠핑 장소로 베리 굿~~~비양도
# 2                            나만의 캠핑 장소가 있나요?
# 3                             9월 캠핑장소 추천드려요!
# 4           충주 목계솔밭 무료 캠핑장 차박캠핑장소로 마음에 들었어요.
# ...

# %%
# url_list 저장
df.to_excel("2019캠핑장소naver_blog.xlsx")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44500/417176902.py in <module>
#       1 # url_list 저장
# ----> 2 df.to_excel("2019캠핑장소naver_blog.xlsx")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2282             inf_rep=inf_rep,
#    2283         )
# -> 2284         formatter.write(
#    2285             excel_writer,
#    2286             sheet_name=sheet_name,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     832             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
# ...

# %%
from wordcloud import WordCloud, STOPWORDS

import numpy as np
from PIL import Image

# %%
import matplotlib.pyplot as plt
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager,rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %matplotlib inline

# %%
text = open('../data/2019차박장소.txt', 'r', encoding='utf8').read()
stopwords = set(STOPWORDS)

# %%
text
# Out:
# '차박 20회 결산 특집! - 차박장소, 차박템\n무안 차박 무료캠핑장소 :) 조금나루해수욕장\n서울근교 차박장소 물놀이도 가능한 광탄유원지\n충주 목계솔밭 무료 캠핑장 차박캠핑장소로 마음에 들었어요.\n강원도 차박장소 명당 [안목해변]\n구미 숨겨진 노지 차박캠핑 장소 소개\n차박장소 추천 벌천포 해수욕장 석양이 아름다운 무료캠핑장\n차박캠핑 장소 추천 : 경기도 연천군 동이리 주상절리에서...\n[석모도 어류정항] 파크스11트레일러/노지캠핑/차박장소추천!\n밤 하늘 별 사진 커플여행 조용한 차박 장소\n궁민남편 차박캠핑 촬영장소 임진강 동이리 주상절리\n충주 수주팔봉-첫번째 차박장소\n[차박20]191228 강화 슬로우5션 카페\n강원도 춘천 :: 서울근교불멍 할 수 있는 차박장소 \'홍천강...\n(77번째) 차박캠핑 노지캠핑 장소로 좋은 인구해수욕장!...\n차박장소로 제부도 임시주차장 추천해요\n당일로 가기 좋은 서울 근교 무료차박장소 : 광탄유원지(샤워X...\n루키 _ 부산 차박장소 사전답사 , 대동 낙동강부지\n노이슈반슈타인 성 도착 그리고 그림 같은 차박 장소.\n차박 장소 추천 :: 강원도 영월 반딧불이캠프\n제부도 캠핑 화장실까지 있어서 차박 장소로 최고\n번째 차박 여행으로 영종도 왕산해수욕장에 가다. - 차박위치 및...\n이날만 조용차박 장소\n차박장소로 인천 월미도, 송도는 어떨까요?\n무료캠핑장 문경 소야솔밭 차박장소로도 좋아\n홍천 모곡밤벌유원지 무료 차박 캠핑장소\n캠핑:여수 차박하기 좋은 장소 추천\n오랜만에 다녀온 차박캠핑 연천 동이리 주상절리(임진강)\n속초여행오면가볼만한곳 브롤스타즈옷 차박캠핑\n여주여행 이포대교 차박\n차박 다녀왔습니다. 전라도 무료캠핑, 차박장소, 캠낚 장소 추천...\n루키모기찌니 _ 부산 차박 장소 사전답사 / 영도 감지해수욕장\n테슬라 모델S 강원도 속초 차박 여행\n무창포해수욕장/용두해수욕장 조개캐기 갯벌체험 차박장소\n국내_동해안 무계획 차박여행_2박3일 일정 및 코스\n강원도동계캠핑 차박
# ...

# %%
import nltk

# %%
from konlpy.tag import Twitter; t = Twitter()
tokens_ko = t.nouns(text) 
tokens_ko
# Out:
# ['차박',
#  '결산',
#  '특집',
#  '차박',
#  '장소',
#  '차박템',
#  '무안',
#  '차박',
#  '무료',
#  '캠핑',
#  '장소',
#  '조금',
#  '나루',
#  '해수욕장',
#  '서울',
#  '근교',
#  '차박',
#  '장소',
#  '물놀이',
#  '광',
#  '유원지',
#  '충주',
#  '목계',
#  '솔밭',
#  '무료',
#  '캠핑장',
#  '차박',
#  '캠핑장',
#  '소로',
#  '마음',
#  '강원도',
#  '차박',
#  '장소',
#  '명당',
#  '안목',
#  '해변',
#  '구미',
#  '노지',
#  '차박',
#  '캠핑',
#  '장소',
#  '소개',
#  '차박',
#  '장소',
#  '추천',
#  '벌',
#  '포',
#  '해수욕장',
#  '석양',
#  '무료',
#  '캠핑장',
#  '차박',
#  '캠핑',
#  '장소',
#  '추천',
#  '경기도',
#  '연천군',
#  '리',
#  '주상절리',
#  '석모도',
#  '어류',
#  '정항',
#  '파크스',
#  '트레일러',
#  '노지',
#  '캠핑',
#  '차박',
#  '장소',
#  '추천',
#  '밤',
#  '하늘',
#  '별',
#  '사진',
#  '커플',
#  '여행',
#  '차박',
#  '장소',
#  '궁민',
#  '남편',
#  '차박',
#  '캠핑',
#  '촬영',
#  '장소',
#  '임진강',
#  '리',
#  '주상절리',
#  '충주',
#  '봉',
#  '첫',
#  '차박',
#  '장소',
#  '차박',
#  '강화',
#  '슬로우',
#  '션',
#  '카페',
#  '강원도',
#  '춘천',
#  '서울',
#  '근교',
#  '불멍',
#  '수',
#  '차박',
#  '장소',
#  '홍천',
#  '강',
#  '차박',
#  '캠핑',
#  '노지',
# ...

# %%
len(tokens_ko)
# Out:
# 7442

# %%
from collections import Counter
tokens_counts = Counter(tokens_ko)
tokens_counts
# Out:
# Counter({'차박': 986,
#          '결산': 1,
#          '특집': 1,
#          '장소': 94,
#          '차박템': 1,
#          '무안': 9,
#          '무료': 38,
#          '캠핑': 547,
#          '조금': 5,
#          '나루': 4,
#          '해수욕장': 76,
#          '서울': 22,
#          '근교': 22,
#          '물놀이': 7,
#          '광': 12,
#          '유원지': 34,
#          '충주': 31,
#          '목계': 16,
#          '솔밭': 16,
#          '캠핑장': 65,
#          '소로': 4,
#          '마음': 1,
#          '강원도': 50,
#          '명당': 2,
#          '안목': 7,
#          '해변': 65,
#          '구미': 4,
#          '노지': 48,
#          '소개': 8,
#          '추천': 46,
#          '벌': 3,
#          '포': 18,
#          '석양': 1,
#          '경기도': 14,
#          '연천군': 1,
#          '리': 16,
#          '주상절리': 16,
#          '석모도': 12,
#          '어류': 11,
#          '정항': 11,
#          '파크스': 1,
#          '트레일러': 2,
#          '밤': 8,
#          '하늘': 3,
#          '별': 4,
#          '사진': 4,
#          '커플': 1,
#          '여행': 180,
# ...

# %%
len(tokens_counts)
# Out:
# 1887

# %%
#데이터정제하기
STOPWORDS = [ '차박', '캠핑', '장소', '여행', '곳', '준비물', '정리', '국내', '더', '터', '방']

token_ko_selected = []
for token in tokens_ko:
    if token not in STOPWORDS:
        token_ko_selected.append(token)
        
token_counts_selected = Counter(token_ko_selected)
token_counts_selected.most_common(200)
# Out:
# [('차', 115),
#  ('해수욕장', 76),
#  ('캠핑장', 65),
#  ('해변', 65),
#  ('박', 63),
#  ('텐트', 51),
#  ('강원도', 50),
#  ('낚시', 50),
#  ('노지', 48),
#  ('공원', 47),
#  ('추천', 46),
#  ('무료', 38),
#  ('유원지', 34),
#  ('강릉', 34),
#  ('마지기', 33),
#  ('후기', 32),
#  ('충주', 31),
#  ('캠핑카', 31),
#  ('첫', 30),
#  ('속초', 29),
#  ('인천', 27),
#  ('마을', 27),
#  ('이야기', 27),
#  ('탑', 26),
#  ('아이', 25),
#  ('전남', 24),
#  ('부산', 23),
#  ('루프', 23),
#  ('서울', 22),
#  ('근교', 22),
#  ('봉', 22),
#  ('캠프', 22),
#  ('제주도', 20),
#  ('카니발', 20),
#  ('오토', 20),
#  ('바다', 20),
#  ('포', 18),
#  ('평창', 18),
#  ('경주', 17),
#  ('야영장', 17),
#  ('목계', 16),
#  ('솔밭', 16),
#  ('리', 16),
#  ('주상절리', 16),
#  ('힐링', 16),
#  ('캠퍼', 16),
#  ('캠낚', 15),
#  ('박지', 15),
#  ('두번째', 15),
#  ('성지', 15),
#  ('카', 15),
#  ('용', 15),
#  ('편', 15),
#  ('경기도', 14),
#  ('맛집', 14),
#  ('계곡', 14),
#  ('가을', 14),
#  ('바위', 14),
#  ('여름', 14),
#  ('스카이', 14),
#  ('청옥산', 14),
#  ('홍천', 13),
#  ('여수', 13),
#  ('포항', 13),
#  ('섬', 13),
#  ('양양', 13),
# ...

# %%
len(token_counts_selected)
# Out:
# 1876

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import platform

font_path = "c:/Windows/Fonts/malgun.ttf"

# %%
wordcloud=WordCloud(font_path = font_path,
                background_color="white",
                   max_words=100,
                   relative_scaling=0.3,
                   width = 500,
                   height = 500
                   ).generate_from_frequencies(token_counts_selected)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %% [markdown]
# ## 그래프

# %%
import pandas as pd

# %%
text = pd.read_excel('../data/2019여행지.xlsx')
text.head()
# Out:
#    여행지  검색수
# 0  제주도   81
# 1   유럽   31
# 2  베트남   65
# 3   여수   27
# 4    괌   26

# %%
df = pd.DataFrame(text)
df
# Out:
#       여행지  검색수
# 0     제주도   81
# 1      유럽   31
# 2     베트남   65
# 3      여수   27
# 4       괌   26
# 5      중국   31
# 6     마카오   23
# 7     강원도   21
# 8      부산   21
# 9      경주   20
# 10     대만   18
# 11     강릉   17
# 12     발리   17
# 13     인천   14
# 14     순천   14
# 15    스페인   13
# 16    프랑스   24
# 17     전남   12
# 18     부산   12
# 19   이탈리아   12
# 20    스위스   12
# 21     대구   12
# 22     태국   12
# 23     영국   29
# 24     방콕   18
# 25     통영   10
# 26     호주   10
# 27     일본   34
# 28     담양    9
# 29     미국   22
# 30     독일    8
# 31  말레이시아    8
# 32   포르투갈    8
# 33    하와이    8
# 34     터키    7
# 35     수원    7
# 36     서울    7
# 37     평창    6
# 38     속초    6
# 39     몽골    6
# 40     당진    6
# 41     곡성    5
# 42    사이판    5
# 43  오스트리아    5
# 44  크로아티아    5
# 45     홍콩    5
# 46  바르셀로나    5
# 47     군산    5

# %%
df1 = df.groupby('여행지').sum('검색수') 
print(df1)
# Out:
#        검색수
# 여행지
# 강릉      17
# 강원도     21
# 경주      20
# 곡성       5
# 괌       26
# 군산       5
# 담양       9
# 당진       6
# 대구      12
# 대만      18
# 독일       8
# 마카오     23
# 말레이시아    8
# 몽골       6
# 미국      22
# 바르셀로나    5
# 발리      17
# 방콕      18
# 베트남     65
# 부산      33
# 사이판      5
# 서울       7
# 속초       6
# 수원       7
# 순천      14
# 스위스     12
# 스페인     13
# 여수      27
# 영국      29
# 오스트리아    5
# 유럽      31
# 이탈리아    12
# 인천      14
# 일본      34
# 전남      12
# 제주도     81
# 중국      31
# 크로아티아    5
# 태국      12
# 터키       7
# 통영      10
# 평창       6
# 포르투갈     8
# 프랑스     24
# 하와이      8
# 호주      10
# 홍콩       5

# %%
df2 = df1.sort_values(by='검색수', ascending=False).head(20)
df2
# Out:
#      검색수
# 여행지
# 제주도   81
# 베트남   65
# 일본    34
# 부산    33
# 유럽    31
# 중국    31
# 영국    29
# 여수    27
# 괌     26
# 프랑스   24
# 마카오   23
# 미국    22
# 강원도   21
# 경주    20
# 방콕    18
# 대만    18
# 강릉    17
# 발리    17
# 인천    14
# 순천    14

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
colors = sns.color_palette('deep',len(df2.index))

plt.figure(figsize=(12,8))
plt.bar(df2.index, df2['검색수'], color=colors)
plt.xticks(df2.index,fontsize=10)
plt.xlabel('여행지', fontsize=10)
plt.ylabel('검색수', fontsize=10)
plt.ylim([0,270])

plt.show()

# %% [markdown]
# ## 국내만

# %%
import pandas as pd

# %%
text = pd.read_excel('../data/2019여행지_국내.xlsx')
text.head()
# Out:
#    여행지  검색수
# 0  제주도   81
# 1   여수   27
# 2  강원도   21
# 3   부산   21
# 4   경주   20

# %%
df = pd.DataFrame(text)
df
# Out:
#     여행지  검색수
# 0   제주도   81
# 1    여수   27
# 2   강원도   21
# 3    부산   21
# 4    경주   20
# 5    강릉   17
# 6    인천   14
# 7    순천   14
# 8    전남   12
# 9    부산   12
# 10   대구   12
# 11   통영   10
# 12   담양    9
# 13   수원    7
# 14   서울    7
# 15   평창    6
# 16   속초    6
# 17   당진    6
# 18   곡성    5
# 19   군산    5

# %%
df1 = df.groupby('여행지').sum('검색수') 
print(df1)
# Out:
#      검색수
# 여행지
# 강릉    17
# 강원도   21
# 경주    20
# 곡성     5
# 군산     5
# 담양     9
# 당진     6
# 대구    12
# 부산    33
# 서울     7
# 속초     6
# 수원     7
# 순천    14
# 여수    27
# 인천    14
# 전남    12
# 제주도   81
# 통영    10
# 평창     6

# %%
df2 = df1.sort_values(by='검색수', ascending=False).head(20)
df2
# Out:
#      검색수
# 여행지
# 제주도   81
# 부산    33
# 여수    27
# 강원도   21
# 경주    20
# 강릉    17
# 순천    14
# 인천    14
# 전남    12
# 대구    12
# 통영    10
# 담양     9
# 서울     7
# 수원     7
# 속초     6
# 당진     6
# 평창     6
# 군산     5
# 곡성     5

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
colors = sns.color_palette('deep',len(df2.index))

plt.figure(figsize=(12,8))
plt.bar(df2.index, df2['검색수'], color=colors)
plt.xticks(df2.index,fontsize=10)
plt.xlabel('여행지', fontsize=10)
plt.ylabel('검색수', fontsize=10)
plt.ylim([0, 270])

plt.show()

# %% [markdown]
# ## 워드클라우드 이뿌게

# %%
from wordcloud import WordCloud, STOPWORDS
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import ImageColorGenerator

# %%
def make_wordc(text, mask_image, color):
    wc = WordCloud(background_color="white",
                  max_words=2000,font_path='C:/Users/MS/Downloads/Jalnan1.ttf',
                  mask=mask_image, max_font_size=90,
                  colormap=color)
    wc=wc.generate_from_frequencies(dict(text))
    f = plt.figure(figsize=(12,12))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")

# %%
image2=np.array(Image.open("../data/여행1.png"))
image3=np.array(Image.open("../data/여행2.png"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8356/343644080.py in <module>
#       1 image2=np.array(Image.open("../data/여행1.png"))
#       2 image3=np.array(Image.open("../data/여행2.png"))
# ----> 3 image2.imshow()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'imshow'

# %%
token_counts_selected
# Out:
# Counter({'박': 130,
#          '강릉': 17,
#          '먹방': 5,
#          '꿈': 2,
#          '나트랑': 10,
#          '자유여행': 91,
#          '후기': 18,
#          '전남': 12,
#          '곡성': 5,
#          '비': 6,
#          '날': 10,
#          '기차': 19,
#          '마을': 20,
#          '겨울': 30,
#          '코스': 127,
#          '주말': 13,
#          '제주': 40,
#          '동쪽': 2,
#          '당일치기': 31,
#          '장소': 2,
#          '공개': 5,
#          '가득': 3,
#          '혼놀족': 1,
#          '위': 9,
#          '단': 5,
#          '달력': 1,
#          '무료': 6,
#          '이벤트': 26,
#          '해외여행': 44,
#          '후': 2,
#          '동전': 3,
#          '활용': 2,
#          '법': 5,
#          '대만': 18,
#          '타이베이': 4,
#          '시내': 4,
#          '투어': 26,
#          '유럽': 31,
#          '리스트': 23,
#          '강원도': 21,
#          '재': 2,
#          '발견': 2,
#          '부산': 21,
#          '세이셸': 1,
#          '케냐': 3,
#          '신혼여행': 7,
#          '준비': 32,
#          '프롤로그': 9,
# ...

# %%
image2=np.array(Image.open("../data/여행1.png"))
image3=np.array(Image.open("../data/여행2.png"))

# %%
make_wordc(token_counts_selected, image2, 'summer')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8356/3550252605.py in <module>
# ----> 1 make_wordc(token_counts_selected, image2, 'summer')
#
# ~\AppData\Local\Temp/ipykernel_8356/2944257369.py in make_wordc(text, mask_image, color)
#       4                   mask=mask_image, max_font_size=90,
#       5                   colormap=color)
# ----> 6     wc=wc.generate_from_frequencies(dict(text))
#       7     f = plt.figure(figsize=(12,12))
#       8     plt.imshow(wc, interpolation="bilinear")
#
# ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     494             while True:
#     495                 # try to find a position
# --> 496                 font = ImageFont.truetype(self.font_path, font_size)
#     497                 # transpose font optionally
# ...

# %% [markdown]
# ## 내용 불러오기

# %%
import sys
import os

import pandas as pd
import numpy as np

# %%
# "url_list.csv" 불러오기
url_load = pd.read_excel("20180201-20200131naver_blog.xlsx")

# %%
num_list = len(url_load)

print(num_list)
url_load

# %%
dict = {}    # 전체 크롤링 데이터를 담을 그릇

number = num_list    # 수집할 글 갯수

# 수집한 url 돌면서 데이터 수집
for i in tqdm_notebook(range(0, number)):
    # 글 띄우기
    url = url_load["url"][i]
    driver = webdriver.Chrome(r"./chromedriver/chromedriver.exe")
    driver.get(url)   # 글 띄우기
    
    # 크롤링
    
    try : 
        # 글의 iframe 접근
        driver.switch_to.frame("mainFrame")

        target_info = {}  # 개별 블로그 내용을 담을 딕셔너리 생성

        # 제목 크롤링
        overlays = ".se-module.se-module-text.se-title-text"                        
        tit = driver.find_element_by_css_selector(overlays)
        title = tit.text

        # 글쓴이 크롤링
        overlays = ".nick"                                 
        nick = driver.find_element_by_css_selector(overlays)
        nickname = nick.text

        # 날짜 크롤링
        overlays = ".se_publishDate.pcol2"    
        date = driver.find_element_by_css_selector(overlays)
        datetime = date.text

        # 내용 크롤링
        overlays = ".se-component.se-text.se-l-default"                                 
        contents = driver.find_elements_by_css_selector(overlays)

        content_list = []
        for content in contents:
            content_list.append(content.text)
 
        content_str = ' '.join(content_list)
    
        # 크롤링한 글은 target_info라는 딕셔너리에 담음
        target_info['title'] = title
        target_info['nickname'] = nickname
        target_info['datetime'] = datetime
        target_info['content'] = content_str

        # 각각의 글은 dict라는 딕셔너리에 담음
        dict[i] = target_info
        time.sleep(1)
        
        # 크롤링 성공하면 글 제목을 출력
        print(i, title)

        # 글 하나 크롤링 후 크롬 창 닫기
        driver.close()       
    
    # 에러나면 현재 크롬창을 닫고 다음 글(i+1)로 이동
    except:
        driver.close()
        time.sleep(1)
        continue
    
    # 중간 저장 (없어도됨)
    if i == 30 or 50 or 80:
        # 판다스로 만들기
        import pandas as pd
        result_df = pd.DataFrame.from_dict(dict, 'index')

        # 저장하기
        result_df.to_excel("naver_blog_content.xlsx", encoding='utf-8-sig')   # 한글은 오류날 수 있어서 encoding 추가
        time.sleep(3)

print('수집한 글 갯수: ', len(dict))
print(dict)

# %%
dict[0]

# %%
# 판다스화
result_df = pd.DataFrame.from_dict(dict, 'index')
result_df

# %%
# 엑셀 저장
result_df.to_excel("naver_blog_content.xlsx", encoding='utf-8-sig')

# %%
# 트위터에서 만든 소셜 분석을 위한 형태소 분석기 Okt 사용
okt = Okt()
myList = okt.pos(content_list, norm=True, stem=True) # 모든 형태소 추출
myList_filter = [x for x, y in myList if y in ['nouns']] # 추출된 값 중 동사만 추출
Okt = Text(myList_filter, name="Okt")
 
# 그래프에서 한글이 출력이 안되는 문제 해결 ( 처럼 출력됨)
font_location = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)
 
# 그래프 x, y 라벨 설정
plt.xlabel("명사")
plt.ylabel("빈도")
 
# 그래프에서 x, y 값을 설정
wordInfo = dict()
for tags, counts in Okt.vocab().most_common(50):
    if(len(str(tags)) > 1):
        wordInfo[tags] = counts
 
values = sorted(wordInfo.values(), reverse=True)
keys = sorted(wordInfo, key=wordInfo.get, reverse=True)
 
# 그래프 값 설정
plt.bar(range(len(wordInfo)), values, align='center')
plt.xticks(range(len(wordInfo)), list(keys), rotation='70')
plt.show()

# wordCloud 출력
wc = WordCloud(width = 1000, height = 600, background_color="white", font_path=font_location, max_words=50)
plt.imshow(wc.generate_from_frequencies(Okt.vocab()))
plt.axis("off")
plt.show()
